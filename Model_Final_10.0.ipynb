# %%
import cv2
import numpy as np
from tensorflow.keras.models import load_model
from tensorflow.keras.preprocessing.image import img_to_array

# %%
cam = 2
fps = 240

model_version = "my_model_14.0.keras"
Im_Width = 128
Im_Height = 128

# %%
def crop_image(frame, x, y, w, h):
    return frame[y:y+h, x:x+w]

# %%
def measure_brightness(frame):
    gray = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY) 
    brightness = np.mean(gray)
    return brightness

# %%
def measure_edge_richness(frame):
    gray = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)  # Convert to grayscale
    edges = cv2.Canny(gray, 200, 400)  # Apply Canny edge detection
    edge_richness = np.sum(edges)  # Sum of edge pixel intensities
    return edge_richness

# %%
def select_best_frame(frame_buffer):

    best_frame = None
    highest_brightness = 150
    highest_edge_richness = 100000

    for frame in frame_buffer:

        #Crop
        cropped_frame = crop_image(frame, 220, 0, 200, 200)

        # Measure brightness
        brightness = measure_brightness(cropped_frame)

        if brightness > 150:
            # Update the best frame if this one is better
            if brightness > highest_brightness:
                highest_brightness = brightness
                best_frame = frame  # Save the frame as the best frame
    
        elif brightness > 50 and brightness < 100:
            # Apply edge detection
            edge_richness = measure_edge_richness(cropped_frame)
            # Update the best frame if this one is better
            if edge_richness > highest_edge_richness:
                highest_edge_richness = edge_richness
                best_frame = frame  # Save the cropped frame as the best frame

    return best_frame  # Returns None if no frames meet the threshold

# %%
def process_frame(frame, target_size):

    # Resize the frame to the target size
    resized_frame = cv2.resize(frame, target_size)

    # Normalize pixel values to [0, 1]
    normalized_frame = resized_frame / 255.0

    # Convert to NumPy array and add batch dimension
    frame_array = img_to_array(normalized_frame)
    frame_array = np.expand_dims(frame_array, axis=0)  # Shape: (1, height, width, channels)

    return frame_array

# %%
def predict_frame(frame, model, target_size):

    # Preprocess the frame
    frame_array = process_frame(frame, target_size)

   # Make a prediction
    prediction = model.predict(frame_array)[0][0]  # Get the confidence score
    print(f"Raw Prediction: {prediction}")

    # Interpret the prediction
    if prediction > 0.5:
        #send_to_arduino(arduino, 1)
        return "Non-Defective", prediction       
        
    else:
        #send_to_arduino(arduino, 0)
        return "Defective", prediction

# %%
def capture(cam, model_path, target_size=(Im_Width, Im_Height)):

    cap = cv2.VideoCapture(cam)  # Open webcam
    frame_buffer = []
    max_frames = 10  # Number of frames to evaluate

    # Load the model
    print("Loading model...") 
    model = load_model(model_path)
    print("Model loaded successfully.")

    while True:

        ret, frame = cap.read()
        if not ret:
            print("Failed to capture frame. Exiting...")
            break

        frame_buffer.append(frame)

        # Process the buffer when it's full
        if len(frame_buffer) == max_frames:
            best_frame = select_best_frame(frame_buffer)
            frame_buffer = []  # Clear the buffer

            # Process and predict
            if best_frame is not None:
                feedback, confidence = predict_frame(best_frame, model, target_size)
                print(f"Prediction: {feedback} (Confidence: {confidence:.2f})")

                prob = abs(round(confidence,2)- 0.5)*200

                # Display feedback on the frame
                cv2.putText(best_frame, f"Prediction: {feedback}", (10, 30),
                        cv2.FONT_HERSHEY_SIMPLEX, 1, (0, 255, 0), 2)
                cv2.putText(best_frame, f"Confidence: {prob:.0f}", (10, 60),
                        cv2.FONT_HERSHEY_SIMPLEX, 1, (0, 255, 0), 2)

                # Display the best frame
                cv2.imshow("Best Frame", best_frame)

            else:
                # Load and display the "no-bottle" image in the same window
                image_path = "no-bottle.bmp"
                image = cv2.imread(image_path)

                if image is None:
                    print("Error: Could not load 'no-bottle' image.")
                else:
                    cv2.putText(image, "No Bottle!", (10, 30),
                                cv2.FONT_HERSHEY_SIMPLEX, 1, (0, 255, 0), 2)
                    cv2.imshow("Best Frame", image)

        # Exit on 'ESC' key
        if cv2.waitKey(1) & 0xFF == 27:
            break

    cap.release()
    cv2.destroyAllWindows()

# %%
if __name__ == "__main__":
    model_path = model_version  # Path to your saved model
    capture(cam, model_path, target_size=(Im_Width, Im_Height))
# Out:
# Loading model...
# Model loaded successfully.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 818ms/step
# Raw Prediction: 0.12304011732339859
# Prediction: Defective (Confidence: 0.12)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# Raw Prediction: 0.44447311758995056
# Prediction: Defective (Confidence: 0.44)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# Raw Prediction: 0.0500333346426487
# Prediction: Defective (Confidence: 0.05)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# Raw Prediction: 0.03520885854959488
# Prediction: Defective (Confidence: 0.04)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# Raw Prediction: 0.09576242417097092
# Prediction: Defective (Confidence: 0.10)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# Raw Prediction: 0.8362760543823242
# Prediction: Non-Defective (Confidence: 0.84)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# Raw Prediction: 0.13595989346504211
# Prediction: Defective (Confidence: 0.14)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# Raw Prediction: 0.033842988312244415
# Prediction: Defective (Confidence: 0.03)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# Raw Prediction: 0.6825599670410156
# Prediction: Non-Defective (Confidence: 0.68)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# Raw Prediction: 0.000490108213853091
# Prediction: Defective (Confidence: 0.00)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# Raw Prediction: 0.014252708293497562
# Prediction: Defective (Confidence: 0.01)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# Raw Prediction: 0.8097825050354004
# Prediction: Non-Defective (Confidence: 0.81)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# Raw Prediction: 0.0010464360238984227
# Prediction: Defective (Confidence: 0.00)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# Raw Prediction: 0.02459876611828804
# Prediction: Defective (Confidence: 0.02)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# Raw Prediction: 0.007767143659293652
# Prediction: Defective (Confidence: 0.01)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# Raw Prediction: 0.6524440050125122
# Prediction: Non-Defective (Confidence: 0.65)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# Raw Prediction: 0.9560920000076294
# Prediction: Non-Defective (Confidence: 0.96)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# Raw Prediction: 0.14016786217689514
# Prediction: Defective (Confidence: 0.14)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# Raw Prediction: 0.0008264780044555664
# Prediction: Defective (Confidence: 0.00)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# Raw Prediction: 0.012496394105255604
# Prediction: Defective (Confidence: 0.01)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# Raw Prediction: 0.05079999566078186
# Prediction: Defective (Confidence: 0.05)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# Raw Prediction: 0.07724369317293167
# Prediction: Defective (Confidence: 0.08)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# Raw Prediction: 0.0075752222910523415
# Prediction: Defective (Confidence: 0.01)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# Raw Prediction: 0.026314739137887955
# Prediction: Defective (Confidence: 0.03)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# Raw Prediction: 0.7659661769866943
# Prediction: Non-Defective (Confidence: 0.77)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# Raw Prediction: 0.6248220801353455
# Prediction: Non-Defective (Confidence: 0.62)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# Raw Prediction: 0.9600249528884888
# Prediction: Non-Defective (Confidence: 0.96)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# Raw Prediction: 0.9329853057861328
# Prediction: Non-Defective (Confidence: 0.93)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# Raw Prediction: 0.9742949604988098
# Prediction: Non-Defective (Confidence: 0.97)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# Raw Prediction: 0.9576111435890198
# Prediction: Non-Defective (Confidence: 0.96)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# Raw Prediction: 0.9252410531044006
# Prediction: Non-Defective (Confidence: 0.93)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# Raw Prediction: 0.7754287719726562
# Prediction: Non-Defective (Confidence: 0.78)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# Raw Prediction: 0.9529576301574707
# Prediction: Non-Defective (Confidence: 0.95)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# Raw Prediction: 0.9502296447753906
# Prediction: Non-Defective (Confidence: 0.95)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# Raw Prediction: 0.9154853820800781
# Prediction: Non-Defective (Confidence: 0.92)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# Raw Prediction: 0.926080584526062
# Prediction: Non-Defective (Confidence: 0.93)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# Raw Prediction: 0.9290467500686646
# Prediction: Non-Defective (Confidence: 0.93)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# Raw Prediction: 0.9510217308998108
# Prediction: Non-Defective (Confidence: 0.95)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# Raw Prediction: 0.9182952046394348
# Prediction: Non-Defective (Confidence: 0.92)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# Raw Prediction: 0.9552296996116638
# Prediction: Non-Defective (Confidence: 0.96)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# Raw Prediction: 0.9335736036300659
# Prediction: Non-Defective (Confidence: 0.93)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# Raw Prediction: 0.8501338958740234
# Prediction: Non-Defective (Confidence: 0.85)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# Raw Prediction: 0.9578577280044556
# Prediction: Non-Defective (Confidence: 0.96)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# Raw Prediction: 0.9427177906036377
# Prediction: Non-Defective (Confidence: 0.94)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# Raw Prediction: 0.9220820665359497
# Prediction: Non-Defective (Confidence: 0.92)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# Raw Prediction: 0.9570296406745911
# Prediction: Non-Defective (Confidence: 0.96)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# Raw Prediction: 0.9489873647689819
# Prediction: Non-Defective (Confidence: 0.95)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# Raw Prediction: 0.9158097505569458
# Prediction: Non-Defective (Confidence: 0.92)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# Raw Prediction: 0.9358223676681519
# Prediction: Non-Defective (Confidence: 0.94)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# Raw Prediction: 0.7811511754989624
# Prediction: Non-Defective (Confidence: 0.78)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# Raw Prediction: 0.9658805131912231
# Prediction: Non-Defective (Confidence: 0.97)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# Raw Prediction: 0.9180778861045837
# Prediction: Non-Defective (Confidence: 0.92)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# Raw Prediction: 0.8840842247009277
# Prediction: Non-Defective (Confidence: 0.88)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# Raw Prediction: 0.788826584815979
# Prediction: Non-Defective (Confidence: 0.79)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# Raw Prediction: 0.9504920840263367
# Prediction: Non-Defective (Confidence: 0.95)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# Raw Prediction: 0.76723712682724
# Prediction: Non-Defective (Confidence: 0.77)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# Raw Prediction: 0.5975306630134583
# Prediction: Non-Defective (Confidence: 0.60)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# Raw Prediction: 0.8746405243873596
# Prediction: Non-Defective (Confidence: 0.87)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# Raw Prediction: 0.954560399055481
# Prediction: Non-Defective (Confidence: 0.95)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# Raw Prediction: 0.9538393020629883
# Prediction: Non-Defective (Confidence: 0.95)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# Raw Prediction: 0.8918753266334534
# Prediction: Non-Defective (Confidence: 0.89)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# Raw Prediction: 0.9063210487365723
# Prediction: Non-Defective (Confidence: 0.91)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# Raw Prediction: 0.5874899625778198
# Prediction: Non-Defective (Confidence: 0.59)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# Raw Prediction: 0.799426257610321
# Prediction: Non-Defective (Confidence: 0.80)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# Raw Prediction: 0.9585839509963989
# Prediction: Non-Defective (Confidence: 0.96)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# Raw Prediction: 0.9565277695655823
# Prediction: Non-Defective (Confidence: 0.96)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# Raw Prediction: 0.9247503876686096
# Prediction: Non-Defective (Confidence: 0.92)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# Raw Prediction: 0.930852472782135
# Prediction: Non-Defective (Confidence: 0.93)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# Raw Prediction: 0.9369394183158875
# Prediction: Non-Defective (Confidence: 0.94)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# Raw Prediction: 0.719406008720398
# Prediction: Non-Defective (Confidence: 0.72)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# Raw Prediction: 0.9593541622161865
# Prediction: Non-Defective (Confidence: 0.96)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# Raw Prediction: 0.9492475986480713
# Prediction: Non-Defective (Confidence: 0.95)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# Raw Prediction: 0.9018505215644836
# Prediction: Non-Defective (Confidence: 0.90)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# Raw Prediction: 0.8896085023880005
# Prediction: Non-Defective (Confidence: 0.89)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# Raw Prediction: 0.8373026847839355
# Prediction: Non-Defective (Confidence: 0.84)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# Raw Prediction: 0.9588519930839539
# Prediction: Non-Defective (Confidence: 0.96)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# Raw Prediction: 0.8579016327857971
# Prediction: Non-Defective (Confidence: 0.86)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# Raw Prediction: 0.9615814685821533
# Prediction: Non-Defective (Confidence: 0.96)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# Raw Prediction: 0.9365145564079285
# Prediction: Non-Defective (Confidence: 0.94)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# Raw Prediction: 0.5082689523696899
# Prediction: Non-Defective (Confidence: 0.51)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# Raw Prediction: 0.5752034783363342
# Prediction: Non-Defective (Confidence: 0.58)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# Raw Prediction: 0.9639963507652283
# Prediction: Non-Defective (Confidence: 0.96)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# Raw Prediction: 0.6059098243713379
# Prediction: Non-Defective (Confidence: 0.61)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# Raw Prediction: 0.9655346274375916
# Prediction: Non-Defective (Confidence: 0.97)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# Raw Prediction: 0.8736488223075867
# Prediction: Non-Defective (Confidence: 0.87)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# Raw Prediction: 0.9616079330444336
# Prediction: Non-Defective (Confidence: 0.96)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# Raw Prediction: 0.9565237760543823
# Prediction: Non-Defective (Confidence: 0.96)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# Raw Prediction: 0.923662006855011
# Prediction: Non-Defective (Confidence: 0.92)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# Raw Prediction: 0.766708254814148
# Prediction: Non-Defective (Confidence: 0.77)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# Raw Prediction: 0.9649916291236877
# Prediction: Non-Defective (Confidence: 0.96)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# Raw Prediction: 0.9122260808944702
# Prediction: Non-Defective (Confidence: 0.91)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# Raw Prediction: 0.9278491735458374
# Prediction: Non-Defective (Confidence: 0.93)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# Raw Prediction: 0.9699245691299438
# Prediction: Non-Defective (Confidence: 0.97)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# Raw Prediction: 0.9583913683891296
# Prediction: Non-Defective (Confidence: 0.96)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# Raw Prediction: 0.9595625400543213
# Prediction: Non-Defective (Confidence: 0.96)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# Raw Prediction: 0.9672521352767944
# Prediction: Non-Defective (Confidence: 0.97)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# Raw Prediction: 0.6796255111694336
# Prediction: Non-Defective (Confidence: 0.68)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# Raw Prediction: 0.8672072291374207
# Prediction: Non-Defective (Confidence: 0.87)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# Raw Prediction: 0.8906911611557007
# Prediction: Non-Defective (Confidence: 0.89)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# Raw Prediction: 0.7116241455078125
# Prediction: Non-Defective (Confidence: 0.71)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# Raw Prediction: 0.9660522937774658
# Prediction: Non-Defective (Confidence: 0.97)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# Raw Prediction: 0.9034512042999268
# Prediction: Non-Defective (Confidence: 0.90)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# Raw Prediction: 0.8742526173591614
# Prediction: Non-Defective (Confidence: 0.87)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# Raw Prediction: 0.2694980502128601
# Prediction: Defective (Confidence: 0.27)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# Raw Prediction: 0.9144130945205688
# Prediction: Non-Defective (Confidence: 0.91)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# Raw Prediction: 0.9643784761428833
# Prediction: Non-Defective (Confidence: 0.96)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# Raw Prediction: 0.9648043513298035
# Prediction: Non-Defective (Confidence: 0.96)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# Raw Prediction: 0.9584384560585022
# Prediction: Non-Defective (Confidence: 0.96)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# Raw Prediction: 0.8563076257705688
# Prediction: Non-Defective (Confidence: 0.86)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# Raw Prediction: 0.8896501660346985
# Prediction: Non-Defective (Confidence: 0.89)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# Raw Prediction: 0.9631884694099426
# Prediction: Non-Defective (Confidence: 0.96)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# Raw Prediction: 0.9260651469230652
# Prediction: Non-Defective (Confidence: 0.93)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# Raw Prediction: 0.96331387758255
# Prediction: Non-Defective (Confidence: 0.96)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# Raw Prediction: 8.991543509750954e-09
# Prediction: Defective (Confidence: 0.00)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# Raw Prediction: 6.61062848905658e-09
# Prediction: Defective (Confidence: 0.00)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# Raw Prediction: 6.132143681725211e-09
# Prediction: Defective (Confidence: 0.00)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# Raw Prediction: 2.2514335284995468e-08
# Prediction: Defective (Confidence: 0.00)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# Raw Prediction: 2.2978967617603985e-09
# Prediction: Defective (Confidence: 0.00)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# Raw Prediction: 2.5586142093914077e-09
# Prediction: Defective (Confidence: 0.00)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# Raw Prediction: 5.0226214298731975e-09
# Prediction: Defective (Confidence: 0.00)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# Raw Prediction: 5.404432101840939e-08
# Prediction: Defective (Confidence: 0.00)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# Raw Prediction: 1.023442752767778e-08
# Prediction: Defective (Confidence: 0.00)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# Raw Prediction: 1.4491721600506935e-08
# Prediction: Defective (Confidence: 0.00)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# Raw Prediction: 7.81203723931867e-08
# Prediction: Defective (Confidence: 0.00)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# Raw Prediction: 9.240286757972171e-09
# Prediction: Defective (Confidence: 0.00)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# Raw Prediction: 2.999014014903878e-08
# Prediction: Defective (Confidence: 0.00)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# Raw Prediction: 1.3400853049461148e-07
# Prediction: Defective (Confidence: 0.00)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# Raw Prediction: 6.87821781752973e-08
# Prediction: Defective (Confidence: 0.00)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# Raw Prediction: 6.45466400328587e-08
# Prediction: Defective (Confidence: 0.00)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# Raw Prediction: 4.8116444162360494e-08
# Prediction: Defective (Confidence: 0.00)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# Raw Prediction: 4.965102107234998e-08
# Prediction: Defective (Confidence: 0.00)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# Raw Prediction: 7.193148121587001e-08
# Prediction: Defective (Confidence: 0.00)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# Raw Prediction: 1.5964224076014943e-07
# Prediction: Defective (Confidence: 0.00)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# Raw Prediction: 9.785172551346477e-06
# Prediction: Defective (Confidence: 0.00)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# Raw Prediction: 6.223650483860865e-10
# Prediction: Defective (Confidence: 0.00)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# Raw Prediction: 2.7263430979473924e-07
# Prediction: Defective (Confidence: 0.00)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# Raw Prediction: 0.10209137201309204
# Prediction: Defective (Confidence: 0.10)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# Raw Prediction: 0.0023862658999860287
# Prediction: Defective (Confidence: 0.00)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# Raw Prediction: 0.0374135822057724
# Prediction: Defective (Confidence: 0.04)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# Raw Prediction: 0.33402377367019653
# Prediction: Defective (Confidence: 0.33)
