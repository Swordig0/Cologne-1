# %%
import os
import cv2
import numpy as np

def crop_image(frame, x, y, w, h):
    """
    Crops a region of interest (ROI) from an image.

    Args:
        frame (np.array): Input image.
        x (int): X-coordinate of the top-left corner of the ROI.
        y (int): Y-coordinate of the top-left corner of the ROI.
        w (int): Width of the ROI.
        h (int): Height of the ROI.

    Returns:
        np.array: Cropped image.
    """
    return frame[y:y+h, x:x+w]

def measure_edge_richness(frame):
    """
    Measures the edge richness of a frame using Canny edge detection.
    
    Args:
        frame (np.array): Input frame (BGR format).
    
    Returns:
        edges (np.array): The edge-detected image.
        edge_richness (int): The sum of edge intensities (or count of edge pixels).
    """
    gray = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)  # Convert to grayscale
    edges = cv2.Canny(gray, 100, 200)  # Apply Canny edge detection
    edge_richness = np.sum(edges)  # Sum of edge pixel intensities
    return edges, edge_richness

def process_batch_with_best_frame(input_path, output_path, x, y, w, h, best_frame_path):
    """
    Processes a batch of images, crops them, applies edge detection, saves results,
    and identifies the best frame based on edge richness.

    Args:
        input_path (str): Path to the folder containing input images.
        output_path (str): Path to save edge detection results.
        x, y, w, h (int): Coordinates and size of the cropping rectangle.
        best_frame_path (str): Path to save the best frame.
    """
    if not os.path.exists(output_path):
        os.makedirs(output_path)  # Create the output directory if it doesn't exist

    best_frame = None
    best_frame_name = None
    highest_edge_richness = -1  # Initialize with a very low value

    for filename in os.listdir(input_path):
        input_file = os.path.join(input_path, filename)

        # Ensure the file is an image
        if not filename.lower().endswith(('.jpg')):
            continue

        # Read the image
        frame = cv2.imread(input_file)
        if frame is None:
            print(f"Failed to read {input_file}. Skipping...")
            continue

        # Crop the image
        cropped = crop_image(frame, x, y, w, h)

        # Apply edge detection
        edges, edge_richness = measure_edge_richness(cropped)

        # Save the edge-detected image
        edge_file = os.path.join(output_path, f"edges_{filename}")
        cv2.imwrite(edge_file, edges)

        # Save the edge richness score to a text file
        score_file = os.path.join(output_path, "edge_richness_scores.txt")
        with open(score_file, "a") as f:
            f.write(f"{filename}: {edge_richness}\n")

        # Update the best frame if this one is better
        if edge_richness > highest_edge_richness:
            highest_edge_richness = edge_richness
            best_frame = frame  # Save the cropped frame as the best frame
            best_frame_name = filename

        print(f"Processed {filename}: Edge Richness = {edge_richness}")

    # Save the best frame separately
    if best_frame is not None:
        best_frame_file = os.path.join(best_frame_path, f"best_frame_{best_frame_name}")
        cv2.imwrite(best_frame_file, best_frame)
        print(f"Best frame saved as: {best_frame_file} with Edge Richness = {highest_edge_richness}")

# Example usage
input_path = "Edge/Samples/08"   # Replace with the path to your input images
output_path = "Edge/Results/08"  # Replace with the path to save results
best_frame_path = "Edge/Results/08/Best"    # Replace with the path to save the best frame
x, y, w, h = 60, 0, 520, 300  # Example crop rectangle (top-left at (100, 50), 200x200 size)
process_batch_with_best_frame(input_path, output_path, x, y, w, h, best_frame_path)
# Out:
# Processed Image4385.jpg: Edge Richness = 114495
# Processed Image4386.jpg: Edge Richness = 112710
# Processed Image4387.jpg: Edge Richness = 127245
# Processed Image4388.jpg: Edge Richness = 110160
# Processed Image4389.jpg: Edge Richness = 119850
# Processed Image4390.jpg: Edge Richness = 141270
# Processed Image4391.jpg: Edge Richness = 156315
# Processed Image4392.jpg: Edge Richness = 164730
# Processed Image4393.jpg: Edge Richness = 177225
# Processed Image4394.jpg: Edge Richness = 175950
# Processed Image4395.jpg: Edge Richness = 184110
# Processed Image4396.jpg: Edge Richness = 171105
# Processed Image4397.jpg: Edge Richness = 141015
# Processed Image4398.jpg: Edge Richness = 134385
# Processed Image4399.jpg: Edge Richness = 131325
# Processed Image4400.jpg: Edge Richness = 158865
# Processed Image4401.jpg: Edge Richness = 157590
# Processed Image4402.jpg: Edge Richness = 165495
# Processed Image4403.jpg: Edge Richness = 161925
# Processed Image4404.jpg: Edge Richness = 175695
# Processed Image4405.jpg: Edge Richness = 126480
# Processed Image4406.jpg: Edge Richness = 143310
# Processed Image4407.jpg: Edge Richness = 149430
# Processed Image4408.jpg: Edge Richness = 164475
# Processed Image4409.jpg: Edge Richness = 167280
# Processed Image4410.jpg: Edge Richness = 171615
# Processed Image4411.jpg: Edge Richness = 162945
# Processed Image4412.jpg: Edge Richness = 179775
# Processed Image4413.jpg: Edge Richness = 147645
# Processed Image4414.jpg: Edge Richness = 142800
# Processed Image4415.jpg: Edge Richness = 149175
# Processed Image4416.jpg: Edge Richness = 140505
# Processed Image4417.jpg: Edge Richness = 128265
# Processed Image4418.jpg: Edge Richness = 119085
# Processed Image4419.jpg: Edge Richness = 125460
# Processed Image4420.jpg: Edge Richness = 112455
# Processed Image4421.jpg: Edge Richness = 115515
# Processed Image4422.jpg: Edge Richness = 122910
# Processed Image4423.jpg: Edge Richness = 131835
# Processed Image4424.jpg: Edge Richness = 137190
# Processed Image4425.jpg: Edge Richness = 131580
# Processed Image4426.jpg: Edge Richness = 118320
# Processed Image4427.jpg: Edge Richness = 111945
# Processed Image4428.jpg: Edge Richness = 111945
# Processed Image4429.jpg: Edge Richness = 107610
# Processed Image4430.jpg: Edge Richness = 105825
# Processed Image4431.jpg: Edge Richness = 106335
# Processed Image4432.jpg: Edge Richness = 94605
# Processed Image4433.jpg: Edge Richness = 85170
# Processed Image4434.jpg: Edge Richness = 66555
# Processed Image4435.jpg: Edge Richness = 61455
# Processed Image4436.jpg: Edge Richness = 59160
# Processed Image4437.jpg: Edge Richness = 58650
# Processed Image4438.jpg: Edge Richness = 52530
# Processed Image4439.jpg: Edge Richness = 51000
# Processed Image4440.jpg: Edge Richness = 48450
# Processed Image4441.jpg: Edge Richness = 45900
# Processed Image4442.jpg: Edge Richness = 42330
# Processed Image4443.jpg: Edge Richness = 40800
# Processed Image4444.jpg: Edge Richness = 35700
# Processed Image4445.jpg: Edge Richness = 35700
# Processed Image4446.jpg: Edge Richness = 31365
# Processed Image4447.jpg: Edge Richness = 27030
# Processed Image4448.jpg: Edge Richness = 26265
# Processed Image4449.jpg: Edge Richness = 24480
# Processed Image4450.jpg: Edge Richness = 39780
# Processed Image4451.jpg: Edge Richness = 18870
# Processed Image4452.jpg: Edge Richness = 17085
# Processed Image4453.jpg: Edge Richness = 29835
# Processed Image4454.jpg: Edge Richness = 14535
# Processed Image4455.jpg: Edge Richness = 11220
# Processed Image4456.jpg: Edge Richness = 6375
# Processed Image4900.jpg: Edge Richness = 0
# Processed Image4901.jpg: Edge Richness = 0
# Processed Image4902.jpg: Edge Richness = 0
# Processed Image4903.jpg: Edge Richness = 0
# Processed Image4904.jpg: Edge Richness = 0
# Processed Image4905.jpg: Edge Richness = 0
# Processed Image4906.jpg: Edge Richness = 0
# Processed Image4907.jpg: Edge Richness = 0
# Best frame saved as: Edge/Results/08/Best\best_frame_Image4395.jpg with Edge Richness = 184110
