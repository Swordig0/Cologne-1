# %%
import cv2
import numpy as np
from tensorflow.keras.models import load_model
from tensorflow.keras.preprocessing.image import img_to_array

Im_Width = 128
Im_Height = 128

def process_frame(frame, target_size):
    """
    Processes a webcam frame for model prediction.
    
    Args:
        frame (np.array): Captured frame from the webcam.
        target_size (tuple): Target size for resizing the frame (width, height).

    Returns:
        np.array: Preprocessed image ready for model prediction.
    """
    # Resize the frame to the target size
    resized_frame = cv2.resize(frame, target_size)

    # Normalize pixel values to [0, 1]
    normalized_frame = resized_frame / 255.0

    # Convert to NumPy array and add batch dimension
    frame_array = img_to_array(normalized_frame)
    frame_array = np.expand_dims(frame_array, axis=0)  # Shape: (1, height, width, channels)

    return frame_array

def predict_frame(frame, model, target_size):
    """
    Predicts the class of a single frame using the model.

    Args:
        frame (np.array): Captured frame from the webcam.
        model: Loaded Keras model.
        target_size (tuple): Target size for resizing the frame.

    Returns:
        str: Predicted class label.
        float: Confidence score.
    """
    # Preprocess the frame
    frame_array = process_frame(frame, target_size)

    # Make a prediction
    prediction = model.predict(frame_array)[0][0]  # Get the confidence score
    print(f"Raw Prediction: {prediction}")

    # Interpret the prediction
    if prediction > 0.5:
        return "Non-Defective", prediction
    else:
        return "Defective", prediction

def run_webcam_with_model(model_path, target_size=(Im_Width, Im_Height)):
    """
    Opens the webcam, captures frames, and processes them using the model.

    Args:
        model_path (str): Path to the saved Keras model.
        target_size (tuple): Target size for resizing frames (width, height).
    """
    # Load the model
    print("Loading model...")
    model = load_model(model_path)
    print("Model loaded successfully.")

    # Open the webcam
    cap = cv2.VideoCapture(0)
    if not cap.isOpened():
        raise IOError("Cannot open the webcam")

    print("Webcam opened. Press 'ESC' to exit.")
    try:
        while True:
            # Capture frame from the webcam
            ret, frame = cap.read()
            if not ret:
                print("Failed to capture frame. Exiting...")
                break

            # Process and predict
            feedback, confidence = predict_frame(frame, model, target_size)
            print(f"Prediction: {feedback} (Confidence: {confidence:.2f})")

            # Display feedback on the frame
            cv2.putText(frame, f"Prediction: {feedback}", (10, 30),
                        cv2.FONT_HERSHEY_SIMPLEX, 1, (0, 255, 0), 2)
            cv2.putText(frame, f"Confidence: {confidence:.2f}", (10, 60),
                        cv2.FONT_HERSHEY_SIMPLEX, 1, (0, 255, 0), 2)

            # Show the frame in a window
            cv2.imshow("Webcam Feed", frame)

            # Exit on 'ESC' key
            if cv2.waitKey(1) & 0xFF == 27:  # 27 is the ASCII code for ESC
                print("Exiting...")
                break

    finally:
        # Release resources
        cap.release()
        cv2.destroyAllWindows()

# Run the script
if __name__ == "__main__":
    model_path = "my_model_1.1.keras"  # Path to your saved model
    run_webcam_with_model(model_path, target_size=(Im_Width, Im_Height))
# Out:
# Loading model...
# Model loaded successfully.
# Webcam opened. Press 'ESC' to exit.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 936ms/step
# Raw Prediction: 0.030797040089964867
# Prediction: Defective (Confidence: 0.03)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# Raw Prediction: 0.02191970683634281
# Prediction: Defective (Confidence: 0.02)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# Raw Prediction: 0.026983264833688736
# Prediction: Defective (Confidence: 0.03)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# Raw Prediction: 0.026376815512776375
# Prediction: Defective (Confidence: 0.03)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# Raw Prediction: 0.025404738262295723
# Prediction: Defective (Confidence: 0.03)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# Raw Prediction: 0.022928591817617416
# Prediction: Defective (Confidence: 0.02)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# Raw Prediction: 0.02058466710150242
# Prediction: Defective (Confidence: 0.02)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step
# Raw Prediction: 0.026451654732227325
# Prediction: Defective (Confidence: 0.03)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# Raw Prediction: 0.02689388394355774
# Prediction: Defective (Confidence: 0.03)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# Raw Prediction: 0.02459418959915638
# Prediction: Defective (Confidence: 0.02)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# Raw Prediction: 0.02347995899617672
# Prediction: Defective (Confidence: 0.02)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# Raw Prediction: 0.027287796139717102
# Prediction: Defective (Confidence: 0.03)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# Raw Prediction: 0.02139468677341938
# Prediction: Defective (Confidence: 0.02)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# Raw Prediction: 0.021761301904916763
# Prediction: Defective (Confidence: 0.02)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# Raw Prediction: 0.024058885872364044
# Prediction: Defective (Confidence: 0.02)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# Raw Prediction: 0.018382756039500237
# Prediction: Defective (Confidence: 0.02)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# Raw Prediction: 0.016602417454123497
# Prediction: Defective (Confidence: 0.02)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# Raw Prediction: 0.01504067238420248
# Prediction: Defective (Confidence: 0.02)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# Raw Prediction: 0.017980044707655907
# Prediction: Defective (Confidence: 0.02)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# Raw Prediction: 0.021860308945178986
# Prediction: Defective (Confidence: 0.02)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# Raw Prediction: 0.01808062382042408
# Prediction: Defective (Confidence: 0.02)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# Raw Prediction: 0.018133845180273056
# Prediction: Defective (Confidence: 0.02)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# Raw Prediction: 0.012922806665301323
# Prediction: Defective (Confidence: 0.01)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# Raw Prediction: 0.01236011739820242
# Prediction: Defective (Confidence: 0.01)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# Raw Prediction: 0.02153783105313778
# Prediction: Defective (Confidence: 0.02)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# Raw Prediction: 0.019395193085074425
# Prediction: Defective (Confidence: 0.02)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# Raw Prediction: 0.017671236768364906
# Prediction: Defective (Confidence: 0.02)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# Raw Prediction: 0.010149810463190079
# Prediction: Defective (Confidence: 0.01)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# Raw Prediction: 0.012059517204761505
# Prediction: Defective (Confidence: 0.01)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# Raw Prediction: 0.017056401818990707
# Prediction: Defective (Confidence: 0.02)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# Raw Prediction: 0