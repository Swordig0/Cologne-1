# %%
import cv2
import numpy as np
from tensorflow.keras.models import load_model
from tensorflow.keras.preprocessing.image import img_to_array

# %%
cam = 2
fps = 240

model_version = "my_model_18.0.keras"
Im_Width = 128
Im_Height = 128

# %%
def crop_image(frame, x, y, w, h):
    return frame[y:y+h, x:x+w]

# %%
def measure_brightness(frame):
    gray = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY) 
    brightness = np.mean(gray)
    return brightness

# %%
def measure_edge_richness(frame):
    gray = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)  # Convert to grayscale
    edges = cv2.Canny(gray, 200, 400)  # Apply Canny edge detection
    edge_richness = np.sum(edges)  # Sum of edge pixel intensities
    return edge_richness

# %%
def select_best_frame(frame_buffer):

    best_frame = None
    highest_brightness = 0
    #highest_edge_richness = 100000

    for frame in frame_buffer:

        #Crop
        cropped_frame = crop_image(frame, 220, 0, 200, 200)

        # Measure brightness
        brightness = measure_brightness(cropped_frame)

        if brightness > 150:
            # Update the best frame if this one is better
            if brightness > highest_brightness:
                highest_brightness = brightness
                best_frame = frame  # Save the frame as the best frame
        
        elif brightness > 25 and brightness < 90:
            # Update the best frame if this one is better
            if brightness > highest_brightness:
                highest_brightness = brightness
                best_frame = frame  # Save the frame as the best frame


    return best_frame  # Returns None if no frames meet the threshold

# %%
def process_frame(frame, target_size):

    # Resize the frame to the target size
    resized_frame = cv2.resize(frame, target_size)

    # Normalize pixel values to [0, 1]
    normalized_frame = resized_frame / 255.0

    # Convert to NumPy array and add batch dimension
    frame_array = img_to_array(normalized_frame)
    frame_array = np.expand_dims(frame_array, axis=0)  # Shape: (1, height, width, channels)

    return frame_array

# %%
def predict_frame(frame, model, target_size):

    # Preprocess the frame
    frame_array = process_frame(frame, target_size)

   # Make a prediction
    prediction = model.predict(frame_array)[0][0]  # Get the confidence score
    print(f"Raw Prediction: {prediction}")

    # Interpret the prediction
    if prediction > 0.5:
        #send_to_arduino(arduino, 1)
        return "Non-Defective", prediction       
        
    else:
        #send_to_arduino(arduino, 0)
        return "Defective", prediction

# %%
def capture(cam, model_path, target_size=(Im_Width, Im_Height)):

    cap = cv2.VideoCapture(cam)  # Open webcam
    frame_buffer = []
    max_frames = 20  # Number of frames to evaluate

    # Load the model
    print("Loading model...") 
    model = load_model(model_path)
    print("Model loaded successfully.")

    while True:

        ret, frame = cap.read()
        if not ret:
            print("Failed to capture frame. Exiting...")
            break

        frame_buffer.append(frame)

        # Process the buffer when it's full
        if len(frame_buffer) == max_frames:
            best_frame = select_best_frame(frame_buffer)
            frame_buffer = []  # Clear the buffer

            # Process and predict
            if best_frame is not None:
                feedback, confidence = predict_frame(best_frame, model, target_size)
                print(f"Prediction: {feedback} (Confidence: {confidence:.2f})")

                prob = abs(round(confidence,2)- 0.5)*200

                # Display feedback on the frame
                cv2.putText(best_frame, f"Prediction: {feedback}", (10, 30),
                        cv2.FONT_HERSHEY_SIMPLEX, 1, (0, 255, 0), 2)
                cv2.putText(best_frame, f"Confidence: {prob:.0f}", (10, 60),
                        cv2.FONT_HERSHEY_SIMPLEX, 1, (0, 255, 0), 2)

                # Display the best frame
                cv2.imshow("Best Frame", best_frame)

            else:
                # Load and display the "no-bottle" image in the same window
                image_path = "Image0001.jpg"
                image = cv2.imread(image_path)

                if image is None:
                    print("Error: Could not load 'no-bottle' image.")
                else:
                    cv2.putText(image, "No Bottle!", (10, 30),
                                cv2.FONT_HERSHEY_SIMPLEX, 1, (0, 255, 0), 2)
                    cv2.imshow("Best Frame", image)

        # Exit on 'ESC' key
        if cv2.waitKey(1) & 0xFF == 27:
            break

    cap.release()
    cv2.destroyAllWindows()

# %%
if __name__ == "__main__":
    model_path = model_version  # Path to your saved model
    capture(cam, model_path, target_size=(Im_Width, Im_Height))
# Out:
# Loading model...
# Model loaded successfully.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 831ms/step
# Raw Prediction: 0.5909385681152344
# Prediction: Non-Defective (Confidence: 0.59)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# Raw Prediction: 0.6638904809951782
# Prediction: Non-Defective (Confidence: 0.66)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# Raw Prediction: 0.5518721342086792
# Prediction: Non-Defective (Confidence: 0.55)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# Raw Prediction: 0.6157424449920654
# Prediction: Non-Defective (Confidence: 0.62)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# Raw Prediction: 0.6226192712783813
# Prediction: Non-Defective (Confidence: 0.62)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# Raw Prediction: 1.913395317387767e-05
# Prediction: Defective (Confidence: 0.00)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# Raw Prediction: 1.1321758393023629e-05
# Prediction: Defective (Confidence: 0.00)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# Raw Prediction: 0.0002248434175271541
# Prediction: Defective (Confidence: 0.00)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# Raw Prediction: 3.0561339372070506e-05
# Prediction: Defective (Confidence: 0.00)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# Raw Prediction: 0.08336801826953888
# Prediction: Defective (Confidence: 0.08)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# Raw Prediction: 0.00404388690367341
# Prediction: Defective (Confidence: 0.00)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# Raw Prediction: 0.43145716190338135
# Prediction: Defective (Confidence: 0.43)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# Raw Prediction: 0.0003674536128528416
# Prediction: Defective (Confidence: 0.00)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# Raw Prediction: 6.253078481677221e-06
# Prediction: Defective (Confidence: 0.00)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# Raw Prediction: 0.537696897983551
# Prediction: Non-Defective (Confidence: 0.54)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# Raw Prediction: 0.7016580700874329
# Prediction: Non-Defective (Confidence: 0.70)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# Raw Prediction: 0.6936988830566406
# Prediction: Non-Defective (Confidence: 0.69)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# Raw Prediction: 0.4403294622898102
# Prediction: Defective (Confidence: 0.44)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# Raw Prediction: 0.4619997441768646
# Prediction: Defective (Confidence: 0.46)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# Raw Prediction: 0.45016714930534363
# Prediction: Defective (Confidence: 0.45)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# Raw Prediction: 0.5456336736679077
# Prediction: Non-Defective (Confidence: 0.55)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# Raw Prediction: 0.6241331696510315
# Prediction: Non-Defective (Confidence: 0.62)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# Raw Prediction: 0.6013870239257812
# Prediction: Non-Defective (Confidence: 0.60)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# Raw Prediction: 0.4608828127384186
# Prediction: Defective (Confidence: 0.46)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# Raw Prediction: 0.6654990911483765
# Prediction: Non-Defective (Confidence: 0.67)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# Raw Prediction: 0.473248690366745
# Prediction: Defective (Confidence: 0.47)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# Raw Prediction: 0.4504909813404083
# Prediction: Defective (Confidence: 0.45)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# Raw Prediction: 0.615680456161499
# Prediction: Non-Defective (Confidence: 0.62)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# Raw Prediction: 0.6306712627410889
# Prediction: Non-Defective (Confidence: 0.63)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# Raw Prediction: 0.5928186178207397
# Prediction: Non-Defective (Confidence: 0.59)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# Raw Prediction: 0.6858144402503967
# Prediction: Non-Defective (Confidence: 0.69)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# Raw Prediction: 0.49329838156700134
# Prediction: Defective (Confidence: 0.49)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# Raw Prediction: 0.4435690939426422
# Prediction: Defective (Confidence: 0.44)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# Raw Prediction: 0.5306328535079956
# Prediction: Non-Defective (Confidence: 0.53)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step
# Raw Prediction: 0.019619133323431015
# Prediction: Defective (Confidence: 0.02)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# Raw Prediction: 0.6242839694023132
# Prediction: Non-Defective (Confidence: 0.62)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# Raw Prediction: 9.183030869053255e-08
# Prediction: Defective (Confidence: 0.00)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# Raw Prediction: 0.47936269640922546
# Prediction: Defective (Confidence: 0.48)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# Raw Prediction: 0.4088834226131439
# Prediction: Defective (Confidence: 0.41)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# Raw Prediction: 0.5758212804794312
# Prediction: Non-Defective (Confidence: 0.58)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# Raw Prediction: 0.6336913108825684
# Prediction: Non-Defective (Confidence: 0.63)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# Raw Prediction: 2.0829997083637863e-05
# Prediction: Defective (Confidence: 0.00)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# Raw Prediction: 0.6800864338874817
# Prediction: Non-Defective (Confidence: 0.68)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# Raw Prediction: 0.47366294264793396
# Prediction: Defective (Confidence: 0.47)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# Raw Prediction: 0.0009431347716599703
# Prediction: Defective (Confidence: 0.00)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# Raw Prediction: 4.2911352693408844e-07
# Prediction: Defective (Confidence: 0.00)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# Raw Prediction: 7.122393071767874e-06
# Prediction: Defective (Confidence: 0.00)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# Raw Prediction: 3.123885790046188e-06
# Prediction: Defective (Confidence: 0.00)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# Raw Prediction: 0.5686812400817871
# Prediction: Non-Defective (Confidence: 0.57)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# Raw Prediction: 1.2982601447220077e-06
# Prediction: Defective (Confidence: 0.00)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# Raw Prediction: 0.40962451696395874
# Prediction: Defective (Confidence: 0.41)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# Raw Prediction: 1.006499246614112e-06
# Prediction: Defective (Confidence: 0.00)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# Raw Prediction: 8.33179637993453e-06
# Prediction: Defective (Confidence: 0.00)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# Raw Prediction: 0.0020176912657916546
# Prediction: Defective (Confidence: 0.00)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# Raw Prediction: 9.785150041352608e-07
# Prediction: Defective (Confidence: 0.00)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# Raw Prediction: 0.005782672669738531
# Prediction: Defective (Confidence: 0.01)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# Raw Prediction: 0.00012854015221819282
# Prediction: Defective (Confidence: 0.00)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# Raw Prediction: 0.45139655470848083
# Prediction: Defective (Confidence: 0.45)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# Raw Prediction: 0.3068370819091797
# Prediction: Defective (Confidence: 0.31)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# Raw Prediction: 0.018037674948573112
# Prediction: Defective (Confidence: 0.02)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# Raw Prediction: 0.4842037260532379
# Prediction: Defective (Confidence: 0.48)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# Raw Prediction: 0.643247127532959
# Prediction: Non-Defective (Confidence: 0.64)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# Raw Prediction: 0.6313232183456421
# Prediction: Non-Defective (Confidence: 0.63)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# Raw Prediction: 0.4205201268196106
# Prediction: Defective (Confidence: 0.42)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# Raw Prediction: 0.6121585369110107
# Prediction: Non-Defective (Confidence: 0.61)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# Raw Prediction: 0.6399728655815125
# Prediction: Non-Defective (Confidence: 0.64)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# Raw Prediction: 0.44351136684417725
# Prediction: Defective (Confidence: 0.44)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# Raw Prediction: 0.6292613744735718
# Prediction: Non-Defective (Confidence: 0.63)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# Raw Prediction: 0.6313384771347046
# Prediction: Non-Defective (Confidence: 0.63)
