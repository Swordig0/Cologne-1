# %%
import cv2
import numpy as np
from tensorflow.keras.models import load_model
from tensorflow.keras.preprocessing.image import img_to_array

# %%
cam = 0
fps = 240

model_version = "my_model_14.0.keras"
Im_Width = 128
Im_Height = 128

# %%
def crop_image(frame, x, y, w, h):
    return frame[y:y+h, x:x+w]

# %%
def measure_brightness(frame):
    gray = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY) 
    brightness = np.mean(gray)
    return brightness

# %%
def measure_edge_richness(frame):
    gray = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)  # Convert to grayscale
    edges = cv2.Canny(gray, 200, 400)  # Apply Canny edge detection
    edge_richness = np.sum(edges)  # Sum of edge pixel intensities
    return edge_richness

# %%
def select_best_frame(frame_buffer):

    best_frame = None
    highest_brightness = 150
    highest_edge_richness = 100000

    for frame in frame_buffer:

        #Crop
        cropped_frame = crop_image(frame, 220, 0, 200, 200)

        # Measure brightness
        brightness = measure_brightness(cropped_frame)

        if brightness > 125:
            # Update the best frame if this one is better
            if brightness > highest_brightness:
                highest_brightness = brightness
                best_frame = frame  # Save the frame as the best frame
    
        elif brightness > 50 and brightness < 100:
            # Apply edge detection
            edge_richness = measure_edge_richness(cropped_frame)
            # Update the best frame if this one is better
            if edge_richness > highest_edge_richness:
                highest_edge_richness = edge_richness
                best_frame = frame  # Save the cropped frame as the best frame

    return best_frame  # Returns None if no frames meet the threshold

# %%
def process_frame(frame, target_size):

    # Resize the frame to the target size
    resized_frame = cv2.resize(frame, target_size)

    # Normalize pixel values to [0, 1]
    normalized_frame = resized_frame / 255.0

    # Convert to NumPy array and add batch dimension
    frame_array = img_to_array(normalized_frame)
    frame_array = np.expand_dims(frame_array, axis=0)  # Shape: (1, height, width, channels)

    return frame_array

# %%
def predict_frame(frame, model, target_size):

    # Preprocess the frame
    frame_array = process_frame(frame, target_size)

   # Make a prediction
    prediction = model.predict(frame_array)[0][0]  # Get the confidence score
    print(f"Raw Prediction: {prediction}")

    # Interpret the prediction
    if prediction > 0.5:
        return "Non-Defective", prediction
    else:
        return "Defective", prediction

# %%
def capture(cam, model_path, target_size=(Im_Width, Im_Height)):

    cap = cv2.VideoCapture(cam)  # Open webcam
    frame_buffer = []
    max_frames = 5  # Number of frames to evaluate

    # Load the model
    print("Loading model...") 
    model = load_model(model_path)
    print("Model loaded successfully.")

    while True:

        ret, frame = cap.read()
        if not ret:
            print("Failed to capture frame. Exiting...")
            break

        frame_buffer.append(frame)

        # Process the buffer when it's full
        if len(frame_buffer) == max_frames:
            best_frame = select_best_frame(frame_buffer)
            frame_buffer = []  # Clear the buffer

            # Process and predict
            if best_frame is not None:
                feedback, confidence = predict_frame(best_frame, model, target_size)
                print(f"Prediction: {feedback} (Confidence: {confidence:.2f})")

                cv2.putText(best_frame, f"Prediction: {feedback}", (10, 30),
                            cv2.FONT_HERSHEY_SIMPLEX, 1, (0, 255, 0), 2)
                cv2.putText(best_frame, f"Confidence: {confidence:.2f}", (10, 60),
                            cv2.FONT_HERSHEY_SIMPLEX, 1, (0, 255, 0), 2)

                # Display the best frame
                cv2.imshow("Best Frame", best_frame)

            else:
                # Load and display the "no-bottle" image in the same window
                image_path = "no-bottle.bmp"
                image = cv2.imread(image_path)

                if image is None:
                    print("Error: Could not load 'no-bottle' image.")
                else:
                    cv2.putText(image, "No Bottle!", (10, 30),
                                cv2.FONT_HERSHEY_SIMPLEX, 1, (0, 255, 0), 2)
                    cv2.imshow("Best Frame", image)

        # Exit on 'ESC' key
        if cv2.waitKey(1) & 0xFF == 27:
            break

    cap.release()
    cv2.destroyAllWindows()

# %%
if __name__ == "__main__":
    model_path = model_version  # Path to your saved model
    capture(cam, model_path, target_size=(Im_Width, Im_Height))
# Out:
# Loading model...
# Model loaded successfully.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 829ms/step
# Raw Prediction: 0.0046396213583648205
# Prediction: Defective (Confidence: 0.00)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# Raw Prediction: 0.012645121663808823
# Prediction: Defective (Confidence: 0.01)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# Raw Prediction: 0.004953987896442413
# Prediction: Defective (Confidence: 0.00)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# Raw Prediction: 0.004679356701672077
# Prediction: Defective (Confidence: 0.00)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# Raw Prediction: 0.006414749659597874
# Prediction: Defective (Confidence: 0.01)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# Raw Prediction: 0.007889972068369389
# Prediction: Defective (Confidence: 0.01)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# Raw Prediction: 0.014901204966008663
# Prediction: Defective (Confidence: 0.01)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# Raw Prediction: 0.01189353596419096
# Prediction: Defective (Confidence: 0.01)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# Raw Prediction: 0.01928853429853916
# Prediction: Defective (Confidence: 0.02)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# Raw Prediction: 0.0279395654797554
# Prediction: Defective (Confidence: 0.03)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# Raw Prediction: 0.031979262828826904
# Prediction: Defective (Confidence: 0.03)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# Raw Prediction: 0.013536565937101841
# Prediction: Defective (Confidence: 0.01)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# Raw Prediction: 0.008082421496510506
# Prediction: Defective (Confidence: 0.01)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# Raw Prediction: 0.00549278175458312
# Prediction: Defective (Confidence: 0.01)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# Raw Prediction: 0.006249305326491594
# Prediction: Defective (Confidence: 0.01)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# Raw Prediction: 0.0054914322681725025
# Prediction: Defective (Confidence: 0.01)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# Raw Prediction: 0.005522247403860092
# Prediction: Defective (Confidence: 0.01)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# Raw Prediction: 0.005557881202548742
# Prediction: Defective (Confidence: 0.01)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# Raw Prediction: 0.003683751914650202
# Prediction: Defective (Confidence: 0.00)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# Raw Prediction: 0.004149270709604025
# Prediction: Defective (Confidence: 0.00)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# Raw Prediction: 0.005601557437330484
# Prediction: Defective (Confidence: 0.01)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# Raw Prediction: 0.0069910455495119095
# Prediction: Defective (Confidence: 0.01)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# Raw Prediction: 0.010516684502363205
# Prediction: Defective (Confidence: 0.01)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# Raw Prediction: 0.0044425190426409245
# Prediction: Defective (Confidence: 0.00)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# Raw Prediction: 0.01022646389901638
# Prediction: Defective (Confidence: 0.01)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# Raw Prediction: 0.015915358439087868
# Prediction: Defective (Confidence: 0.02)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# Raw Prediction: 0.02286504954099655
# Prediction: Defective (Confidence: 0.02)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# Raw Prediction: 0.019843077287077904
# Prediction: Defective (Confidence: 0.02)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# Raw Prediction: 0.022201040759682655
# Prediction: Defective (Confidence: 0.02)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# Raw Prediction: 0.016673486679792404
# Prediction: Defective (Confidence: 0.02)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# Raw Prediction: 0.015231302939355373
# Prediction: Defective (Confidence: 0.02)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# Raw Prediction: 0.017949305474758148
# Prediction: Defective (Confidence: 0.02)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# Raw Prediction: 0.025419289246201515
# Prediction: Defective (Confidence: 0.03)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# Raw Prediction: 0.02188257873058319
# Prediction: Defective (Confidence: 0.02)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# Raw Prediction: 0.020764725282788277
# Prediction: Defective (Confidence: 0.02)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# Raw Prediction: 0.024020465090870857
# Prediction: Defective (Confidence: 0.02)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step
#