# %%
import os
import cv2
import numpy as np

# %%
def measure_brightness(frame):
    """
    Measures the brightness of an image by calculating the average pixel intensity.

    Args:
        frame (np.array): Input image in BGR format.

    Returns:
        float: Average brightness of the image.
    """
    gray = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)  # Convert to grayscale
    brightness = np.mean(gray)  # Compute the mean intensity
    return brightness

# %%
def crop_image(frame, x, y, w, h):
    """
    Crops a region of interest (ROI) from an image.

    Args:
        frame (np.array): Input image.
        x (int): X-coordinate of the top-left corner of the ROI.
        y (int): Y-coordinate of the top-left corner of the ROI.
        w (int): Width of the ROI.
        h (int): Height of the ROI.

    Returns:
        np.array: Cropped image.
    """
    return frame[y:y+h, x:x+w]

# %%
def process_brightness_batch(input_path, output_path):
    """
    Processes a batch of images, measures brightness, and saves results.

    Args:
        input_path (str): Path to the folder containing input images.
        output_path (str): Path to save results.
    """
    if not os.path.exists(output_path):
        os.makedirs(output_path)  # Create the output directory if it doesn't exist

    best_frame = None
    best_frame_name = None
    highest_brightness = -1  # Initialize with a very low value

    brightness_scores = []

    for filename in os.listdir(input_path):
        input_file = os.path.join(input_path, filename)

        # Ensure the file is an image
        if not filename.lower().endswith(('.jpg')):
            continue

        # Read the image
        frame = cv2.imread(input_file)
        if frame is None:
            print(f"Failed to read {input_file}. Skipping...")
            continue
        
        cropped = crop_image(frame, x, y, w, h)
        
        # Measure brightness
        brightness = measure_brightness(cropped)
        brightness_scores.append((filename, brightness))

        print(f"Processed {filename}: Brightness = {brightness:.2f}")

        # Save brightness scores to a text file
        scores_file = os.path.join(output_path, "brightness_scores.txt")
        with open(scores_file, "a") as f:
            f.write(f"{brightness:.2f}\n")

        # Update the best frame if this one is better
        if brightness > highest_brightness:
            highest_brightness = brightness
            best_frame = frame  # Save the cropped frame as the best frame
            best_frame_name = filename
    
    # Save the best frame separately
    if best_frame is not None:
        best_frame_file = os.path.join(best_frame_path, f"best_frame_{best_frame_name}")
        cv2.imwrite(best_frame_file, best_frame)
        print(f"Best frame saved as: {best_frame_file} with Brightness = {highest_brightness}")


# Example usage
input_path = "Brightness/Samples/08"   # Replace with your input images path
output_path = "Brightness/Results/C/08"  # Replace with your results path
best_frame_path = "Brightness/Results/C/08/Best"    # Replace with the path to save the best frame
x, y, w, h = 120, 0, 400, 250  # Example crop rectangle (top-left at (100, 50), 200x200 size)
process_brightness_batch(input_path, output_path)
# Out:
# Processed Image4385.jpg: Brightness = 79.65
# Processed Image4386.jpg: Brightness = 85.68
# Processed Image4387.jpg: Brightness = 92.93
# Processed Image4388.jpg: Brightness = 98.37
# Processed Image4389.jpg: Brightness = 105.22
# Processed Image4390.jpg: Brightness = 98.51
# Processed Image4391.jpg: Brightness = 111.04
# Processed Image4392.jpg: Brightness = 117.09
# Processed Image4393.jpg: Brightness = 124.15
# Processed Image4394.jpg: Brightness = 130.29
# Processed Image4395.jpg: Brightness = 137.07
# Processed Image4396.jpg: Brightness = 143.32
# Processed Image4397.jpg: Brightness = 141.49
# Processed Image4398.jpg: Brightness = 147.93
# Processed Image4399.jpg: Brightness = 153.67
# Processed Image4400.jpg: Brightness = 159.92
# Processed Image4401.jpg: Brightness = 161.28
# Processed Image4402.jpg: Brightness = 167.49
# Processed Image4403.jpg: Brightness = 173.36
# Processed Image4404.jpg: Brightness = 178.88
# Processed Image4405.jpg: Brightness = 177.33
# Processed Image4406.jpg: Brightness = 183.37
# Processed Image4407.jpg: Brightness = 190.36
# Processed Image4408.jpg: Brightness = 197.09
# Processed Image4409.jpg: Brightness = 197.95
# Processed Image4410.jpg: Brightness = 205.00
# Processed Image4411.jpg: Brightness = 211.59
# Processed Image4412.jpg: Brightness = 218.48
# Processed Image4413.jpg: Brightness = 217.18
# Processed Image4414.jpg: Brightness = 222.80
# Processed Image4415.jpg: Brightness = 227.88
# Processed Image4416.jpg: Brightness = 232.40
# Processed Image4417.jpg: Brightness = 212.28
# Processed Image4418.jpg: Brightness = 212.96
# Processed Image4419.jpg: Brightness = 213.81
# Processed Image4420.jpg: Brightness = 212.85
# Processed Image4421.jpg: Brightness = 210.44
# Processed Image4422.jpg: Brightness = 206.27
# Processed Image4423.jpg: Brightness = 200.85
# Processed Image4424.jpg: Brightness = 196.12
# Processed Image4425.jpg: Brightness = 190.51
# Processed Image4426.jpg: Brightness = 185.32
# Processed Image4427.jpg: Brightness = 179.88
# Processed Image4428.jpg: Brightness = 174.19
# Processed Image4429.jpg: Brightness = 168.08
# Processed Image4430.jpg: Brightness = 161.08
# Processed Image4431.jpg: Brightness = 153.99
# Processed Image4432.jpg: Brightness = 146.62
# Processed Image4433.jpg: Brightness = 139.64
# Processed Image4434.jpg: Brightness = 132.56
# Processed Image4435.jpg: Brightness = 125.37
# Processed Image4436.jpg: Brightness = 118.29
# Processed Image4437.jpg: Brightness = 122.48
# Processed Image4438.jpg: Brightness = 115.29
# Processed Image4439.jpg: Brightness = 107.82
# Processed Image4440.jpg: Brightness = 100.00
# Processed Image4441.jpg: Brightness = 94.91
# Processed Image4442.jpg: Brightness = 87.69
# Processed Image4443.jpg: Brightness = 81.06
# Processed Image4444.jpg: Brightness = 74.18
# Processed Image4445.jpg: Brightness = 71.50
# Processed Image4446.jpg: Brightness = 64.73
# Processed Image4447.jpg: Brightness = 58.39
# Processed Image4448.jpg: Brightness = 52.44
# Processed Image4449.jpg: Brightness = 50.63
# Processed Image4450.jpg: Brightness = 45.10
# Processed Image4451.jpg: Brightness = 39.85
# Processed Image4452.jpg: Brightness = 35.62
# Processed Image4453.jpg: Brightness = 35.60
# Processed Image4454.jpg: Brightness = 31.95
# Processed Image4455.jpg: Brightness = 30.86
# Processed Image4456.jpg: Brightness = 30.13
# Processed Image4900.jpg: Brightness = 56.06
# Processed Image4901.jpg: Brightness = 55.45
# Processed Image4902.jpg: Brightness = 55.64
# Processed Image4903.jpg: Brightness = 56.01
# Processed Image4904.jpg: Brightness = 55.25
# Processed Image4905.jpg: Brightness = 55.93
# Processed Image4906.jpg: Brightness = 54.81
# Processed Image4907.jpg: Brightness = 55.27
# Best frame saved as: Brightness/Results/C/08/Best\best_frame_Image4416.jpg with Brightness = 232.40346
