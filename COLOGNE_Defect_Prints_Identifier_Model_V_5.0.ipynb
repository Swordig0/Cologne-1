# %%
import cv2
import numpy as np
from tensorflow.keras.models import load_model
from tensorflow.keras.preprocessing.image import img_to_array

def process_frame(frame, target_size):
    """
    Processes a webcam frame for model prediction.
    
    Args:
        frame (np.array): Captured frame from the webcam.
        target_size (tuple): Target size for resizing the frame (width, height).

    Returns:
        np.array: Preprocessed image ready for model prediction.
    """
    # Resize the frame to the target size
    resized_frame = cv2.resize(frame, target_size)

    # Normalize pixel values to [0, 1]
    normalized_frame = resized_frame / 255.0

    # Convert to NumPy array and add batch dimension
    frame_array = img_to_array(normalized_frame)
    frame_array = np.expand_dims(frame_array, axis=0)  # Shape: (1, height, width, channels)

    return frame_array

def predict_frame(frame, model, target_size):
    """
    Predicts the class of a single frame using the model.

    Args:
        frame (np.array): Captured frame from the webcam.
        model: Loaded Keras model.
        target_size (tuple): Target size for resizing the frame.

    Returns:
        str: Predicted class label.
        float: Confidence score.
    """
    # Preprocess the frame
    frame_array = process_frame(frame, target_size)

    # Make a prediction
    prediction = model.predict(frame_array)[0][0]  # Get the confidence score
    print(f"Raw Prediction: {prediction}")

    # Interpret the prediction
    if prediction > 0.5:
        return "Non-Defective", prediction
    else:
        return "Defective", prediction

def run_webcam_with_model(model_path, target_size=(128, 128)):
    """
    Opens the webcam, captures frames, and processes them using the model.

    Args:
        model_path (str): Path to the saved Keras model.
        target_size (tuple): Target size for resizing frames (width, height).
    """
    # Load the model
    print("Loading model...")
    model = load_model(model_path)
    print("Model loaded successfully.")

    # Open the webcam
    cap = cv2.VideoCapture(2)
    if not cap.isOpened():
        raise IOError("Cannot open the webcam")

    print("Webcam opened. Press 'ESC' to exit.")
    try:
        while True:
            # Capture frame from the webcam
            ret, frame = cap.read()
            if not ret:
                print("Failed to capture frame. Exiting...")
                break

            # Process and predict
            feedback, confidence = predict_frame(frame, model, target_size)
            print(f"Prediction: {feedback} (Confidence: {confidence:.2f})")

            # Display feedback on the frame
            cv2.putText(frame, f"Prediction: {feedback}", (10, 30),
                        cv2.FONT_HERSHEY_SIMPLEX, 1, (0, 255, 0), 2)
            cv2.putText(frame, f"Confidence: {confidence:.2f}", (10, 60),
                        cv2.FONT_HERSHEY_SIMPLEX, 1, (0, 255, 0), 2)

            # Show the frame in a window
            cv2.imshow("Webcam Feed", frame)

            # Exit on 'ESC' key
            if cv2.waitKey(1) & 0xFF == 27:  # 27 is the ASCII code for ESC
                print("Exiting...")
                break

    finally:
        # Release resources
        cap.release()
        cv2.destroyAllWindows()

# Run the script
if __name__ == "__main__":
    model_path = "my_model_4.0.h5"  # Path to your saved model
    run_webcam_with_model(model_path, target_size=(128, 128))
# Out:
# Loading model...
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Model loaded successfully.
# Webcam opened. Press 'ESC' to exit.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# Raw Prediction: 0.5592830181121826
# Prediction: Non-Defective (Confidence: 0.56)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step
# Raw Prediction: 0.5799026489257812
# Prediction: Non-Defective (Confidence: 0.58)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step
# Raw Prediction: 0.5878680944442749
# Prediction: Non-Defective (Confidence: 0.59)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step
# Raw Prediction: 0.6227930188179016
# Prediction: Non-Defective (Confidence: 0.62)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step
# Raw Prediction: 0.5878754258155823
# Prediction: Non-Defective (Confidence: 0.59)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step
# Raw Prediction: 0.5919308662414551
# Prediction: Non-Defective (Confidence: 0.59)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step
# Raw Prediction: 0.6060628890991211
# Prediction: Non-Defective (Confidence: 0.61)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step
# Raw Prediction: 0.5670977830886841
# Prediction: Non-Defective (Confidence: 0.57)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step
# Raw Prediction: 0.5034387111663818
# Prediction: Non-Defective (Confidence: 0.50)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step
# Raw Prediction: 0.5805941820144653
# Prediction: Non-Defective (Confidence: 0.58)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step
# Raw Prediction: 0.6242862939834595
# Prediction: Non-Defective (Confidence: 0.62)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step
# Raw Prediction: 0.5866436958312988
# Prediction: Non-Defective (Confidence: 0.59)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step
# Raw Prediction: 0.6136856079101562
# Prediction: Non-Defective (Confidence: 0.61)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step
# Raw Prediction: 0.5743908286094666
# Prediction: Non-Defective (Confidence: 0.57)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step
# Raw Prediction: 0.5568588972091675
# Prediction: Non-Defective (Confidence: 0.56)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step
# Raw Prediction: 0.5581799745559692
# Prediction: Non-Defective (Confidence: 0.56)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step
# Raw Prediction: 0.5625536441802979
# Prediction: Non-Defective (Confidence: 0.56)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step
# Raw Prediction: 0.6174914836883545
# Prediction: Non-Defective (Confidence: 0.62)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step
# Raw Prediction: 0.5693533420562744
# Prediction: Non-Defective (Confidence: 0.57)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step
# Raw Prediction: 0.5833386778831482
# Prediction: Non-Defective (Confidence: 0.58)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step
# Raw Prediction: 0.5998469591140747
# Prediction: Non-Defective (Confidence: 0.60)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step
# Raw Prediction: 0.5815273523330688
# Prediction: Non-Defective (Confidence: 0.58)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step
# Raw Prediction: 0.5544796586036682
# Prediction: Non-Defective (Confidence: 0.55)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step
# Raw Prediction: 0.5292518734931946
# Prediction: Non-Defective (Confidence: 0.53)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step
# Raw Prediction: 0.5868701934814453
# Prediction: Non-Defective (Confidence: 0.59)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step
# Raw Prediction: 0.5230826735496521
# Prediction: Non-Defective (Confidence: 0.52)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step
# Raw Prediction: 0.5886387825012207
# Prediction: Non-Defective (Confidence: 0.59)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step
# Raw Prediction: 0.5665899515151978
# Prediction: Non-Defective (Confidence: 0.57)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step
# Raw Prediction: 0.590444803237915
# Prediction: Non-Defective (Confidence: 0.59)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step
# Raw Prediction: 0.5575602650642395
# Prediction: Non-Defective (Confidence: 0.56)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step
# Raw Prediction: 0.5712958574295044
# Prediction: Non-Defective (Confidence: 0.57)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step
# Raw Prediction: 0.5964767932891846
# Prediction: Non-Defective (Confidence: 0.60)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step
# Raw Prediction: 0.5279918909072876
# Prediction: Non-Defective (Confidence: 0.53)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step
# Raw Prediction: 0.580237627029419
# Prediction: Non-Defective (Confidence: 0.58)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step
# Raw Prediction: 0.5639840364456177
# Prediction: Non-Defective (Confidence: 0.56)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step
# Raw Prediction: 0.5701810121536255
# Prediction: Non-Defective (Confidence: 0.57)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step
# Raw Prediction: 0.5698093175888062
# Prediction: Non-Defective (Confidence: 0.57)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step
# Raw Prediction: 0.5651794672012329
# Prediction: Non-Defective (Confidence: 0.57)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step
# Raw Prediction: 0.5424926280975342
# Prediction: Non-Defective (Confidence: 0.54)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step
# Raw Prediction: 0.5645998120307922
# Prediction: Non-Defective (Confidence: 0.56)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step
# Raw Prediction: 0.5913186073303223
# Prediction: Non-Defective (Confidence: 0.59)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step
# Raw Prediction: 0.5439335107803345
# Prediction: Non-Defective (Confidence: 0.54)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step
# Raw Prediction: 0.5930787324905396
# Prediction: Non-Defective (Confidence: 0.59)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step
# Raw Prediction: 0.579135537147522
# Prediction: Non-Defective (Confidence: 0.58)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step
# Raw Prediction: 0.5042167901992798
# Prediction: Non-Defective (Confidence: 0.50)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step
# Raw Prediction: 0.5803654789924622
# Prediction: Non-Defective (Confidence: 0.58)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step
# Raw Prediction: 0.5604515075683594
# Prediction: Non-Defective (Confidence: 0.56)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step
# Raw Prediction: 0.5215264558792114
# Prediction: Non-Defective (Confidence: 0.52)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step
# Raw Prediction: 0.4678404629230499
# Prediction: Defective (Confidence: 0.47)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step
# Raw Prediction: 0.5299842357635498
# Prediction: Non-Defective (Confidence: 0.53)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step
# Raw Prediction: 0.5699599981307983
# Prediction: Non-Defective (Confidence: 0.57)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step
# Raw Prediction: 0.5541002750396729
# Prediction: Non-Defective (Confidence: 0.55)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step
# Raw Prediction: 0.48848918080329895
# Prediction: Defective (Confidence: 0.49)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step
# Raw Prediction: 0.6131346225738525
# Prediction: Non-Defective (Confidence: 0.61)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step
# Raw Prediction: 0.5801877975463867
# Prediction: Non-Defective (Confidence: 0.58)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step
# Raw Prediction: 0.7364864945411682
# Prediction: Non-Defective (Confidence: 0.74)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step
# Raw Prediction: 0.5419722199440002
# Prediction: Non-Defective (Confidence: 0.54)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step
# Raw Prediction: 0.5454539656639099
# Prediction: Non-Defective (Confidence: 0.55)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step
# Raw Prediction: 0.5868287086486816
# Prediction: Non-Defective (Confidence: 0.59)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step
# Raw Prediction: 0.574173092842102
# Prediction: Non-Defective (Confidence: 0.57)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step
# Raw Prediction: 0.5439121723175049
# Prediction: Non-Defective (Confidence: 0.54)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step
# Raw Prediction: 0.5805569887161255
# Prediction: Non-Defective (Confidence: 0.58)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step
# Raw Prediction: 0.5645211935043335
# Prediction: Non-Defective (Confidence: 0.56)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step
# Raw Prediction: 0.5693092346191406
# Prediction: Non-Defective (Confidence: 0.57)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step
# Raw Prediction: 0.5817815065383911
# Prediction: Non-Defective (Confidence: 0.58)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step
# Raw Prediction: 0.593518853187561
# Prediction: Non-Defective (Confidence: 0.59)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step
# Raw Prediction: 0.5755820274353027
# Prediction: Non-Defective (Confidence: 0.58)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step
# Raw Prediction: 0.5817446708679199
# Prediction: Non-Defective (Confidence: 0.58)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 95ms/step
# Raw Prediction: 0.5994617342948914
# Prediction: Non-Defective (Confidence: 0.60)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step
# Raw Prediction: 0.5495527982711792
# Prediction: Non-Defective (Confidence: 0.55)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step
# Raw Prediction: 0.5805290341377258
# Prediction: Non-Defective (Confidence: 0.58)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step
# Raw Prediction: 0.5273118019104004
# Prediction: Non-Defective (Confidence: 0.53)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step
# Raw Prediction: 0.5684856176376343
# Prediction: Non-Defective (Confidence: 0.57)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step
# Raw Prediction: 0.5449473857879639
# Prediction: Non-Defective (Confidence: 0.54)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step
# Raw Prediction: 0.6050046682357788
# Prediction: Non-Defective (Confidence: 0.61)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step
# Raw Prediction: 0.5877426862716675
# Prediction: Non-Defective (Confidence: 0.59)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step
# Raw Prediction: 0.5631107687950134
# Prediction: Non-Defective (Confidence: 0.56)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step
# Raw Prediction: 0.5572606325149536
# Prediction: Non-Defective (Confidence: 0.56)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step
# Raw Prediction: 0.554452657699585
# Prediction: Non-Defective (Confidence: 0.55)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step
# Raw Prediction: 0.5398669242858887
# Prediction: Non-Defective (Confidence: 0.54)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step
# Raw Prediction: 0.5585055947303772
# Prediction: Non-Defective (Confidence: 0.56)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step
# Raw Prediction: 0.5363254547119141
# Prediction: Non-Defective (Confidence: 0.54)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step
# Raw Prediction: 0.537328839302063
# Prediction: Non-Defective (Confidence: 0.54)
# Exiting...
