# %%
import cv2
import numpy as np
from tensorflow.keras.models import load_model
from tensorflow.keras.preprocessing.image import img_to_array

cam = 0

def process_frame(frame, target_size):
    """
    Processes a webcam frame for model prediction.
    
    Args:
        frame (np.array): Captured frame from the webcam.
        target_size (tuple): Target size for resizing the frame (width, height).

    Returns:
        np.array: Preprocessed image ready for model prediction.
    """
    # Resize the frame to the target size
    resized_frame = cv2.resize(frame, target_size)

    # Normalize pixel values to [0, 1]
    normalized_frame = resized_frame / 255.0

    # Convert to NumPy array and add batch dimension
    frame_array = img_to_array(normalized_frame)
    frame_array = np.expand_dims(frame_array, axis=0)  # Shape: (1, height, width, channels)

    return frame_array

def predict_frame(frame, model, target_size):
    """
    Predicts the class of a single frame using the model.

    Args:
        frame (np.array): Captured frame from the webcam.
        model: Loaded Keras model.
        target_size (tuple): Target size for resizing the frame.

    Returns:
        str: Predicted class label.
        float: Confidence score.
    """
    # Preprocess the frame
    frame_array = process_frame(frame, target_size)

    # Make a prediction
    prediction = model.predict(frame_array)[0][0]  # Get the confidence score
    print(f"Raw Prediction: {prediction}")

    # Interpret the prediction
    if prediction > 0.5:
        return "Non-Defective", prediction
    else:
        return "Defective", prediction

def run_webcam_with_model(model_path, target_size=(480, 640)):
    """
    Opens the webcam, captures frames, and processes them using the model.

    Args:
        model_path (str): Path to the saved Keras model.
        target_size (tuple): Target size for resizing frames (width, height).
    """
    # Load the model
    print("Loading model...")
    model = load_model(model_path)
    print("Model loaded successfully.")

    # Open the webcam
    cap = cv2.VideoCapture(cam)
    if not cap.isOpened():
        raise IOError("Cannot open the webcam")

    print("Webcam opened. Press 'ESC' to exit.")
    try:
        while True:
            # Capture frame from the webcam
            ret, frame = cap.read()
            if not ret:
                print("Failed to capture frame. Exiting...")
                break

            # Process and predict
            feedback, confidence = predict_frame(frame, model, target_size)
            print(f"Prediction: {feedback} (Confidence: {confidence:.2f})")

            prob = abs(round(confidence,2)- 0.5)*200

            # Display feedback on the frame
            cv2.putText(frame, f"Prediction: {feedback}", (10, 30),
                        cv2.FONT_HERSHEY_SIMPLEX, 1, (0, 255, 0), 2)
            cv2.putText(frame, f"Confidence: {prob:.0f}", (10, 60),
                        cv2.FONT_HERSHEY_SIMPLEX, 1, (0, 255, 0), 2)

            # Show the frame in a window
            cv2.imshow("Webcam Feed", frame)

            # Exit on 'ESC' key
            if cv2.waitKey(1) & 0xFF == 27:  # 27 is the ASCII code for ESC
                print("Exiting...")
                break

    finally:
        # Release resources
        cap.release()
        cv2.destroyAllWindows()

# Run the script
if __name__ == "__main__":
    model_path = "my_model_9.0.keras"  # Path to your saved model
    run_webcam_with_model(model_path, target_size=(480, 640))
# Out:
# Loading model...
# Model loaded successfully.
# Webcam opened. Press 'ESC' to exit.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# Raw Prediction: 0.007799210958182812
# Prediction: Defective (Confidence: 0.01)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 410ms/step
# Raw Prediction: 0.0048645129427313805
# Prediction: Defective (Confidence: 0.00)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 465ms/step
# Raw Prediction: 0.006688245572149754
# Prediction: Defective (Confidence: 0.01)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 667ms/step
# Raw Prediction: 0.0027333861216902733
# Prediction: Defective (Confidence: 0.00)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 418ms/step
# Raw Prediction: 0.0036284644156694412
# Prediction: Defective (Confidence: 0.00)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 429ms/step
# Raw Prediction: 0.002692708047106862
# Prediction: Defective (Confidence: 0.00)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 499ms/step
# Raw Prediction: 0.003024934558197856
# Prediction: Defective (Confidence: 0.00)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 701ms/step
# Raw Prediction: 0.004131124820560217
# Prediction: Defective (Confidence: 0.00)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 437ms/step
# Raw Prediction: 0.003258319804444909
# Prediction: Defective (Confidence: 0.00)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 681ms/step
# Raw Prediction: 0.0027995705604553223
# Prediction: Defective (Confidence: 0.00)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 648ms/step
# Raw Prediction: 0.002494530752301216
# Prediction: Defective (Confidence: 0.00)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 664ms/step
# Raw Prediction: 0.0021537169814109802
# Prediction: Defective (Confidence: 0.00)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 440ms/step
# Raw Prediction: 0.003963566850870848
# Prediction: Defective (Confidence: 0.00)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 443ms/step
# Raw Prediction: 0.002495087217539549
# Prediction: Defective (Confidence: 0.00)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 598ms/step
# Raw Prediction: 0.003004614729434252
# Prediction: Defective (Confidence: 0.00)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 675ms/step
# Raw Prediction: 0.001953003229573369
# Prediction: Defective (Confidence: 0.00)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 448ms/step
# Raw Prediction: 0.0023439896758645773
# Prediction: Defective (Confidence: 0.00)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 553ms/step
# Raw Prediction: 0.0032136801164597273
# Prediction: Defective (Confidence: 0.00)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 441ms/step
# Raw Prediction: 0.001675968524068594
# Prediction: Defective (Confidence: 0.00)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 607ms/step
# Raw Prediction: 0.0020348045509308577
# Prediction: Defective (Confidence: 0.00)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 484ms/step
# Raw Prediction: 0.001951431157067418
# Prediction: Defective (Confidence: 0.00)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 536ms/step
# Raw Prediction: 0.0016682903515174985
# Prediction: Defective (Confidence: 0.00)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 460ms/step
# Raw Prediction: 0.003728176699951291
# Prediction: Defective (Confidence: 0.00)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 445ms/step
# Raw Prediction: 0.004495325032621622
# Prediction: Defective (Confidence: 0.00)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 742ms/step
# Raw Prediction: 0.00543996412307024
# Prediction: Defective (Confidence: 0.01)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 436ms/step
# Raw Prediction: 0.0020494440104812384
# Prediction: Defective (Confidence: 0.00)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 513ms/step
# Raw Prediction: 0.0026048575527966022
# Prediction: Defective (Confidence: 0.00)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 540ms/step
# Raw Prediction: 0.0024256121832877398
# Prediction: Defective (Confidence: 0.00)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 427ms/step
# Raw Prediction: 0.0027560030575841665
# Prediction: Defective (Confidence: 0.00)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 562ms/step
# Raw Prediction: 0.001951970043592155
# Prediction: Defective (Confidence: 0.00)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 565ms/step
# Raw Prediction: 0.003826010273769498
# Prediction: Defective (Confidence: 0.00)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 629ms/step
# Raw Prediction: 0.002309598261490464
# Prediction: Defective (Confidence: 0.00)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 661ms/step
# Raw Prediction: 0.00264141708612442
# Prediction: Defective (Confidence: 0.00)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 687ms/step
# Raw Prediction: 0.0033135355915874243
# Prediction: Defective (Confidence: 0.00)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 461ms/step
# Raw Prediction: 0.00196093344129622
# Prediction: Defective (Confidence: 0.00)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 549ms/step
# Raw Prediction: 0.00260729412548244
# Prediction: Defective (Confidence: 0.00)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 436ms/step
# Raw Prediction: 0.0020505746360868216
# Prediction: Defective (Confidence: 0.00)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 490ms/step
# Raw Prediction: 0.002730131847783923
# Prediction: Defective (Confidence: 0.00)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 433ms/step
# Raw Prediction: 0.0018551084212958813
# Prediction: Defective (Confidence: 0.00)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 665ms/step
# Raw Prediction: 0.0021028295159339905
# Prediction: Defective (Confidence: 0.00)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 555ms/step
# Raw Prediction: 0.002315994119271636
# Prediction: Defective (Confidence: 0.00)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 453ms/step
# Raw Prediction: 0.0019161379896104336
# Prediction: Defective (Confidence: 0.00)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 430ms/step
# Raw Prediction: 0.0020716870203614235
# Prediction: Defective (Confidence: 0.00)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 690ms/step
# Raw Prediction: 0.0017300976905971766
# Prediction: Defective (Confidence: 0.00)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 587ms/step
