# %%
import cv2
import os
import threading
#import time
import numpy as np

# %%
def save_frames_as_images():
    """Capture frames from the camera and save them as images in a folder."""
    output_dir = "frames"
    os.makedirs(output_dir, exist_ok=True)

    cap = cv2.VideoCapture(0)  # Use 0 for the default camera
    if not cap.isOpened():
        print("Error: Could not open the camera.")
        return

    frame_count = 0
    print("Press 'q' to stop capturing frames.")

    while True:
        ret, frame = cap.read()
        if not ret:
            print("Error: Frame capture failed.")
            break

        # Save the current frame as an image
        frame_filename = os.path.join(output_dir, f"frame_{frame_count:04d}.jpg")
        cv2.imwrite(frame_filename, frame)
        print(f"Saved: {frame_filename}")
        frame_count += 1

        # Display the frame
        cv2.imshow("Live Stream - Capturing Frames", frame)

        # Break on 'q' key press
        if cv2.waitKey(1) & 0xFF == ord('q'):
            break

    cap.release()
    cv2.destroyAllWindows()
    print(f"Captured {frame_count} frames, saved in '{output_dir}'.")



def playBack():
    path = "02.mp4"
    cap = cv2.VideoCapture(path)
    try:
        while True:
        # Capture frame
            success, img = cap.read()
            if not success:
                print("Failed to capture frame")
                break

            cv2.imshow("Image", img)

             # Check for Escape key press
            if cv2.waitKey(1) & 0xFF == 27:  # '27' is the ASCII code for the Escape key
                print("Exiting...")
                break

    finally:
        # Release resources
        cap.release()
        cv2.destroyAllWindows()

def count():
    count = 0
    while True:   
        count += 1
        print("Count", count)
        print("\n")
        if cv2.waitKey(1) & 0xFF == 27:  # '27' is the ASCII code for the Escape key
                print("Exiting...")
                break

if __name__ == "__main__":
    # Directory to monitor for edge richness calculation
    frame_folder = "frames"

    # Create threads for frame capture and edge richness calculation
    capture_thread = threading.Thread(target=save_frames_as_images)
    #edge_thread = threading.Thread(target=playBack)
    count_thread = threading.Thread(target=count)

    # Start the threads
    capture_thread.start()
    #edge_thread.start()
    count_thread.start()

    # Wait for threads to complete
    capture_thread.join()
    #edge_thread.join()
    count_thread.join()
# Out:
# Count 1
#
#
# Count 2
#
#
# Count 3
#
#
# Count 4
#
#
# Count 5
#
#
# Count 6
#
#
# Count 7
#
#
# Count 8
#
#
# Count 9
#
#
# Count 10
#
#
# Count 11
#
#
# Count 12
#
#
# Count 13
#
#
# Count 14
#
#
# Count 15
#
#
# Count 16
#
#
# Count 17
#
#
# Count 18
#
#
# Count 19
#
#
# Count 20
#
#
# Count 21
#
#
# Count 22
#
#
# Count 23
#
#
# Count 24
#
#
# Count 25
#
#
# Count 26
#
#
# Count 27
#
#
# Count 28
#
#
# Count 29
#
#
# Count 30
#
#
# Count 31
#
#
# Count 32
#
#
# Count 33
#
#
# Count 34
#
#
# Count 35
#
#
# Count 36
#
#
# Count 37
#
#
# Count 38
#
#
# Count 39
#
#
# Count 40
#
#
# Count 41
#
#
# Count 42
#
#
# Count 43
#
#
# Count 44
#
#
# Count 45
#
#
# Count 46
#
#
# Count 47
#
#
# Count 48
#
#
# Count 49
#
#
# Count 50
#
#
# Count 51
#
#
# Count 52
#
#
# Count 53
#
#
# Count 54
#
#
# Count 55
#
#
# Count 56
#
#
# Count 57
#
#
# Count 58
#
#
# Count 59
#
#
# Count 60
#
#
# Count 61
#
#
# Count 62
#
#
# Count 63
#
#
# Count 64
#
#
# Count 65
#
#
# Count 66
#
#
# Count 67
#
#
# Count 68
#
#
# Count 69
#
#
# Count 70
#
#
# Count 71
#
#
# Count 72
#
#
# Count 73
#
#
# Count 74
#
#
# Count 75
#
#
# Count 76
#
#
# Count 77
#
#
# Count 78
#
#
# Count 79
#
#
# Count 80
#
#
# Count 81
#
#
# Count 82
#
#
# Count 83
#
#
# Count 84
#
#
# Count 85
#
#
# Count 86
#
#
# Count 87
#
#
# Count 88
#
#
# Count 89
#
#
# Count 90
#
#
# Count 91
#
#
# Count 92
#
#
# Count 93
#
#
# Count 94
#
#
# Count 95
#
#
# Count 96
#
#
# Count 97
#
#
# Count 98
#
#
# Count 99
#
#
# Count 100
#
#
# Count 101
#
#
# Count 102
#
#
# Count 103
#
#
# Count 104
#
#
# Count 105
#
#
# Count 106
#
#
# Count 107
#
#
# Count 108
#
#
# Count 109
#
#
# Count 110
#
#
# Count 111
#
#
# Count 112
#
#
# Count 113
#
#
# Count 114
#
#
# Count 115
#
#
# Count 116
#
#
# Count 117
#
#
# Count 118
#
#
# Count 119
#
#
# Count 120
#
#
# Count 121
#
#
# Count 122
#
#
# Count 123
#
#
# Count 124
#
#
# Count 125
#
#
# Count 126
#
#
# Count 127
#
#
# Count 128
#
#
# Count 129
#
#
# Count 130
#
#
# Count 131
#
#
# Count 132
#
#
# Count 133
#
#
# Count 134
#
#
# Count 135
#
#
# Count 136
#
#
# Count 137
#
#
# Count 138
#
#
# Count 139
#
#
# Count 140
#
#
# Count 141
#
#
# Count 142
#
#
# Count 143
#
#
# Count 144
#
#
# Count 145
#
#
# Count 146
#
#
# Count 147
#
#
# Count 148
#
#
# Count 149
#
#
# Count 150
#
#
# Count 151
#
#
# Count 152
#
#
# Count 153
#
#
# Count 154
#
#
# Count 155
#
#
# Count 156
#
#
# Count 157
#
#
# Count 158
#
#
# Count 159
#
#
# Count 160
#
#
# Count 161
#
#
# Count 162
#
#
# Count 163
#
#
# Count 164
#
#
# Count 165
#
#
# Count 166
#
#
# Count 167
#
#
# Count 168
#
#
# Count 169
#
#
# Count 170
#
#
# Count 171
#
#
# Count 172
#
#
# Count 173
#
#
# Count 174
#
#
# Count 175
#
#
# Count 176
#
#
# Count 177
#
#
# Count 178
#
#
# Count 179
#
#
# Count 180
#
#
# Count 181
#
#
# Count 182
#
#
# Count 183
#
#
# Count 184
#
#
# Count 185
#
#
# Count 186
#
#
# Count 187
#
#
# Count 188
#
#
# Count 189
#
#
# Count 190
#
#
# Count 191
#
#
# Count 192
#
#
# Count 193
#
#
# Count 194
#
#
# Count 195
#
#
# Count 196
#
#
# Count 197
#
#
# Count 198
#
#
# Count 199
#
#
# Count 200
#
#
# Count 201
#
#
# Count 202
#
#
# Count 203
#
#
# Count 204
#
#
# Count 205
#
#
# Count 206
#
#
# Count 207
#
#
# Count 208
#
#
# Count 209
#
#
# Count 210
#
#
# Count 211
#
#
# Count 212
#
#
# Count 213
#
#
# Count 214
#
#
# Count 215
#
#
# Count 216
#
#
# Count 217
#
#
# Count 218
#
#
# Count 219
#
#
# Count 220
#
#
# Count 221
#
#
# Count 222
#
#
# Count 223
#
#
# Count 224
#
#
# Count 225
#
#
# Count 226
#
#
# Count 227
#
#
# Count 228
#
#
# Count 229
#
#
# Count 230
#
#
# Count 231
#
#
# Count 232
#
#
# Count 233
#
#
# Count 234
#
#
# Count 235
#
#
# Count 236
#
#
# Count 237
#
#
# Count 238
#
#
# Count 239
#
#
# Count 240
#
#
# Count 241
#
#
# Count 242
#
#
# Count 243
#
#
# Count 244
#
#
# Count 245
#
#
# Count 246
#
#
# Count 247
#
#
# Count 248
#
#
# Count 249
#
#
# Count 250
#
#
# Count 251
#
#
# Count 252
#
#
# Count 253
#
#
# Count 254
#
#
# Count 255
#
#
# Count 256
#
#
# Count 257
#
#
# Count 258
#
#
# Count 259
#
#
# Count 260
#
#
# Count 261
#
#
# Count 262
#
#
# Count 263
#
#
# Count 264
#
#
# Count 265
#
#
# Count 266
#
#
# Count 267
#
#
# Count 268
#
#
# Count 269
#
#
# Count 270
#
#
# Count 271
#
#
# Count 272
#
#
# Count 273
#
#
# Count 274
#
#
# Count 275
#
#
# Count 276
#
#
# Count 277
#
#
# Count 278
#
#
# Count 279
#
#
# Count 280
#
#
# Count 281
#
#
# Count 282
#
#
# Count 283
#
#
# Count 284
#
#
# Count 285
#
#
# Count 286
#
#
# Count 287
#
#
# Count 288
#
#
# Count 289
#
#
# Count 290
#
#
# Count 291
#
#
# Count 292
#
#
# Count 293
#
#
# Count 294
#
#
# Count 295
#
#
# Count 296
#
#
# Count 297
#
#
# Count 298
#
#
# Count 299
#
#
# Count 300
#
#
# Count 301
#
#
# Count 302
#
#
# Count 303
#
#
# Count 304
#
#
# Count 305
#
#
# Count 306
#
#
# Count 307
#
#
# Count 308
#
#
# Count 309
#
#
# Count 310
#
#
# Count 311
#
#
# Count 312
#
#
# Count 313
#
#
# Count 314
#
#
# Count 315
#
#
# Count 316
#
#
# Count 317
#
#
# Count 318
#
#
# Count 319
#
#
# Count 320
#
#
# Count 321
#
#
# Count 322
#
#
# Count 323
#
#
# Count 324
#
#
# Count 325
#
#
# Count 326
#
#
# Count 327
#
#
# Count 328
#
#
# Count 329
#
#
# Count 330
#
#
# Count 331
#
#
# Count 332
#
#
# Count 333
#
#
# Count 334
#
#
# Count 335
#
#
# Count 336
#
#
# Count 337
#
#
# Count 338
#
#
# Count 339
#
#
# Count 340
#
#
# Count 341
#
#
# Count 342
#
#
# Count 343
#
#
# Count 344
#
#
# Count 345
#
#
# Count 346
#
#
# Count 347
#
#
# Count 348
#
#
# Count 349
#
#
# Count 350
#
#
# Count 351
#
#
# Count 352
#
#
# Count 353
#
#
# Count 354
#
#
# Count 355
#
#
# Count 356
#
#
# Count 357
#
#
# Count 358
#
#
# Count 359
#
#
# Count 360
#
#
# Count 361
#
#
# Count 362
#
#
# Count 363
#
#
# Count 364
#
#
# Count 365
#
#
# Count 366
#
#
# Count 367
#
#
# Count 368
#
#
# Count 369
#
#
# Count 370
#
#
# Count 371
#
#
# Count 372
#
#
# Count 373
#
#
# Count 374
#
#
# Count 375
#
#
# Count 376
#
#
# Count 377
#
#
# Count 378
#
#
# Count 379
#
#
# Count 380
#
#
# Count 381
#
#
# Count 382
#
#
# Count 383
#
#
# Count 384
#
#
# Count 385
#
#
# Count 386
#
#
# Count 387
#
#
# Count 388
#
#
# Count 389
#
#
# Press 'q' to stop capturing frames.
# Count 390
#
#
# Count 391
#
#
# Count 392
#
#
# Count 393
#
#
# Count 394
#
#
# Count 395
#
#
# Count 396
#
#
# Count 397
#
#
# Count 398
#
#
# Count 399
#
#
# Count 400
#
#
# Count 401
#
#
# Count 402
#
#
# Count 403
#
#
# Count 404
#
#
# Count 405
#
#
# Count 406
#
#
# Saved: frames\frame_0000.jpg
# Count 407
#
#
# Count 408
#
#
# Saved: frames\frame_0001.jpg
# Count 409
#
#
# Count 410
#
#
# Saved: frames\frame_0002.jpg
# Count 411
#
#
# Count 412
#
#
# Saved: frames\frame_0003.jpg
# Count 413
#
#
# Saved: frames\frame_0004.jpg
# Count 414
#
#
# Count 415
#
#
# Saved: frames\frame_0005.jpg
# Count 416
#
#
# Count 417
#
#
# Saved: frames\frame_0006.jpg
# Count 418
#
#
# Count 419
#
#
# Saved: frames\frame_0007.jpg
# Count 420
#
#
# Count 421
#
#
# Saved: frames\frame_0008.jpg
# Count 422
#
#
# Saved: frames\frame_0009.jpg
# Count 423
#
#
# Saved: frames\frame_0010.jpg
# Count 424
#
#
# Count 425
#
#
# Saved: frames\frame_0011.jpg
# Count 426
#
#
# Count 427
#
#
# Saved: frames\frame_0012.jpg
# Count 428
#
#
# Count 429
#
#
# Saved: frames\frame_0013.jpg
# Count 430
#
#
# Count 431
#
#
# Saved: frames\frame_0014.jpg
# Count 432
#
#
# Saved: frames\frame_0015.jpg
# Count 433
#
#
# Count 434
#
#
# Saved: frames\frame_0016.jpg
# Count 435
#
#
# Count 436
#
#
# Saved: frames\frame_0017.jpg
# Count 437
#
#
# Count 438
#
#
# Saved: frames\frame_0018.jpg
# Count 439
#
#
# Count 440
#
#
# Saved: frames\frame_0019.jpg
# Count 441
#
#
# Count 442
#
#
# Saved: frames\frame_0020.jpg
# Count 443
#
#
# Count 444
#
#
# Saved: frames\frame_0021.jpg
# Count 445
#
#
# Saved: frames\frame_0022.jpg
# Count 446
#
#
# Saved: frames\frame_0023.jpg
# Count 447
#
#
# Count 448
#
#
# Saved: frames\frame_0024.jpg
# Count 449
#
#
# Saved: frames\frame_0025.jpg
# Count 450
#
#
# Saved: frames\frame_0026.jpg
# Count 451
#
#
# Saved: frames\frame_0027.jpg
# Count 452
#
#
# Saved: frames\frame_0028.jpg
# Count 453
#
#
# Saved: frames\frame_0029.jpg
# Count 454
#
#
# Saved: frames\frame_0030.jpg
# Count 455
#
#
# Saved: frames\frame_0031.jpg
# Count 456
#
#
# Saved: frames\frame_0032.jpg
# Count 457
#
#
# Saved: frames\frame_0033.jpg
# Count 458
#
#
# Count 459
#
#
# Saved: frames\frame_0034.jpg
# Count 460
#
#
# Saved: frames\frame_0035.jpg
# Count 461
#
#
# Count 462
#
#
# Saved: frames\frame_0036.jpg
# Count 463
#
#
# Saved: frames\frame_0037.jpg
# Count 464
#
#
# Saved: frames\frame_0038.jpg
# Count 465
#
#
# Count 466
#
#
# Saved: frames\frame_0039.jpg
# Count 467
#
#
# Count 468
#
#
# Saved: frames\frame_0040.jpg
# Count 469
#
#
# Saved: frames\frame_0041.jpg
# Count 470
#
#
# Count 471
#
#
# Saved: frames\frame_0042.jpg
# Count 472
#
#
# Saved: frames\frame_0043.jpg
# Count 473
#
#
# Count 474
#
#
# Saved: frames\frame_0044.jpg
# Count 475
#
#
# Saved: frames\frame_0045.jpg
# Count 476
#
#
# Saved: frames\frame_0046.jpg
# Count 477
#
#
# Saved: frames\frame_0047.jpg
# Count 478
#
#
# Saved: frames\frame_0048.jpg
# Count 479
#
#
# Saved: frames\frame_0049.jpg
# Count 480
#
#
# Count 481
#
#
# Saved: frames\frame_0050.jpg
# Count 482
#
#
# Saved: frames\frame_0051.jpg
# Count 483
#
#
# Count 484
#
#
# Saved: frames\frame_0052.jpg
# Count 485
#
#
# Count 486
#
#
# Saved: frames\frame_0053.jpg
# Count 487
#
#
# Count 488
#
#
# Saved: frames\frame_0054.jpg
# Count 489
#
#
# Count 490
#
#
# Saved: frames\frame_0055.jpg
# Count 491
#
#
# Count 492
#
#
# Saved: frames\frame_0056.jpg
# Count 493
#
#
# Saved: frames\frame_0057.jpg
# Count 494
#
#
# Count 495
#
#
# Saved: frames\frame_0058.jpg
# Count 496
#
#
# Count 497
#
#
# Saved: frames\frame_0059.jpg
# Count 498
#
#
# Count 499
#
#
# Saved: frames\frame_0060.jpg
# Count 500
#
#
# Saved: frames\frame_0061.jpg
# Count 501
#
#
# Saved: frames\frame_0062.jpg
# Count 502
#
#
# Count 503
#
#
# Saved: frames\frame_0063.jpg
# Count 504
#
#
# Count 505
#
#
# Saved: frames\frame_0064.jpg
# Count 506
#
#
# Count 507
#
#
# Saved: frames\frame_0065.jpg
# Count 508
#
#
# Count 509
#
#
# Saved: frames\frame_0066.jpg
# Count 510
#
#
# Count 511
#
#
# Saved: frames\frame_0067.jpg
# Count 512
#
#
# Saved: frames\frame_0068.jpg
# Count 513
#
#
# Saved: frames\frame_0069.jpg
# Count 514
#
#
# Count 515
#
#
# Saved: frames\frame_0070.jpg
# Count 516
#
#
# Count 517
#
#
# Saved: frames\frame_0071.jpg
# Count 518
#
#
# Count 519
#
#
# Saved: frames\frame_0072.jpg
# Count 520
#
#
# Saved: frames\frame_0073.jpg
# Count 521
#
#
# Count 522
#
#
# Saved: frames\frame_0074.jpg
# Count 523
#
#
# Count 524
#
#
# Saved: frames\frame_0075.jpg
# Count 525
#
#
# Count 526
#
#
# Saved: frames\frame_0076.jpg
# Count 527
#
#
# Count 528
#
#
# Saved: frames\frame_0077.jpg
# Count 529
#
#
# Count 530
#
#
# Saved: frames\frame_0078.jpg
# Count 531
#
#
# Count 532
#
#
# Saved: frames\frame_0079.jpg
# Count 533
#
#
# Count 534
#
#
# Saved: frames\frame_0080.jpg
# Count 535
#
#
# Count 536
#
#
# Saved: frames\frame_0081.jpg
# Count 537
#
#
# Count 538
#
#
# Saved: frames\frame_0082.jpg
# Count 539
#
#
# Count 540
#
#
# Saved: frames\frame_0083.jpg
# Count 541
#
#
# Count 542
#
#
# Saved: frames\frame_0084.jpg
# Count 543
#
#
# Saved: frames\frame_0085.jpg
# Count 544
#
#
# Count 545
#
#
# Saved: frames\frame_0086.jpg
# Count 546
#
#
# Count 547
#
#
# Saved: frames\frame_0087.jpg
# Count 548
#
#
# Count 549
#
#
# Saved: frames\frame_0088.jpg
# Count 550
#
#
# Count 551
#
#
# Count 552
#
#
# Saved: frames\frame_0089.jpg
# Count 553
#
#
# Count 554
#
#
# Count 555
#
#
# Saved: frames\frame_0090.jpg
# Count 556
#
#
# Count 557
#
#
# Count 558
#
#
# Saved: frames\frame_0091.jpg
# Count 559
#
#
# Count 560
#
#
# Saved: frames\frame_0092.jpg
# Count 561
#
#
# Count 562
#
#
# Saved: frames\frame_0093.jpg
# Count 563
#
#
# Saved: frames\frame_0094.jpg
# Count 564
#
#
# Count 565
#
#
# Count 566
#
#
# Saved: frames\frame_0095.jpg
# Count 567
#
#
# Count 568
#
#
# Saved: frames\frame_0096.jpg
# Count 569
#
#
# Saved: frames\frame_0097.jpg
# Count 570
#
#
# Count 571
#
#
# Saved: frames\frame_0098.jpg
# Count 572
#
#
# Count 573
#
#
# Saved: frames\frame_0099.jpg
# Count 574
#
#
# Count 575
#
#
# Count 576
#
#
# Saved: frames\frame_0100.jpg
# Count 577
#
#
# Count 578
#
#
# Saved: frames\frame_0101.jpg
# Count 579
#
#
# Count 580
#
#
# Count 581
#
#
# Saved: frames\frame_0102.jpg
# Count 582
#
#
# Count 583
#
#
# Saved: frames\frame_0103.jpg
# Count 584
#
#
# Count 585
#
#
# Saved: frames\frame_0104.jpg
# Count 586
#
#
# Count 587
#
#
# Saved: frames\frame_0105.jpg
# Count 588
#
#
# Count 589
#
#
# Count 590
#
#
# Saved: frames\frame_0106.jpg
# Count 591
#
#
# Count 592
#
#
# Saved: frames\frame_0107.jpg
# Count 593
#
#
# Count 594
#
#
# Saved: frames\frame_0108.jpg
# Count 595
#
#
# Count 596
#
#
# Saved: frames\frame_0109.jpg
# Count 597
#
#
# Count 598
#
#
# Saved: frames\frame_0110.jpg
# Count 599
#
#
# Count 600
#
#
# Saved: frames\frame_0111.jpg
# Count 601
#
#
# Count 602
#
#
# Saved: frames\frame_0112.jpg
# Count 603
#
#
# Count 604
#
#
# Saved: frames\frame_0113.jpg
# Count 605
#
#
# Saved: frames\frame_0114.jpg
# Count 606
#
#
# Saved: frames\frame_0115.jpg
# Count 607
#
#
# Saved: frames\frame_0116.jpg
# Count 608
#
#
# Saved: frames\frame_0117.jpg
# Count 609
#
#
# Count 610
#
#
# Saved: frames\frame_0118.jpg
# Count 611
#
#
# Count 612
#
#
# Saved: frames\frame_0119.jpg
# Count 613
#
#
# Saved: frames\frame_0120.jpg
# Count 614
#
#
# Count 615
#
#
# Saved: frames\frame_0121.jpg
# Count 616
#
#
# Count 617
#
#
# Saved: frames\frame_0122.jpg
# Count 618
#
#
# Saved: frames\frame_0123.jpg
# Count 619
#
#
# Saved: frames\frame_0124.jpg
# Count 620
#
#
# Saved: frames\frame_0125.jpg
# Count 621
#
#
# Count 622
#
#
# Saved: frames\frame_0126.jpg
# Count 623
#
#
# Count 624
#
#
# Saved: frames\frame_0127.jpg
# Count 625
#
#
# Count 626
#
#
# Saved: frames\frame_0128.jpg
# Count 627
#
#
# Count 628
#
#
# Saved: frames\frame_0129.jpg
# Count 629
#
#
# Count 630
#
#
# Saved: frames\frame_0130.jpg
# Count 631
#
#
# Count 632
#
#
# Saved: frames\frame_0131.jpg
# Count 633
#
#
# Count 634
#
#
# Saved: frames\frame_0132.jpg
# Count 635
#
#
# Count 636
#
#
# Saved: frames\frame_0133.jpg
# Count 637
#
#
# Count 638
#
#
# Saved: frames\frame_0134.jpg
# Count 639
#
#
# Count 640
#
#
# Saved: frames\frame_0135.jpg
# Count 641
#
#
# Saved: frames\frame_0136.jpg
# Count 642
#
#
# Count 643
#
#
# Saved: frames\frame_0137.jpg
# Count 644
#
#
# Count 645
#
#
# Saved: frames\frame_0138.jpg
# Count 646
#
#
# Saved: frames\frame_0139.jpg
# Count 647
#
#
# Count 648
#
#
# Saved: frames\frame_0140.jpg
# Count 649
#
#
# Count 650
#
#
# Saved: frames\frame_0141.jpg
# Count 651
#
#
# Saved: frames\frame_0142.jpg
# Count 652
#
#
# Saved: frames\frame_0143.jpg
# Count 653
#
#
# Saved: frames\frame_0144.jpg
# Count 654
#
#
# Count 655
#
#
# Saved: frames\frame_0145.jpg
# Count 656
#
#
# Saved: frames\frame_0146.jpg
# Count 657
#
#
# Saved: frames\frame_0147.jpg
# Count 658
#
#
# Count 659
#
#
# Saved: frames\frame_0148.jpg
# Count 660
#
#
# Saved: frames\frame_0149.jpg
# Count 661
#
#
# Saved: frames\frame_0150.jpg
# Count 662
#
#
# Count 663
#
#
# Saved: frames\frame_0151.jpg
# Count 664
#
#
# Count 665
#
#
# Saved: frames\frame_0152.jpg
# Count 666
#
#
# Saved: frames\frame_0153.jpg
# Count 667
#
#
# Saved: frames\frame_0154.jpg
# Count 668
#
#
# Count 669
#
#
# Saved: frames\frame_0155.jpg
# Count 670
#
#
# Count 671
#
#
# Saved: frames\frame_0156.jpg
# Count 672
#
#
# Saved: frames\frame_0157.jpg
# Count 673
#
#
# Saved: frames\frame_0158.jpg
# Count 674
#
#
# Count 675
#
#
# Saved: frames\frame_0159.jpg
# Count 676
#
#
# Count 677
#
#
# Saved: frames\frame_0160.jpg
# Count 678
#
#
# Saved: frames\frame_0161.jpg
# Count 679
#
#
# Saved: frames\frame_0162.jpg
# Count 680
#
#
# Saved: frames\frame_0163.jpg
# Count 681
#
#
# Count 682
#
#
# Saved: frames\frame_0164.jpg
# Count 683
#
#
# Saved: frames\frame_0165.jpg
# Count 684
#
#
# Count 685
#
#
# Saved: frames\frame_0166.jpg
# Count 686
#
#
# Count 687
#
#
# Saved: frames\frame_0167.jpg
# Count 688
#
#
# Saved: frames\frame_0168.jpg
# Count 689
#
#
# Saved: frames\frame_0169.jpg
# Count 690
#
#
# Count 691
#
#
# Saved: frames\frame_0170.jpg
# Count 692
#
#
# Count 693
#
#
# Saved: frames\frame_0171.jpg
# Count 694
#
#
# Saved: frames\frame_0172.jpg
# Count 695
#
#
# Saved: frames\frame_0173.jpg
# Count 696
#
#
# Saved: frames\frame_0174.jpg
# Count 697
#
#
# Saved: frames\frame_0175.jpg
# Count 698
#
#
# Count 699
#
#
# Saved: frames\frame_0176.jpg
# Count 700
#
#
# Count 701
#
#
# Saved: frames\frame_0177.jpg
# Count 702
#
#
# Saved: frames\frame_0178.jpg
# Count 703
#
#
# Count 704
#
#
# Saved: frames\frame_0179.jpg
# Count 705
#
#
# Count 706
#
#
# Saved: frames\frame_0180.jpg
# Count 707
#
#
# Saved: frames\frame_0181.jpg
# Count 708
#
#
# Count 709
#
#
# Saved: frames\frame_0182.jpg
# Count 710
#
#
# Count 711
#
#
# Saved: frames\frame_0183.jpg
# Count 712
#
#
# Count 713
#
#
# Saved: frames\frame_0184.jpg
# Count 714
#
#
# Saved: frames\frame_0185.jpg
# Count 715
#
#
# Saved: frames\frame_0186.jpg
# Count 716
#
#
# Saved: frames\frame_0187.jpg
# Count 717
#
#
# Count 718
#
#
# Saved: frames\frame_0188.jpg
# Count 719
#
#
# Saved: frames\frame_0189.jpg
# Count 720
#
#
# Saved: frames\frame_0190.jpg
# Count 721
#
#
# Count 722
#
#
# Saved: frames\frame_0191.jpg
# Count 723
#
#
# Saved: frames\frame_0192.jpg
# Count 724
#
#
# Count 725
#
#
# Saved: frames\frame_0193.jpg
# Count 726
#
#
# Count 727
#
#
# Saved: frames\frame_0194.jpg
# Count 728
#
#
# Saved: frames\frame_0195.jpg
# Count 729
#
#
# Saved: frames\frame_0196.jpg
# Count 730
#
#
# Saved: frames\frame_0197.jpg
# Count 731
#
#
# Count 732
#
#
# Saved: frames\frame_0198.jpg
# Count 733
#
#
# Saved: frames\frame_0199.jpg
# Count 734
#
#
# Count 735
#
#
# Saved: frames\frame_0200.jpg
# Count 736
#
#
# Saved: frames\frame_0201.jpg
# Count 737
#
#
# Saved: frames\frame_0202.jpg
# Count 738
#
#
# Saved: frames\frame_0203.jpg
# Count 739
#
#
# Saved: frames\frame_0204.jpg
# Count 740
#
#
# Saved: frames\frame_0205.jpg
# Count 741
#
#
# Saved: frames\frame_0206.jpg
# Count 742
#
#
# Saved: frames\frame_0207.jpg
# Count 743
#
#
# Saved: frames\frame_0208.jpg
# Count 744
#
#
# Count 745
#
#
# Saved: frames\frame_0209.jpg
# Count 746
#
#
# Saved: frames\frame_0210.jpg
# Count 747
#
#
# Saved: frames\frame_0211.jpg
# Count 748
#
#
# Saved: frames\frame_0212.jpg
# Count 749
#
#
# Saved: frames\frame_0213.jpg
# Count 750
#
#
# Saved: frames\frame_0214.jpg
# Count 751
#
#
# Saved: frames\frame_0215.jpg
# Count 752
#
#
# Count 753
#
#
# Saved: frames\frame_0216.jpg
# Count 754
#
#
# Count 755
#
#
# Saved: frames\frame_0217.jpg
# Count 756
#
#
# Saved: frames\frame_0218.jpg
# Count 757
#
#
# Count 758
#
#
# Saved: frames\frame_0219.jpg
# Count 759
#
#
# Saved: frames\frame_0220.jpg
# Count 760
#
#
# Saved: frames\frame_0221.jpg
# Count 761
#
#
# Saved: frames\frame_0222.jpg
# Count 762
#
#
# Saved: frames\frame_0223.jpg
# Count 763
#
#
# Count 764
#
#
# Saved: frames\frame_0224.jpg
# Count 765
#
#
# Saved: frames\frame_0225.jpg
# Count 766
#
#
# Count 767
#
#
# Saved: frames\frame_0226.jpg
# Count 768
#
#
# Saved: frames\frame_0227.jpg
# Count 769
#
#
# Saved: frames\frame_0228.jpg
# Count 770
#
#
# Saved: frames\frame_0229.jpg
# Count 771
#
#
# Saved: frames\frame_0230.jpg
# Count 772
#
#
# Saved: frames\frame_0231.jpg
# Count 773
#
#
# Saved: frames\frame_0232.jpg
# Count 774
#
#
# Saved: frames\frame_0233.jpg
# Count 775
#
#
# Saved: frames\frame_0234.jpg
# Count 776
#
#
# Saved: frames\frame_0235.jpg
# Count 777
#
#
# Count 778
#
#
# Saved: frames\frame_0236.jpg
# Count 779
#
#
# Saved: frames\frame_0237.jpg
# Count 780
#
#
# Saved: frames\frame_0238.jpg
# Count 781
#
#
# Count 782
#
#
# Saved: frames\frame_0239.jpg
# Count 783
#
#
# Saved: frames\frame_0240.jpg
# Count 784
#
#
# Count 785
#
#
# Saved: frames\frame_0241.jpg
# Count 786
#
#
# Count 787
#
#
# Saved: frames\frame_0242.jpg
# Count 788
#
#
# Saved: frames\frame_0243.jpg
# Count 789
#
#
# Saved: frames\frame_0244.jpg
# Count 790
#
#
# Count 791
#
#
# Saved: frames\frame_0245.jpg
# Count 792
#
#
# Saved: frames\frame_0246.jpg
# Count 793
#
#
# Count 794
#
#
# Saved: frames\frame_0247.jpg
# Count 795
#
#
# Count 796
#
#
# Saved: frames\frame_0248.jpg
# Count 797
#
#
# Saved: frames\frame_0249.jpg
# Count 798
#
#
# Count 799
#
#
# Saved: frames\frame_0250.jpg
# Count 800
#
#
# Count 801
#
#
# Saved: frames\frame_0251.jpg
# Count 802
#
#
# Count 803
#
#
# Saved: frames\frame_0252.jpg
# Count 804
#
#
# Count 805
#
#
# Saved: frames\frame_0253.jpg
# Count 806
#
#
# Saved: frames\frame_0254.jpg
# Count 807
#
#
# Count 808
#
#
# Saved: frames\frame_0255.jpg
# Count 809
#
#
# Count 810
#
#
# Saved: frames\frame_0256.jpg
# Count 811
#
#
# Saved: frames\frame_0257.jpg
# Count 812
#
#
# Count 813
#
#
# Saved: frames\frame_0258.jpg
# Count 814
#
#
# Saved: frames\frame_0259.jpg
# Count 815
#
#
# Saved: frames\frame_0260.jpg
# Count 816
#
#
# Saved: frames\frame_0261.jpg
# Count 817
#
#
# Count 818
#
#
# Saved: frames\frame_0262.jpg
# Count 819
#
#
# Saved: frames\frame_0263.jpg
# Count 820
#
#
# Count 821
#
#
# Saved: frames\frame_0264.jpg
# Count 822
#
#
# Saved: frames\frame_0265.jpg
# Count 823
#
#
# Saved: frames\frame_0266.jpg
# Count 824
#
#
# Saved: frames\frame_0267.jpg
# Count 825
#
#
# Count 826
#
#
# Saved: frames\frame_0268.jpg
# Count 827
#
#
# Count 828
#
#
# Saved: frames\frame_0269.jpg
# Count 829
#
#
# Count 830
#
#
# Saved: frames\frame_0270.jpg
# Count 831
#
#
# Saved: frames\frame_0271.jpg
# Count 832
#
#
# Count 833
#
#
# Saved: frames\frame_0272.jpg
# Count 834
#
#
# Saved: frames\frame_0273.jpg
# Count 835
#
#
# Count 836
#
#
# Saved: frames\frame_0274.jpg
# Count 837
#
#
# Count 838
#
#
# Saved: frames\frame_0275.jpg
# Count 839
#
#
# Count 840
#
#
# Saved: frames\frame_0276.jpg
# Count 841
#
#
# Count 842
#
#
# Saved: frames\frame_0277.jpg
# Count 843
#
#
# Saved: frames\frame_0278.jpg
# Count 844
#
#
# Saved: frames\frame_0279.jpg
# Count 845
#
#
# Count 846
#
#
# Saved: frames\frame_0280.jpg
# Count 847
#
#
# Saved: frames\frame_0281.jpg
# Count 848
#
#
# Count 849
#
#
# Saved: frames\frame_0282.jpg
# Count 850
#
#
# Count 851
#
#
# Count 852
#
#
# Saved: frames\frame_0283.jpg
# Count 853
#
#
# Saved: frames\frame_0284.jpg
# Count 854
#
#
# Saved: frames\frame_0285.jpg
# Count 855
#
#
# Saved: frames\frame_0286.jpg
# Count 856
#
#
# Saved: frames\frame_0287.jpg
# Count 857
#
#
# Count 858
#
#
# Saved: frames\frame_0288.jpg
# Count 859
#
#
# Count 860
#
#
# Saved: frames\frame_0289.jpg
# Count 861
#
#
# Count 862
#
#
# Saved: frames\frame_0290.jpg
# Count 863
#
#
# Saved: frames\frame_0291.jpg
# Count 864
#
#
# Count 865
#
#
# Saved: frames\frame_0292.jpg
# Count 866
#
#
# Saved: frames\frame_0293.jpg
# Count 867
#
#
# Saved: frames\frame_0294.jpg
# Count 868
#
#
# Saved: frames\frame_0295.jpg
# Count 869
#
#
# Saved: frames\frame_0296.jpg
# Count 870
#
#
# Saved: frames\frame_0297.jpg
# Count 871
#
#
# Count 872
#
#
# Saved: frames\frame_0298.jpg
# Count 873
#
#
# Count 874
#
#
# Saved: frames\frame_0299.jpg
# Count 875
#
#
# Count 876
#
#
# Saved: frames\frame_0300.jpg
# Count 877
#
#
# Count 878
#
#
# Count 879
#
#
# Saved: frames\frame_0301.jpg
# Count 880
#
#
# Saved: frames\frame_0302.jpg
# Count 881
#
#
# Count 882
#
#
# Saved: frames\frame_0303.jpg
# Count 883
#
#
# Saved: frames\frame_0304.jpg
# Count 884
#
#
# Count 885
#
#
# Saved: frames\frame_0305.jpg
# Count 886
#
#
# Count 887
#
#
# Saved: frames\frame_0306.jpg
# Count 888
#
#
# Count 889
#
#
# Saved: frames\frame_0307.jpg
# Count 890
#
#
# Count 891
#
#
# Saved: frames\frame_0308.jpg
# Count 892
#
#
# Count 893
#
#
# Saved: frames\frame_0309.jpg
# Count 894
#
#
# Count 895
#
#
# Saved: frames\frame_0310.jpg
# Count 896
#
#
# Count 897
#
#
# Saved: frames\frame_0311.jpg
# Count 898
#
#
# Saved: frames\frame_0312.jpg
# Count 899
#
#
# Saved: frames\frame_0313.jpg
# Count 900
#
#
# Saved: frames\frame_0314.jpg
# Count 901
#
#
# Count 902
#
#
# Saved: frames\frame_0315.jpg
# Count 903
#
#
# Count 904
#
#
# Saved: frames\frame_0316.jpg
# Count 905
#
#
# Count 906
#
#
# Saved: frames\frame_0317.jpg
# Count 907
#
#
# Count 908
#
#
# Saved: frames\frame_0318.jpg
# Count 909
#
#
# Count 910
#
#
# Saved: frames\frame_0319.jpg
# Count 911
#
#
# Saved: frames\frame_0320.jpg
# Count 912
#
#
# Saved: frames\frame_0321.jpg
# Count 913
#
#
# Saved: frames\frame_0322.jpg
# Count 914
#
#
# Saved: frames\frame_0323.jpg
# Count 915
#
#
# Saved: frames\frame_0324.jpg
# Count 916
#
#
# Saved: frames\frame_0325.jpg
# Count 917
#
#
# Count 918
#
#
# Saved: frames\frame_0326.jpg
# Count 919
#
#
# Saved: frames\frame_0327.jpg
# Count 920
#
#
# Saved: frames\frame_0328.jpg
# Count 921
#
#
# Saved: frames\frame_0329.jpg
# Count 922
#
#
# Saved: frames\frame_0330.jpg
# Count 923
#
#
# Count 924
#
#
# Saved: frames\frame_0331.jpg
# Count 925
#
#
# Saved: frames\frame_0332.jpg
# Count 926
#
#
# Saved: frames\frame_0333.jpg
# Count 927
#
#
# Saved: frames\frame_0334.jpg
# Count 928
#
#
# Count 929
#
#
# Saved: frames\frame_0335.jpg
# Count 930
#
#
# Count 931
#
#
# Saved: frames\frame_0336.jpg
# Count 932
#
#
# Saved: frames\frame_0337.jpg
# Count 933
#
#
# Saved: frames\frame_0338.jpg
# Count 934
#
#
# Saved: frames\frame_0339.jpg
# Count 935
#
#
# Count 936
#
#
# Saved: frames\frame_0340.jpg
# Count 937
#
#
# Saved: frames\frame_0341.jpg
# Count 938
#
#
# Saved: frames\frame_0342.jpg
# Count 939
#
#
# Count 940
#
#
# Saved: frames\frame_0343.jpg
# Count 941
#
#
# Saved: frames\frame_0344.jpg
# Count 942
#
#
# Saved: frames\frame_0345.jpg
# Count 943
#
#
# Count 944
#
#
# Saved: frames\frame_0346.jpg
# Count 945
#
#
# Count 946
#
#
# Saved: frames\frame_0347.jpg
# Count 947
#
#
# Count 948
#
#
# Saved: frames\frame_0348.jpg
# Count 949
#
#
# Saved: frames\frame_0349.jpg
# Count 950
#
#
# Count 951
#
#
# Saved: frames\frame_0350.jpg
# Count 952
#
#
# Count 953
#
#
# Saved: frames\frame_0351.jpg
# Count 954
#
#
# Saved: frames\frame_0352.jpg
# Count 955
#
#
# Saved: frames\frame_0353.jpg
# Count 956
#
#
# Count 957
#
#
# Saved: frames\frame_0354.jpg
# Count 958
#
#
# Count 959
#
#
# Saved: frames\frame_0355.jpg
# Count 960
#
#
# Saved: frames\frame_0356.jpg
# Count 961
#
#
# Count 962
#
#
# Saved: frames\frame_0357.jpg
# Count 963
#
#
# Saved: frames\frame_0358.jpg
# Count 964
#
#
# Count 965
#
#
# Saved: frames\frame_0359.jpg
# Count 966
#
#
# Count 967
#
#
# Saved: frames\frame_0360.jpg
# Count 968
#
#
# Saved: frames\frame_0361.jpg
# Count 969
#
#
# Count 970
#
#
# Saved: frames\frame_0362.jpg
# Count 971
#
#
# Saved: frames\frame_0363.jpg
# Count 972
#
#
# Saved: frames\frame_0364.jpg
# Count 973
#
#
# Saved: frames\frame_0365.jpg
# Count 974
#
#
# Saved: frames\frame_0366.jpg
# Count 975
#
#
# Count 976
#
#
# Saved: frames\frame_0367.jpg
# Count 977
#
#
# Count 978
#
#
# Saved: frames\frame_0368.jpg
# Count 979
#
#
# Saved: frames\frame_0369.jpg
# Count 980
#
#
# Saved: frames\frame_0370.jpg
# Count 981
#
#
# Saved: frames\frame_0371.jpg
# Count 982
#
#
# Count 983
#
#
# Saved: frames\frame_0372.jpg
# Count 984
#
#
# Count 985
#
#
# Saved: frames\frame_0373.jpg
# Count 986
#
#
# Saved: frames\frame_0374.jpg
# Count 987
#
#
# Count 988
#
#
# Saved: frames\frame_0375.jpg
# Count 989
#
#
# Saved: frames\frame_0376.jpg
# Count 990
#
#
# Saved: frames\frame_0377.jpg
# Count 991
#
#
# Saved: frames\frame_0378.jpg
# Count 992
#
#
# Count 993
#
#
# Saved: frames\frame_0379.jpg
# Count 994
#
#
# Saved: frames\frame_0380.jpg
# Count 995
#
#
# Count 996
#
#
# Saved: frames\frame_0381.jpg
# Count 997
#
#
# Count 998
#
#
# Saved: frames\frame_0382.jpg
# Count 999
#
#
# Count 1000
#
#
# Saved: frames\frame_0383.jpg
# Count 1001
#
#
# Saved: frames\frame_0384.jpg
# Count 1002
#
#
# Count 1003
#
#
# Saved: frames\frame_0385.jpg
# Count 1004
#
#
# Saved: frames\frame_0386.jpg
# Count 1005
#
#
# Count 1006
#
#
# Saved: frames\frame_0387.jpg
# Count 1007
#
#
# Saved: frames\frame_0388.jpg
# Count 1008
#
#
# Saved: frames\frame_0389.jpg
# Count 1009
#
#
# Saved: frames\frame_0390.jpg
# Count 1010
#
#
# Saved: frames\frame_0391.jpg
# Count 1011
#
#
# Saved: frames\frame_0392.jpg
# Count 1012
#
#
# Saved: frames\frame_0393.jpg
# Count 1013
#
#
# Saved: frames\frame_0394.jpg
# Count 1014
#
#
# Saved: frames\frame_0395.jpg
# Count 1015
#
#
# Saved: frames\frame_0396.jpg
# Count 1016
#
#
# Saved: frames\frame_0397.jpg
# Count 1017
#
#
# Saved: frames\frame_0398.jpg
# Count 1018
#
#
# Saved: frames\frame_0399.jpg
# Count 1019
#
#
# Saved: frames\frame_0400.jpg
# Count 1020
#
#
# Count 1021
#
#
# Saved: frames\frame_0401.jpg
# Count 1022
#
#
# Count 1023
#
#
# Saved: frames\frame_0402.jpg
# Count 1024
#
#
# Saved: frames\frame_0403.jpg
# Count 1025
#
#
# Saved: frames\frame_0404.jpg
# Count 1026
#
#
# Saved: frames\frame_0405.jpg
# Count 1027
#
#
# Count 1028
#
#
# Saved: frames\frame_0406.jpg
# Count 1029
#
#
# Count 1030
#
#
# Saved: frames\frame_0407.jpg
# Count 1031
#
#
# Saved: frames\frame_0408.jpg
# Count 1032
#
#
# Saved: frames\frame_0409.jpg
# Count 1033
#
#
# Count 1034
#
#
# Saved: frames\frame_0410.jpg
# Count 1035
#
#
# Saved: frames\frame_0411.jpg
# Count 1036
#
#
# Saved: frames\frame_0412.jpg
# Count 1037
#
#
# Count 1038
#
#
# Saved: frames\frame_0413.jpg
# Count 1039
#
#
# Count 1040
#
#
# Saved: frames\frame_0414.jpg
# Count 1041
#
#
# Count 1042
#
#
# Saved: frames\frame_0415.jpg
# Count 1043
#
#
# Count 1044
#
#
# Saved: frames\frame_0416.jpg
# Count 1045
#
#
# Saved: frames\frame_0417.jpg
# Count 1046
#
#
# Saved: frames\frame_0418.jpg
# Count 1047
#
#
# Saved: frames\frame_0419.jpg
# Count 1048
#
#
# Saved: frames\frame_0420.jpg
# Count 1049
#
#
# Saved: frames\frame_0421.jpg
# Count 1050
#
#
# Saved: frames\frame_0422.jpg
# Count 1051
#
#
# Count 1052
#
#
# Saved: frames\frame_0423.jpg
# Count 1053
#
#
# Saved: frames\frame_0424.jpg
# Count 1054
#
#
# Count 1055
#
#
# Saved: frames\frame_0425.jpg
# Count 1056
#
#
# Count 1057
#
#
# Saved: frames\frame_0426.jpg
# Count 1058
#
#
# Saved: frames\frame_0427.jpg
# Count 1059
#
#
# Saved: frames\frame_0428.jpg
# Count 1060
#
#
# Saved: frames\frame_0429.jpg
# Count 1061
#
#
# Saved: frames\frame_0430.jpg
# Count 1062
#
#
# Count 1063
#
#
# Saved: frames\frame_0431.jpg
# Count 1064
#
#
# Count 1065
#
#
# Saved: frames\frame_0432.jpg
# Count 1066
#
#
# Saved: frames\frame_0433.jpg
# Count 1067
#
#
# Count 1068
#
#
# Saved: frames\frame_0434.jpg
# Count 1069
#
#
# Count 1070
#
#
# Saved: frames\frame_0435.jpg
# Count 1071
#
#
# Count 1072
#
#
# Saved: frames\frame_0436.jpg
# Count 1073
#
#
# Saved: frames\frame_0437.jpg
# Count 1074
#
#
# Count 1075
#
#
# Saved: frames\frame_0438.jpg
# Count 1076
#
#
# Count 1077
#
#
# Saved: frames\frame_0439.jpg
# Count 1078
#
#
# Saved: frames\frame_0440.jpg
# Count 1079
#
#
# Saved: frames\frame_0441.jpg
# Count 1080
#
#
# Saved: frames\frame_0442.jpg
# Count 1081
#
#
# Saved: frames\frame_0443.jpg
# Count 1082
#
#
# Saved: frames\frame_0444.jpg
# Count 1083
#
#
# Saved: frames\frame_0445.jpg
# Count 1084
#
#
# Saved: frames\frame_0446.jpg
# Count 1085
#
#
# Count 1086
#
#
# Saved: frames\frame_0447.jpg
# Count 1087
#
#
# Saved: frames\frame_0448.jpg
# Count 1088
#
#
# Count 1089
#
#
# Saved: frames\frame_0449.jpg
# Count 1090
#
#
# Count 1091
#
#
# Saved: frames\frame_0450.jpg
# Count 1092
#
#
# Saved: frames\frame_0451.jpg
# Count 1093
#
#
# Count 1094
#
#
# Saved: frames\frame_0452.jpg
# Count 1095
#
#
# Saved: frames\frame_0453.jpg
# Count 1096
#
#
# Saved: frames\frame_0454.jpg
# Count 1097
#
#
# Count 1098
#
#
# Saved: frames\frame_0455.jpg
# Count 1099
#
#
# Saved: frames\frame_0456.jpg
# Count 1100
#
#
# Count 1101
#
#
# Saved: frames\frame_0457.jpg
# Count 1102
#
#
# Saved: frames\frame_0458.jpg
# Count 1103
#
#
# Count 1104
#
#
# Saved: frames\frame_0459.jpg
# Count 1105
#
#
# Saved: frames\frame_0460.jpg
# Count 1106
#
#
# Count 1107
#
#
# Saved: frames\frame_0461.jpg
# Count 1108
#
#
# Count 1109
#
#
# Saved: frames\frame_0462.jpg
# Count 1110
#
#
# Saved: frames\frame_0463.jpg
# Count 1111
#
#
# Count 1112
#
#
# Saved: frames\frame_0464.jpg
# Count 1113
#
#
# Saved: frames\frame_0465.jpg
# Count 1114
#
#
# Count 1115
#
#
# Saved: frames\frame_0466.jpg
# Count 1116
#
#
# Saved: frames\frame_0467.jpg
# Count 1117
#
#
# Saved: frames\frame_0468.jpg
# Count 1118
#
#
# Saved: frames\frame_0469.jpg
# Count 1119
#
#
# Count 1120
#
#
# Saved: frames\frame_0470.jpg
# Count 1121
#
#
# Count 1122
#
#
# Saved: frames\frame_0471.jpg
# Count 1123
#
#
# Count 1124
#
#
# Saved: frames\frame_0472.jpg
# Count 1125
#
#
# Saved: frames\frame_0473.jpg
# Count 1126
#
#
# Saved: frames\frame_0474.jpg
# Count 1127
#
#
# Count 1128
#
#
# Saved: frames\frame_0475.jpg
# Count 1129
#
#
# Count 1130
#
#
# Saved: frames\frame_0476.jpg
# Count 1131
#
#
# Saved: frames\frame_0477.jpg
# Count 1132
#
#
# Count 1133
#
#
# Saved: frames\frame_0478.jpg
# Count 1134
#
#
# Count 1135
#
#
# Saved: frames\frame_0479.jpg
# Count 1136
#
#
# Count 1137
#
#
# Saved: frames\frame_0480.jpg
# Count 1138
#
#
# Count 1139
#
#
# Saved: frames\frame_0481.jpg
# Count 1140
#
#
# Count 1141
#
#
# Saved: frames\frame_0482.jpg
# Count 1142
#
#
# Count 1143
#
#
# Saved: frames\frame_0483.jpg
# Count 1144
#
#
# Count 1145
#
#
# Saved: frames\frame_0484.jpg
# Count 1146
#
#
# Count 1147
#
#
# Saved: frames\frame_0485.jpg
# Count 1148
#
#
# Count 1149
#
#
# Saved: frames\frame_0486.jpg
# Count 1150
#
#
# Count 1151
#
#
# Saved: frames\frame_0487.jpg
# Count 1152
#
#
# Count 1153
#
#
# Saved: frames\frame_0488.jpg
# Count 1154
#
#
# Count 1155
#
#
# Saved: frames\frame_0489.jpg
# Count 1156
#
#
# Count 1157
#
#
# Saved: frames\frame_0490.jpg
# Count 1158
#
#
# Count 1159
#
#
# Saved: frames\frame_0491.jpg
# Count 1160
#
#
# Count 1161
#
#
# Saved: frames\frame_0492.jpg
# Count 1162
#
#
# Count 1163
#
#
# Saved: frames\frame_0493.jpg
# Count 1164
#
#
# Count 1165
#
#
# Saved: frames\frame_0494.jpg
# Count 1166
#
#
# Count 1167
#
#
# Saved: frames\frame_0495.jpg
# Count 1168
#
#
# Count 1169
#
#
# Saved: frames\frame_0496.jpg
# Count 1170
#
#
# Count 1171
#
#
# Count 1172
#
#
# Saved: frames\frame_0497.jpg
# Count 1173
#
#
# Count 1174
#
#
# Saved: frames\frame_0498.jpg
# Count 1175
#
#
# Count 1176
#
#
# Saved: frames\frame_0499.jpg
# Count 1177
#
#
# Saved: frames\frame_0500.jpg
# Count 1178
#
#
# Count 1179
#
#
# Saved: frames\frame_0501.jpg
# Count 1180
#
#
# Saved: frames\frame_0502.jpg
# Count 1181
#
#
# Count 1182
#
#
# Saved: frames\frame_0503.jpg
# Count 1183
#
#
# Count 1184
#
#
# Saved: frames\frame_0504.jpg
# Count 1185
#
#
# Count 1186
#
#
# Saved: frames\frame_0505.jpg
# Count 1187
#
#
# Count 1188
#
#
# Saved: frames\frame_0506.jpg
# Count 1189
#
#
# Saved: frames\frame_0507.jpg
# Count 1190
#
#
# Count 1191
#
#
# Saved: frames\frame_0508.jpg
# Count 1192
#
#
# Saved: frames\frame_0509.jpg
# Count 1193
#
#
# Count 1194
#
#
# Saved: frames\frame_0510.jpg
# Count 1195
#
#
# Count 1196
#
#
# Saved: frames\frame_0511.jpg
# Count 1197
#
#
# Saved: frames\frame_0512.jpg
# Count 1198
#
#
# Saved: frames\frame_0513.jpg
# Count 1199
#
#
# Saved: frames\frame_0514.jpg
# Count 1200
#
#
# Saved: frames\frame_0515.jpg
# Count 1201
#
#
# Count 1202
#
#
# Saved: frames\frame_0516.jpg
# Count 1203
#
#
# Count 1204
#
#
# Saved: frames\frame_0517.jpg
# Count 1205
#
#
# Saved: frames\frame_0518.jpg
# Count 1206
#
#
# Count 1207
#
#
# Saved: frames\frame_0519.jpg
# Count 1208
#
#
# Saved: frames\frame_0520.jpg
# Count 1209
#
#
# Saved: frames\frame_0521.jpg
# Count 1210
#
#
# Saved: frames\frame_0522.jpg
# Count 1211
#
#
# Saved: frames\frame_0523.jpg
# Count 1212
#
#
# Saved: frames\frame_0524.jpg
# Count 1213
#
#
# Count 1214
#
#
# Count 1215
#
#
# Saved: frames\frame_0525.jpg
# Count 1216
#
#
# Count 1217
#
#
# Saved: frames\frame_0526.jpg
# Count 1218
#
#
# Saved: frames\frame_0527.jpg
# Count 1219
#
#
# Saved: frames\frame_0528.jpg
# Count 1220
#
#
# Saved: frames\frame_0529.jpg
# Count 1221
#
#
# Saved: frames\frame_0530.jpg
# Count 1222
#
#
# Count 1223
#
#
# Saved: frames\frame_0531.jpg
# Count 1224
#
#
# Saved: frames\frame_0532.jpg
# Count 1225
#
#
# Count 1226
#
#
# Saved: frames\frame_0533.jpg
# Count 1227
#
#
# Saved: frames\frame_0534.jpg
# Count 1228
#
#
# Saved: frames\frame_0535.jpg
# Count 1229
#
#
# Saved: frames\frame_0536.jpg
# Count 1230
#
#
# Count 1231
#
#
# Saved: frames\frame_0537.jpg
# Count 1232
#
#
# Count 1233
#
#
# Saved: frames\frame_0538.jpg
# Count 1234
#
#
# Saved: frames\frame_0539.jpg
# Count 1235
#
#
# Saved: frames\frame_0540.jpg
# Count 1236
#
#
# Count 1237
#
#
# Count 1238
#
#
# Saved: frames\frame_0541.jpg
# Count 1239
#
#
# Count 1240
#
#
# Saved: frames\frame_0542.jpg
# Count 1241
#
#
# Count 1242
#
#
# Saved: frames\frame_0543.jpg
# Count 1243
#
#
# Saved: frames\frame_0544.jpg
# Count 1244
#
#
# Count 1245
#
#
# Saved: frames\frame_0545.jpg
# Count 1246
#
#
# Count 1247
#
#
# Saved: frames\frame_0546.jpg
# Count 1248
#
#
# Count 1249
#
#
# Count 1250
#
#
# Saved: frames\frame_0547.jpg
# Count 1251
#
#
# Saved: frames\frame_0548.jpg
# Count 1252
#
#
# Count 1253
#
#
# Saved: frames\frame_0549.jpg
# Count 1254
#
#
# Count 1255
#
#
# Saved: frames\frame_0550.jpg
# Count 1256
#
#
# Count 1257
#
#
# Saved: frames\frame_0551.jpg
# Count 1258
#
#
# Count 1259
#
#
# Saved: frames\frame_0552.jpg
# Count 1260
#
#
# Count 1261
#
#
# Saved: frames\frame_0553.jpg
# Count 1262
#
#
# Count 1263
#
#
# Saved: frames\frame_0554.jpg
# Count 1264
#
#
# Count 1265
#
#
# Saved: frames\frame_0555.jpg
# Count 1266
#
#
# Count 1267
#
#
# Saved: frames\frame_0556.jpg
# Count 1268
#
#
# Count 1269
#
#
# Saved: frames\frame_0557.jpg
# Count 1270
#
#
# Count 1271
#
#
# Saved: frames\frame_0558.jpg
# Count 1272
#
#
# Saved: frames\frame_0559.jpg
# Count 1273
#
#
# Count 1274
#
#
# Saved: frames\frame_0560.jpg
# Count 1275
#
#
# Count 1276
#
#
# Saved: frames\frame_0561.jpg
# Count 1277
#
#
# Count 1278
#
#
# Saved: frames\frame_0562.jpg
# Count 1279
#
#
# Count 1280
#
#
# Saved: frames\frame_0563.jpg
# Count 1281
#
#
# Saved: frames\frame_0564.jpg
# Count 1282
#
#
# Count 1283
#
#
# Saved: frames\frame_0565.jpg
# Count 1284
#
#
# Count 1285
#
#
# Saved: frames\frame_0566.jpg
# Count 1286
#
#
# Count 1287
#
#
# Saved: frames\frame_0567.jpg
# Count 1288
#
#
# Saved: frames\frame_0568.jpg
# Count 1289
#
#
# Count 1290
#
#
# Saved: frames\frame_0569.jpg
# Count 1291
#
#
# Count 1292
#
#
# Saved: frames\frame_0570.jpg
# Count 1293
#
#
# Saved: frames\frame_0571.jpg
# Count 1294
#
#
# Count 1295
#
#
# Saved: frames\frame_0572.jpg
# Count 1296
#
#
# Count 1297
#
#
# Saved: frames\frame_0573.jpg
# Count 1298
#
#
# Saved: frames\frame_0574.jpg
# Count 1299
#
#
# Count 1300
#
#
# Saved: frames\frame_0575.jpg
# Count 1301
#
#
# Count 1302
#
#
# Saved: frames\frame_0576.jpg
# Count 1303
#
#
# Count 1304
#
#
# Saved: frames\frame_0577.jpg
# Count 1305
#
#
# Count 1306
#
#
# Saved: frames\frame_0578.jpg
# Count 1307
#
#
# Count 1308
#
#
# Saved: frames\frame_0579.jpg
# Count 1309
#
#
# Count 1310
#
#
# Saved: frames\frame_0580.jpg
# Count 1311
#
#
# Saved: frames\frame_0581.jpg
# Count 1312
#
#
# Count 1313
#
#
# Saved: frames\frame_0582.jpg
# Count 1314
#
#
# Count 1315
#
#
# Saved: frames\frame_0583.jpg
# Count 1316
#
#
# Count 1317
#
#
# Saved: frames\frame_0584.jpg
# Count 1318
#
#
# Count 1319
#
#
# Saved: frames\frame_0585.jpg
# Count 1320
#
#
# Count 1321
#
#
# Saved: frames\frame_0586.jpg
# Count 1322
#
#
# Count 1323
#
#
# Saved: frames\frame_0587.jpg
# Count 1324
#
#
# Count 1325
#
#
# Saved: frames\frame_0588.jpg
# Count 1326
#
#
# Count 1327
#
#
# Saved: frames\frame_0589.jpg
# Count 1328
#
#
# Count 1329
#
#
# Saved: frames\frame_0590.jpg
# Count 1330
#
#
# Count 1331
#
#
# Saved: frames\frame_0591.jpg
# Count 1332
#
#
# Count 1333
#
#
# Saved: frames\frame_0592.jpg
# Count 1334
#
#
# Count 1335
#
#
# Saved: frames\frame_0593.jpg
# Count 1336
#
#
# Count 1337
#
#
# Saved: frames\frame_0594.jpg
# Count 1338
#
#
# Saved: frames\frame_0595.jpg
# Count 1339
#
#
# Saved: frames\frame_0596.jpg
# Count 1340
#
#
# Count 1341
#
#
# Saved: frames\frame_0597.jpg
# Count 1342
#
#
# Count 1343
#
#
# Saved: frames\frame_0598.jpg
# Count 1344
#
#
# Count 1345
#
#
# Saved: frames\frame_0599.jpg
# Count 1346
#
#
# Count 1347
#
#
# Saved: frames\frame_0600.jpg
# Count 1348
#
#
# Saved: frames\frame_0601.jpg
# Count 1349
#
#
# Count 1350
#
#
# Saved: frames\frame_0602.jpg
# Count 1351
#
#
# Saved: frames\frame_0603.jpg
# Count 1352
#
#
# Count 1353
#
#
# Saved: frames\frame_0604.jpg
# Count 1354
#
#
# Count 1355
#
#
# Saved: frames\frame_0605.jpg
# Count 1356
#
#
# Saved: frames\frame_0606.jpg
# Count 1357
#
#
# Count 1358
#
#
# Saved: frames\frame_0607.jpg
# Count 1359
#
#
# Count 1360
#
#
# Saved: frames\frame_0608.jpg
# Count 1361
#
#
# Saved: frames\frame_0609.jpg
# Count 1362
#
#
# Count 1363
#
#
# Saved: frames\frame_0610.jpg
# Count 1364
#
#
# Count 1365
#
#
# Saved: frames\frame_0611.jpg
# Count 1366
#
#
# Saved: frames\frame_0612.jpg
# Count 1367
#
#
# Saved: frames\frame_0613.jpg
# Count 1368
#
#
# Count 1369
#
#
# Saved: frames\frame_0614.jpg
# Count 1370
#
#
# Saved: frames\frame_0615.jpg
# Count 1371
#
#
# Count 1372
#
#
# Saved: frames\frame_0616.jpg
# Count 1373
#
#
# Count 1374
#
#
# Saved: frames\frame_0617.jpg
# Count 1375
#
#
# Count 1376
#
#
# Saved: frames\frame_0618.jpg
# Count 1377
#
#
# Count 1378
#
#
# Saved: frames\frame_0619.jpg
# Count 1379
#
#
# Count 1380
#
#
# Saved: frames\frame_0620.jpg
# Count 1381
#
#
# Count 1382
#
#
# Saved: frames\frame_0621.jpg
# Count 1383
#
#
# Count 1384
#
#
# Saved: frames\frame_0622.jpg
# Count 1385
#
#
# Count 1386
#
#
# Saved: frames\frame_0623.jpg
# Count 1387
#
#
# Count 1388
#
#
# Saved: frames\frame_0624.jpg
# Count 1389
#
#
# Count 1390
#
#
# Saved: frames\frame_0625.jpg
# Count 1391
#
#
# Count 1392
#
#
# Saved: frames\frame_0626.jpg
# Count 1393
#
#
# Count 1394
#
#
# Saved: frames\frame_0627.jpg
# Count 1395
#
#
# Count 1396
#
#
# Saved: frames\frame_0628.jpg
# Count 1397
#
#
# Count 1398
#
#
# Saved: frames\frame_0629.jpg
# Count 1399
#
#
# Count 1400
#
#
# Count 1401
#
#
# Saved: frames\frame_0630.jpg
# Count 1402
#
#
# Count 1403
#
#
# Saved: frames\frame_0631.jpg
# Count 1404
#
#
# Count 1405
#
#
# Saved: frames\frame_0632.jpg
# Count 1406
#
#
# Saved: frames\frame_0633.jpg
# Count 1407
#
#
# Count 1408
#
#
# Saved: frames\frame_0634.jpg
# Count 1409
#
#
# Count 1410
#
#
# Saved: frames\frame_0635.jpg
# Count 1411
#
#
# Count 1412
#
#
# Saved: frames\frame_0636.jpg
# Count 1413
#
#
# Count 1414
#
#
# Saved: frames\frame_0637.jpg
# Count 1415
#
#
# Saved: frames\frame_0638.jpg
# Count 1416
#
#
# Count 1417
#
#
# Saved: frames\frame_0639.jpg
# Count 1418
#
#
# Count 1419
#
#
# Saved: frames\frame_0640.jpg
# Count 1420
#
#
# Count 1421
#
#
# Saved: frames\frame_0641.jpg
# Count 1422
#
#
# Count 1423
#
#
# Saved: frames\frame_0642.jpg
# Count 1424
#
#
# Count 1425
#
#
# Saved: frames\frame_0643.jpg
# Count 1426
#
#
# Count 1427
#
#
# Saved: frames\frame_0644.jpg
# Count 1428
#
#
# Count 1429
#
#
# Saved: frames\frame_0645.jpg
# Count 1430
#
#
# Count 1431
#
#
# Saved: frames\frame_0646.jpg
# Count 1432
#
#
# Count 1433
#
#
# Saved: frames\frame_0647.jpg
# Count 1434
#
#
# Saved: frames\frame_0648.jpg
# Count 1435
#
#
# Count 1436
#
#
# Saved: frames\frame_0649.jpg
# Count 1437
#
#
# Count 1438
#
#
# Saved: frames\frame_0650.jpg
# Count 1439
#
#
# Saved: frames\frame_0651.jpg
# Count 1440
#
#
# Saved: frames\frame_0652.jpg
# Count 1441
#
#
# Count 1442
#
#
# Saved: frames\frame_0653.jpg
# Count 1443
#
#
# Count 1444
#
#
# Saved: frames\frame_0654.jpg
# Count 1445
#
#
# Count 1446
#
#
# Saved: frames\frame_0655.jpg
# Count 1447
#
#
# Count 1448
#
#
# Count 1449
#
#
# Saved: frames\frame_0656.jpg
# Count 1450
#
#
# Count 1451
#
#
# Saved: frames\frame_0657.jpg
# Count 1452
#
#
# Count 1453
#
#
# Saved: frames\frame_0658.jpg
# Count 1454
#
#
# Saved: frames\frame_0659.jpg
# Count 1455
#
#
# Saved: frames\frame_0660.jpg
# Count 1456
#
#
# Saved: frames\frame_0661.jpg
# Count 1457
#
#
# Saved: frames\frame_0662.jpg
# Count 1458
#
#
# Count 1459
#
#
# Saved: frames\frame_0663.jpg
# Count 1460
#
#
# Saved: frames\frame_0664.jpg
# Count 1461
#
#
# Count 1462
#
#
# Saved: frames\frame_0665.jpg
# Count 1463
#
#
# Saved: frames\frame_0666.jpg
# Count 1464
#
#
# Count 1465
#
#
# Saved: frames\frame_0667.jpg
# Count 1466
#
#
# Saved: frames\frame_0668.jpg
# Count 1467
#
#
# Count 1468
#
#
# Saved: frames\frame_0669.jpg
# Count 1469
#
#
# Count 1470
#
#
# Saved: frames\frame_0670.jpg
# Count 1471
#
#
# Count 1472
#
#
# Saved: frames\frame_0671.jpg
# Count 1473
#
#
# Saved: frames\frame_0672.jpg
# Count 1474
#
#
# Count 1475
#
#
# Saved: frames\frame_0673.jpg
# Count 1476
#
#
# Count 1477
#
#
# Saved: frames\frame_0674.jpg
# Count 1478
#
#
# Saved: frames\frame_0675.jpg
# Count 1479
#
#
# Count 1480
#
#
# Saved: frames\frame_0676.jpg
# Count 1481
#
#
# Saved: frames\frame_0677.jpg
# Count 1482
#
#
# Count 1483
#
#
# Saved: frames\frame_0678.jpg
# Count 1484
#
#
# Count 1485
#
#
# Saved: frames\frame_0679.jpg
# Count 1486
#
#
# Saved: frames\frame_0680.jpg
# Count 1487
#
#
# Count 1488
#
#
# Saved: frames\frame_0681.jpg
# Count 1489
#
#
# Count 1490
#
#
# Saved: frames\frame_0682.jpg
# Count 1491
#
#
# Saved: frames\frame_0683.jpg
# Count 1492
#
#
# Count 1493
#
#
# Saved: frames\frame_0684.jpg
# Count 1494
#
#
# Saved: frames\frame_0685.jpg
# Count 1495
#
#
# Saved: frames\frame_0686.jpg
# Count 1496
#
#
# Count 1497
#
#
# Saved: frames\frame_0687.jpg
# Count 1498
#
#
# Count 1499
#
#
# Saved: frames\frame_0688.jpg
# Count 1500
#
#
# Saved: frames\frame_0689.jpg
# Count 1501
#
#
# Count 1502
#
#
# Saved: frames\frame_0690.jpg
# Count 1503
#
#
# Saved: frames\frame_0691.jpg
# Count 1504
#
#
# Count 1505
#
#
# Saved: frames\frame_0692.jpg
# Count 1506
#
#
# Count 1507
#
#
# Saved: frames\frame_0693.jpg
# Count 1508
#
#
# Saved: frames\frame_0694.jpg
# Count 1509
#
#
# Saved: frames\frame_0695.jpg
# Count 1510
#
#
# Saved: frames\frame_0696.jpg
# Count 1511
#
#
# Saved: frames\frame_0697.jpg
# Count 1512
#
#
# Saved: frames\frame_0698.jpg
# Count 1513
#
#
# Saved: frames\frame_0699.jpg
# Count 1514
#
#
# Saved: frames\frame_0700.jpg
# Count 1515
#
#
# Saved: frames\frame_0701.jpg
# Count 1516
#
#
# Saved: frames\frame_0702.jpg
# Count 1517
#
#
# Saved: frames\frame_0703.jpg
# Count 1518
#
#
# Saved: frames\frame_0704.jpg
# Count 1519
#
#
# Saved: frames\frame_0705.jpg
# Count 1520
#
#
# Saved: frames\frame_0706.jpg
# Count 1521
#
#
# Saved: frames\frame_0707.jpg
# Count 1522
#
#
# Count 1523
#
#
# Saved: frames\frame_0708.jpg
# Count 1524
#
#
# Saved: frames\frame_0709.jpg
# Count 1525
#
#
# Saved: frames\frame_0710.jpg
# Count 1526
#
#
# Saved: frames\frame_0711.jpg
# Count 1527
#
#
# Count 1528
#
#
# Saved: frames\frame_0712.jpg
# Count 1529
#
#
# Saved: frames\frame_0713.jpg
# Count 1530
#
#
# Saved: frames\frame_0714.jpg
# Count 1531
#
#
# Count 1532
#
#
# Saved: frames\frame_0715.jpg
# Count 1533
#
#
# Count 1534
#
#
# Saved: frames\frame_0716.jpg
# Count 1535
#
#
# Count 1536
#
#
# Saved: frames\frame_0717.jpg
# Count 1537
#
#
# Count 1538
#
#
# Saved: frames\frame_0718.jpg
# Count 1539
#
#
# Saved: frames\frame_0719.jpg
# Count 1540
#
#
# Count 1541
#
#
# Saved: frames\frame_0720.jpg
# Count 1542
#
#
# Saved: frames\frame_0721.jpg
# Count 1543
#
#
# Count 1544
#
#
# Saved: frames\frame_0722.jpg
# Count 1545
#
#
# Saved: frames\frame_0723.jpg
# Count 1546
#
#
# Count 1547
#
#
# Saved: frames\frame_0724.jpg
# Count 1548
#
#
# Count 1549
#
#
# Saved: frames\frame_0725.jpg
# Count 1550
#
#
# Count 1551
#
#
# Saved: frames\frame_0726.jpg
# Count 1552
#
#
# Count 1553
#
#
# Saved: frames\frame_0727.jpg
# Count 1554
#
#
# Count 1555
#
#
# Saved: frames\frame_0728.jpg
# Count 1556
#
#
# Count 1557
#
#
# Saved: frames\frame_0729.jpg
# Count 1558
#
#
# Saved: frames\frame_0730.jpg
# Count 1559
#
#
# Saved: frames\frame_0731.jpg
# Count 1560
#
#
# Count 1561
#
#
# Saved: frames\frame_0732.jpg
# Count 1562
#
#
# Saved: frames\frame_0733.jpg
# Count 1563
#
#
# Count 1564
#
#
# Saved: frames\frame_0734.jpg
# Count 1565
#
#
# Count 1566
#
#
# Saved: frames\frame_0735.jpg
# Count 1567
#
#
# Count 1568
#
#
# Saved: frames\frame_0736.jpg
# Count 1569
#
#
# Count 1570
#
#
# Count 1571
#
#
# Saved: frames\frame_0737.jpg
# Count 1572
#
#
# Saved: frames\frame_0738.jpg
# Count 1573
#
#
# Saved: frames\frame_0739.jpg
# Count 1574
#
#
# Count 1575
#
#
# Saved: frames\frame_0740.jpg
# Count 1576
#
#
# Count 1577
#
#
# Saved: frames\frame_0741.jpg
# Count 1578
#
#
# Saved: frames\frame_0742.jpg
# Count 1579
#
#
# Count 1580
#
#
# Saved: frames\frame_0743.jpg
# Count 1581
#
#
# Saved: frames\frame_0744.jpg
# Count 1582
#
#
# Count 1583
#
#
# Saved: frames\frame_0745.jpg
# Count 1584
#
#
# Count 1585
#
#
# Saved: frames\frame_0746.jpg
# Count 1586
#
#
# Count 1587
#
#
# Saved: frames\frame_0747.jpg
# Count 1588
#
#
# Saved: frames\frame_0748.jpg
# Count 1589
#
#
# Saved: frames\frame_0749.jpg
# Count 1590
#
#
# Count 1591
#
#
# Saved: frames\frame_0750.jpg
# Count 1592
#
#
# Count 1593
#
#
# Saved: frames\frame_0751.jpg
# Count 1594
#
#
# Count 1595
#
#
# Saved: frames\frame_0752.jpg
# Count 1596
#
#
# Count 1597
#
#
# Saved: frames\frame_0753.jpg
# Count 1598
#
#
# Count 1599
#
#
# Saved: frames\frame_0754.jpg
# Count 1600
#
#
# Count 1601
#
#
# Saved: frames\frame_0755.jpg
# Count 1602
#
#
# Count 1603
#
#
# Saved: frames\frame_0756.jpg
# Count 1604
#
#
# Saved: frames\frame_0757.jpg
# Count 1605
#
#
# Count 1606
#
#
# Saved: frames\frame_0758.jpg
# Count 1607
#
#
# Count 1608
#
#
# Saved: frames\frame_0759.jpg
# Count 1609
#
#
# Saved: frames\frame_0760.jpg
# Count 1610
#
#
# Saved: frames\frame_0761.jpg
# Count 1611
#
#
# Count 1612
#
#
# Saved: frames\frame_0762.jpg
# Count 1613
#
#
# Saved: frames\frame_0763.jpg
# Count 1614
#
#
# Saved: frames\frame_0764.jpg
# Count 1615
#
#
# Count 1616
#
#
# Saved: frames\frame_0765.jpg
# Count 1617
#
#
# Count 1618
#
#
# Saved: frames\frame_0766.jpg
# Count 1619
#
#
# Count 1620
#
#
# Saved: frames\frame_0767.jpg
# Count 1621
#
#
# Count 1622
#
#
# Saved: frames\frame_0768.jpg
# Count 1623
#
#
# Count 1624
#
#
# Saved: frames\frame_0769.jpg
# Count 1625
#
#
# Saved: frames\frame_0770.jpg
# Count 1626
#
#
# Count 1627
#
#
# Saved: frames\frame_0771.jpg
# Count 1628
#
#
# Count 1629
#
#
# Saved: frames\frame_0772.jpg
# Count 1630
#
#
# Count 1631
#
#
# Saved: frames\frame_0773.jpg
# Count 1632
#
#
# Saved: frames\frame_0774.jpg
# Count 1633
#
#
# Count 1634
#
#
# Saved: frames\frame_0775.jpg
# Count 1635
#
#
# Count 1636
#
#
# Saved: frames\frame_0776.jpg
# Count 1637
#
#
# Count 1638
#
#
# Saved: frames\frame_0777.jpg
# Count 1639
#
#
# Count 1640
#
#
# Count 1641
#
#
# Count 1642
#
#
# Count 1643
#
#
# Count 1644
#
#
# Saved: frames\frame_0778.jpg
# Count 1645
#
#
# Count 1646
#
#
# Saved: frames\frame_0779.jpg
# Count 1647
#
#
# Count 1648
#
#
# Saved: frames\frame_0780.jpg
# Count 1649
#
#
# Count 1650
#
#
# Saved: frames\frame_0781.jpg
# Count 1651
#
#
# Count 1652
#
#
# Saved: frames\frame_0782.jpg
# Count 1653
#
#
# Count 1654
#
#
# Saved: frames\frame_0783.jpg
# Count 1655
#
#
# Count 1656
#
#
# Saved: frames\frame_0784.jpg
# Count 1657
#
#
# Count 1658
#
#
# Saved: frames\frame_0785.jpg
# Count 1659
#
#
# Count 1660
#
#
# Count 1661
#
#
# Saved: frames\frame_0786.jpg
# Count 1662
#
#
# Count 1663
#
#
# Saved: frames\frame_0787.jpg
# Count 1664
#
#
# Count 1665
#
#
# Saved: frames\frame_0788.jpg
# Count 1666
#
#
# Count 1667
#
#
# Saved: frames\frame_0789.jpg
# Count 1668
#
#
# Count 1669
#
#
# Saved: frames\frame_0790.jpg
# Count 1670
#
#
# Count 1671
#
#
# Saved: frames\frame_0791.jpg
# Count 1672
#
#
# Count 1673
#
#
# Saved: frames\frame_0792.jpg
# Count 1674
#
#
# Count 1675
#
#
# Saved: frames\frame_0793.jpg
# Count 1676
#
#
# Count 1677
#
#
# Saved: frames\frame_0794.jpg
# Count 1678
#
#
# Saved: frames\frame_0795.jpg
# Count 1679
#
#
# Count 1680
#
#
# Saved: frames\frame_0796.jpg
# Count 1681
#
#
# Count 1682
#
#
# Saved: frames\frame_0797.jpg
# Count 1683
#
#
# Saved: frames\frame_0798.jpg
# Count 1684
#
#
# Count 1685
#
#
# Saved: frames\frame_0799.jpg
# Count 1686
#
#
# Count 1687
#
#
# Saved: frames\frame_0800.jpg
# Count 1688
#
#
# Count 1689
#
#
# Saved: frames\frame_0801.jpg
# Count 1690
#
#
# Count 1691
#
#
# Saved: frames\frame_0802.jpg
# Count 1692
#
#
# Saved: frames\frame_0803.jpg
# Count 1693
#
#
# Count 1694
#
#
# Saved: frames\frame_0804.jpg
# Count 1695
#
#
# Count 1696
#
#
# Saved: frames\frame_0805.jpg
# Count 1697
#
#
# Saved: frames\frame_0806.jpg
# Count 1698
#
#
# Count 1699
#
#
# Saved: frames\frame_0807.jpg
# Count 1700
#
#
# Count 1701
#
#
# Saved: frames\frame_0808.jpg
# Count 1702
#
#
# Count 1703
#
#
# Saved: frames\frame_0809.jpg
# Count 1704
#
#
# Count 1705
#
#
# Saved: frames\frame_0810.jpg
# Count 1706
#
#
# Count 1707
#
#
# Saved: frames\frame_0811.jpg
# Count 1708
#
#
# Count 1709
#
#
# Saved: frames\frame_0812.jpg
# Count 1710
#
#
# Count 1711
#
#
# Saved: frames\frame_0813.jpg
# Count 1712
#
#
# Saved: frames\frame_0814.jpg
# Count 1713
#
#
# Count 1714
#
#
# Saved: frames\frame_0815.jpg
# Count 1715
#
#
# Count 1716
#
#
# Saved: frames\frame_0816.jpg
# Count 1717
#
#
# Count 1718
#
#
# Saved: frames\frame_0817.jpg
# Count 1719
#
#
# Count 1720
#
#
# Saved: frames\frame_0818.jpg
# Count 1721
#
#
# Count 1722
#
#
# Saved: frames\frame_0819.jpg
# Count 1723
#
#
# Count 1724
#
#
# Saved: frames\frame_0820.jpg
# Count 1725
#
#
# Count 1726
#
#
# Saved: frames\frame_0821.jpg
# Count 1727
#
#
# Saved: frames\frame_0822.jpg
# Count 1728
#
#
# Count 1729
#
#
# Saved: frames\frame_0823.jpg
# Count 1730
#
#
# Count 1731
#
#
# Count 1732
#
#
# Saved: frames\frame_0824.jpg
# Count 1733
#
#
# Count 1734
#
#
# Saved: frames\frame_0825.jpg
# Count 1735
#
#
# Count 1736
#
#
# Saved: frames\frame_0826.jpg
# Count 1737
#
#
# Count 1738
#
#
# Saved: frames\frame_0827.jpg
# Count 1739
#
#
# Count 1740
#
#
# Saved: frames\frame_0828.jpg
# Count 1741
#
#
# Count 1742
#
#
# Saved: frames\frame_0829.jpg
# Count 1743
#
#
# Count 1744
#
#
# Saved: frames\frame_0830.jpg
# Count 1745
#
#
# Count 1746
#
#
# Saved: frames\frame_0831.jpg
# Count 1747
#
#
# Count 1748
#
#
# Saved: frames\frame_0832.jpg
# Count 1749
#
#
# Count 1750
#
#
# Saved: frames\frame_0833.jpg
# Count 1751
#
#
# Count 1752
#
#
# Saved: frames\frame_0834.jpg
# Count 1753
#
#
# Count 1754
#
#
# Saved: frames\frame_0835.jpg
# Count 1755
#
#
# Saved: frames\frame_0836.jpg
# Count 1756
#
#
# Count 1757
#
#
# Saved: frames\frame_0837.jpg
# Count 1758
#
#
# Count 1759
#
#
# Saved: frames\frame_0838.jpg
# Count 1760
#
#
# Saved: frames\frame_0839.jpg
# Count 1761
#
#
# Saved: frames\frame_0840.jpg
# Count 1762
#
#
# Count 1763
#
#
# Saved: frames\frame_0841.jpg
# Count 1764
#
#
# Saved: frames\frame_0842.jpg
# Count 1765
#
#
# Count 1766
#
#
# Count 1767
#
#
# Saved: frames\frame_0843.jpg
# Count 1768
#
#
# Count 1769
#
#
# Saved: frames\frame_0844.jpg
# Count 1770
#
#
# Count 1771
#
#
# Saved: frames\frame_0845.jpg
# Count 1772
#
#
# Count 1773
#
#
# Saved: frames\frame_0846.jpg
# Count 1774
#
#
# Count 1775
#
#
# Saved: frames\frame_0847.jpg
# Count 1776
#
#
# Count 1777
#
#
# Saved: frames\frame_0848.jpg
# Count 1778
#
#
# Count 1779
#
#
# Saved: frames\frame_0849.jpg
# Count 1780
#
#
# Count 1781
#
#
# Saved: frames\frame_0850.jpg
# Count 1782
#
#
# Saved: frames\frame_0851.jpg
# Count 1783
#
#
# Count 1784
#
#
# Saved: frames\frame_0852.jpg
# Count 1785
#
#
# Count 1786
#
#
# Saved: frames\frame_0853.jpg
# Count 1787
#
#
# Count 1788
#
#
# Saved: frames\frame_0854.jpg
# Count 1789
#
#
# Count 1790
#
#
# Saved: frames\frame_0855.jpg
# Count 1791
#
#
# Count 1792
#
#
# Saved: frames\frame_0856.jpg
# Count 1793
#
#
# Count 1794
#
#
# Saved: frames\frame_0857.jpg
# Count 1795
#
#
# Count 1796
#
#
# Saved: frames\frame_0858.jpg
# Count 1797
#
#
# Count 1798
#
#
# Saved: frames\frame_0859.jpg
# Count 1799
#
#
# Count 1800
#
#
# Saved: frames\frame_0860.jpg
# Count 1801
#
#
# Count 1802
#
#
# Saved: frames\frame_0861.jpg
# Count 1803
#
#
# Count 1804
#
#
# Saved: frames\frame_0862.jpg
# Count 1805
#
#
# Count 1806
#
#
# Saved: frames\frame_0863.jpg
# Count 1807
#
#
# Saved: frames\frame_0864.jpg
# Count 1808
#
#
# Count 1809
#
#
# Saved: frames\frame_0865.jpg
# Count 1810
#
#
# Count 1811
#
#
# Saved: frames\frame_0866.jpg
# Count 1812
#
#
# Saved: frames\frame_0867.jpg
# Count 1813
#
#
# Count 1814
#
#
# Saved: frames\frame_0868.jpg
# Count 1815
#
#
# Saved: frames\frame_0869.jpg
# Count 1816
#
#
# Saved: frames\frame_0870.jpg
# Count 1817
#
#
# Count 1818
#
#
# Saved: frames\frame_0871.jpg
# Count 1819
#
#
# Count 1820
#
#
# Saved: frames\frame_0872.jpg
# Count 1821
#
#
# Count 1822
#
#
# Saved: frames\frame_0873.jpg
# Count 1823
#
#
# ...
#
#
# Count 2375
#
#
# Count 2376
#
#
# Count 2377
#
#
# Count 2378
#
#
# Count 2379
#
#
# Count 2380
#
#
# Count 2381
#
#
# Count 2382
#
#
# Count 2383
#
#
# Count 2384
#
#
# Count 2385
#
#
# Count 2386
#
#
# Count 2387
#
#
# Count 2388
#
#
# Count 2389
#
#
# Count 2390
#
#
# Count 2391
#
#
# Count 2392
#
#
# Count 2393
#
#
# Count 2394
#
#
# Count 2395
#
#
# Count 2396
#
#
# Count 2397
#
#
# Count 2398
#
#
# Count 2399
#
#
# Count 2400
#
#
# Count 2401
#
#
# Count 2402
#
#
# Count 2403
#
#
# Count 2404
#
#
# Count 2405
#
#
# Count 2406
#
#
# Count 2407
#
#
# Count 2408
#
#
# Count 2409
#
#
# Count 2410
#
#
# Count 2411
#
#
# Count 2412
#
#
# Count 2413
#
#
# Count 2414
#
#
# Count 2415
#
#
# Count 2416
#
#
# Count 2417
#
#
# Count 2418
#
#
# Count 2419
#
#
# Count 2420
#
#
# Count 2421
#
#
# Count 2422
#
#
# Count 2423
#
#
# Count 2424
#
#
# Count 2425
#
#
# Count 2426
#
#
# Count 2427
#
#
# Count 2428
#
#
# Count 2429
#
#
# Count 2430
#
#
# Count 2431
#
#
# Count 2432
#
#
# Count 2433
#
#
# Count 2434
#
#
# Count 2435
#
#
# Count 2436
#
#
# Count 2437
#
#
# Count 2438
#
#
# Count 2439
#
#
# Count 2440
#
#
# Count 2441
#
#
# Count 2442
#
#
# Count 2443
#
#
# Count 2444
#
#
# Count 2445
#
#
# Count 2446
#
#
# Count 2447
#
#
# Count 2448
#
#
# Count 2449
#
#
# Count 2450
#
#
# Count 2451
#
#
# Count 2452
#
#
# Count 2453
#
#
# Count 2454
#
#
# Count 2455
#
#
# Count 2456
#
#
# Count 2457
#
#
# Count 2458
#
#
# Count 2459
#
#
# Count 2460
#
#
# Count 2461
#
#
# Count 2462
#
#
# Count 2463
#
#
# Count 2464
#
#
# Count 2465
#
#
# Count 2466
#
#
# Count 2467
#
#
# Count 2468
#
#
# Count 2469
#
#
# Count 2470
#
#
# Count 2471
#
#
# Count 2472
#
#
# Count 2473
#
#
# Count 2474
#
#
# Count 2475
#
#
# Count 2476
#
#
# Count 2477
#
#
# Count 2478
#
#
# Count 2479
#
#
# Count 2480
#
#
# Count 2481
#
#
# Count 2482
#
#
# Count 2483
#
#
# Count 2484
#
#
# Count 2485
#
#
# Count 2486
#
#
# Count 2487
#
#
# Count 2488
#
#
# Count 2489
#
#
# Count 2490
#
#
# Count 2491
#
#
# Count 2492
#
#
# Count 2493
#
#
# Count 2494
#
#
# Count 2495
#
#
# Count 2496
#
#
# Count 2497
#
#
# Count 2498
#
#
# Count 2499
#
#
# Count 2500
#
#
# Count 2501
#
#
# Count 2502
#
#
# Count 2503
#
#
# Count 2504
#
#
# Count 2505
#
#
# Count 2506
#
#
# Count 2507
#
#
# Count 2508
#
#
# Count 2509
#
#
# Count 2510
#
#
# Count 2511
#
#
# Count 2512
#
#
# Count 2513
#
#
# Count 2514
#
#
# Count 2515
#
#
# Count 2516
#
#
# Count 2517
#
#
# Count 2518
#
#
# Count 2519
#
#
# Count 2520
#
#
# Count 2521
#
#
# Count 2522
#
#
# Count 2523
#
#
# Count 2524
#
#
# Count 2525
#
#
# Count 2526
#
#
# Count 2527
#
#
# Count 2528
#
#
# Count 2529
#
#
# Count 2530
#
#
# Count 2531
#
#
# Count 2532
#
#
# Count 2533
#
#
# Count 2534
#
#
# Count 2535
#
#
# Count 2536
#
#
# Count 2537
#
#
# Count 2538
#
#
# Count 2539
#
#
# Count 2540
#
#
# Count 2541
#
#
# Count 2542
#
#
# Count 2543
#
#
# Count 2544
#
#
# Count 2545
#
#
# Count 2546
#
#
# Count 2547
#
#
# Count 2548
#
#
# Count 2549
#
#
# Count 2550
#
#
# Count 2551
#
#
# Count 2552
#
#
# Count 2553
#
#
# Count 2554
#
#
# Count 2555
#
#
# Count 2556
#
#
# Count 2557
#
#
# Count 2558
#
#
# Count 2559
#
#
# Count 2560
#
#
# Count 2561
#
#
# Count 2562
#
#
# Count 2563
#
#
# Count 2564
#
#
# Count 2565
#
#
# Count 2566
#
#
# Count 2567
#
#
# Count 2568
#
#
# Count 2569
#
#
# Count 2570
#
#
# Count 2571
#
#
# Count 2572
#
#
# Count 2573
#
#
# Count 2574
#
#
# Count 2575
#
#
# Count 2576
#
#
# Count 2577
#
#
# Count 2578
#
#
# Count 2579
#
#
# Count 2580
#
#
# Count 2581
#
#
# Count 2582
#
#
# Count 2583
#
#
# Count 2584
#
#
# Count 2585
#
#
# Count 2586
#
#
# Count 2587
#
#
# Count 2588
#
#
# Count 2589
#
#
# Count 2590
#
#
# Count 2591
#
#
# Count 2592
#
#
# Count 2593
#
#
# Count 2594
#
#
# Count 2595
#
#
# Count 2596
#
#
# Count 2597
#
#
# Count 2598
#
#
# Count 2599
#
#
# Count 2600
#
#
# Count 2601
#
#
# Count 2602
#
#
# Count 2603
#
#
# Count 2604
#
#
# Count 2605
#
#
# Count 2606
#
#
# Count 2607
#
#
# Count 2608
#
#
# Count 2609
#
#
# Count 2610
#
#
# Count 2611
#
#
# Count 2612
#
#
# Count 2613
#
#
# Count 2614
#
#
# Count 2615
#
#
# Count 2616
#
#
# Count 2617
#
#
# Count 2618
#
#
# Count 2619
#
#
# Count 2620
#
#
# Count 2621
#
#
# Count 2622
#
#
# Count 2623
#
#
# Count 2624
#
#
# Count 2625
#
#
# Count 2626
#
#
# Count 2627
#
#
# Count 2628
#
#
# Count 2629
#
#
# Count 2630
#
#
# Count 2631
#
#
# Count 2632
#
#
# Count 2633
#
#
# Count 2634
#
#
# Count 2635
#
#
# Count 2636
#
#
# Count 2637
#
#
# Count 2638
#
#
# Count 2639
#
#
# Count 2640
#
#
# Count 2641
#
#
# Count 2642
#
#
# Count 2643
#
#
# Count 2644
#
#
# Count 2645
#
#
# Count 2646
#
#
# Count 2647
#
#
# Count 2648
#
#
# Count 2649
#
#
# Count 2650
#
#
# Count 2651
#
#
# Count 2652
#
#
# Count 2653
#
#
# Count 2654
#
#
# Count 2655
#
#
# Count 2656
#
#
# Count 2657
#
#
# Count 2658
#
#
# Count 2659
#
#
# Count 2660
#
#
# Count 2661
#
#
# Count 2662
#
#
# Count 2663
#
#
# Count 2664
#
#
# Count 2665
#
#
# Count 2666
#
#
# Count 2667
#
#
# Count 2668
#
#
# Count 2669
#
#
# Count 2670
#
#
# Count 2671
#
#
# Count 2672
#
#
# Count 2673
#
#
# Count 2674
#
#
# Count 2675
#
#
# Count 2676
#
#
# Count 2677
#
#
# Count 2678
#
#
# Count 2679
#
#
# Count 2680
#
#
# Count 2681
#
#
# Count 2682
#
#
# Count 2683
#
#
# Count 2684
#
#
# Count 2685
#
#
# Count 2686
#
#
# Count 2687
#
#
# Count 2688
#
#
# Count 2689
#
#
# Count 2690
#
#
# Count 2691
#
#
# Count 2692
#
#
# Count 2693
#
#
# Count 2694
#
#
# Count 2695
#
#
# Count 2696
#
#
# Count 2697
#
#
# Count 2698
#
#
# Count 2699
#
#
# Count 2700
#
#
# Count 2701
#
#
# Count 2702
#
#
# Count 2703
#
#
# Count 2704
#
#
# Count 2705
#
#
# Count 2706
#
#
# Count 2707
#
#
# Count 2708
#
#
# Count 2709
#
#
# Count 2710
#
#
# Count 2711
#
#
# Count 2712
#
#
# Count 2713
#
#
# Count 2714
#
#
# Count 2715
#
#
# Count 2716
#
#
# Count 2717
#
#
# Count 2718
#
#
# Count 2719
#
#
# Count 2720
#
#
# Count 2721
#
#
# Count 2722
#
#
# Count 2723
#
#
# Count 2724
#
#
# Count 2725
#
#
# Count 2726
#
#
# Count 2727
#
#
# Count 2728
#
#
# Count 2729
#
#
# Count 2730
#
#
# Count 2731
#
#
# Count 2732
#
#
# Count 2733
#
#
# Count 2734
#
#
# Count 2735
#
#
# Count 2736
#
#
# Count 2737
#
#
# Count 2738
#
#
# Count 2739
#
#
# Count 2740
#
#
# Count 2741
#
#
# Count 2742
#
#
# Count 2743
#
#
# Count 2744
#
#
# Count 2745
#
#
# Count 2746
#
#
# Count 2747
#
#
# Count 2748
#
#
# Count 2749
#
#
# Count 2750
#
#
# Count 2751
#
#
# Count 2752
#
#
# Count 2753
#
#
# Count 2754
#
#
# Count 2755
#
#
# Count 2756
#
#
# Count 2757
#
#
# Count 2758
#
#
# Count 2759
#
#
# Count 2760
#
#
# Count 2761
#
#
# Count 2762
#
#
# Count 2763
#
#
# Count 2764
#
#
# Count 2765
#
#
# Count 2766
#
#
# Count 2767
#
#
# Count 2768
#
#
# Count 2769
#
#
# Count 2770
#
#
# Count 2771
#
#
# Count 2772
#
#
# Count 2773
#
#
# Count 2774
#
#
# Count 2775
#
#
# Count 2776
#
#
# Count 2777
#
#
# Count 2778
#
#
# Count 2779
#
#
# Count 2780
#
#
# Count 2781
#
#
# Count 2782
#
#
# Count 2783
#
#
# Count 2784
#
#
# Count 2785
#
#
# Count 2786
#
#
# Count 2787
#
#
# Count 2788
#
#
# Count 2789
#
#
# Count 2790
#
#
# Count 2791
#
#
# Count 2792
#
#
# Count 2793
#
#
# Count 2794
#
#
# Count 2795
#
#
# Count 2796
#
#
# Count 2797
#
#
# Count 2798
#
#
# Count 2799
#
#
# Count 2800
#
#
# Count 2801
#
#
# Count 2802
#
#
# Count 2803
#
#
# Count 2804
#
#
# Count 2805
#
#
# Count 2806
#
#
# Count 2807
#
#
# Count 2808
#
#
# Count 2809
#
#
# Count 2810
#
#
# Count 2811
#
#
# Count 2812
#
#
# Count 2813
#
#
# Count 2814
#
#
# Count 2815
#
#
# Count 2816
#
#
# Count 2817
#
#
# Count 2818
#
#
# Count 2819
#
#
# Count 2820
#
#
# Count 2821
#
#
# Count 2822
#
#
# Count 2823
#
#
# Count 2824
#
#
# Count 2825
#
#
# Count 2826
#
#
# Count 2827
#
#
# Count 2828
#
#
# Count 2829
#
#
# Count 2830
#
#
# Count 2831
#
#
# Count 2832
#
#
# Count 2833
#
#
# Count 2834
#
#
# Count 2835
#
#
# Count 2836
#
#
# Count 2837
#
#
# Count 2838
#
#
# Count 2839
#
#
# Count 2840
#
#
# Count 2841
#
#
# Count 2842
#
#
# Count 2843
#
#
# Count 2844
#
#
# Count 2845
#
#
# Count 2846
#
#
# Count 2847
#
#
# Count 2848
#
#
# Count 2849
#
#
# Count 2850
#
#
# Count 2851
#
#
# Count 2852
#
#
# Count 2853
#
#
# Count 2854
#
#
# Count 2855
#
#
# Count 2856
#
#
# Count 2857
#
#
# Count 2858
#
#
# Count 2859
#
#
# Count 2860
#
#
# Count 2861
#
#
# Count 2862
#
#
# Count 2863
#
#
# Count 2864
#
#
# Count 2865
#
#
# Count 2866
#
#
# Count 2867
#
#
# Count 2868
#
#
# Count 2869
#
#
# Count 2870
#
#
# Count 2871
#
#
# Count 2872
#
#
# Count 2873
#
#
# Count 2874
#
#
# Count 2875
#
#
# Count 2876
#
#
# Count 2877
#
#
# Count 2878
#
#
# Count 2879
#
#
# Count 2880
#
#
# Count 2881
#
#
# Count 2882
#
#
# Count 2883
#
#
# Count 2884
#
#
# Count 2885
#
#
# Count 2886
#
#
# Count 2887
#
#
# Count 2888
#
#
# Count 2889
#
#
# Count 2890
#
#
# Count 2891
#
#
# Count 2892
#
#
# Count 2893
#
#
# Count 2894
#
#
# Count 2895
#
#
# Count 2896
#
#
# Count 2897
#
#
# Count 2898
#
#
# Count 2899
#
#
# Count 2900
#
#
# Count 2901
#
#
# Count 2902
#
#
# Count 2903
#
#
# Count 2904
#
#
# Count 2905
#
#
# Count 2906
#
#
# Count 2907
#
#
# Count 2908
#
#
# Count 2909
#
#
# Count 2910
#
#
# Count 2911
#
#
# Count 2912
#
#
# Count 2913
#
#
# Count 2914
#
#
# Count 2915
#
#
# Count 2916
#
#
# Count 2917
#
#
# Count 2918
#
#
# Count 2919
#
#
# Count 2920
#
#
# Count 2921
#
#
# Count 2922
#
#
# Count 2923
#
#
# Count 2924
#
#
# Count 2925
#
#
# Count 2926
#
#
# Count 2927
#
#
# Count 2928
#
#
# Count 2929
#
#
# Count 2930
#
#
# Count 2931
#
#
# Count 2932
#
#
# Count 2933
#
#
# Count 2934
#
#
# Count 2935
#
#
# Count 2936
#
#
# Count 2937
#
#
# Count 2938
#
#
# Count 2939
#
#
# Count 2940
#
#
# Count 2941
#
#
# Count 2942
#
#
# Count 2943
#
#
# Count 2944
#
#
# Count 2945
#
#
# Count 2946
#
#
# Count 2947
#
#
# Count 2948
#
#
# Count 2949
#
#
# Count 2950
#
#
# Count 2951
#
#
# Count 2952
#
#
# Count 2953
#
#
# Count 2954
#
#
# Count 2955
#
#
# Count 2956
#
#
# Count 2957
#
#
# Count 2958
#
#
# Count 2959
#
#
# Count 2960
#
#
# Count 2961
#
#
# Count 2962
#
#
# Count 2963
#
#
# Count 2964
#
#
# Count 2965
#
#
# Count 2966
#
#
# Count 2967
#
#
# Count 2968
#
#
# Count 2969
#
#
# Count 2970
#
#
# Count 2971
#
#
# Count 2972
#
#
# Count 2973
#
#
# Count 2974
#
#
# Count 2975
#
#
# Count 2976
#
#
# Count 2977
#
#
# Count 2978
#
#
# Count 2979
#
#
# Count 2980
#
#
# Count 2981
#
#
# Count 2982
#
#
# Count 2983
#
#
# Count 2984
#
#
# Count 2985
#
#
# Count 2986
#
#
# Count 2987
#
#
# Count 2988
#
#
# Count 2989
#
#
# Count 2990
#
#
# Count 2991
#
#
# Count 2992
#
#
# Count 2993
#
#
# Count 2994
#
#
# Count 2995
#
#
# Count 2996
#
#
# Count 2997
#
#
# Count 2998
#
#
# Count 2999
#
#
# Count 3000
#
#
# Count 3001
#
#
# Count 3002
#
#
# Count 3003
#
#
# Count 3004
#
#
# Count 3005
#
#
# Count 3006
#
#
# Count 3007
#
#
# Count 3008
#
#
# Count 3009
#
#
# Count 3010
#
#
# Count 3011
#
#
# Count 3012
#
#
# Count 3013
#
#
# Count 3014
#
#
# Count 3015
#
#
# Count 3016
#
#
# Count 3017
#
#
# Count 3018
#
#
# Count 3019
#
#
# Count 3020
#
#
# Count 3021
#
#
# Count 3022
#
#
# Count 3023
#
#
# Count 3024
#
#
# Count 3025
#
#
# Count 3026
#
#
# Count 3027
#
#
# Count 3028
#
#
# Count 3029
#
#
# Count 3030
#
#
# Count 3031
#
#
# Count 3032
#
#
# Count 3033
#
#
# Count 3034
#
#
# Count 3035
#
#
# Count 3036
#
#
# Count 3037
#
#
# Count 3038
#
#
# Count 3039
#
#
# Count 3040
#
#
# Count 3041
#
#
# Count 3042
#
#
# Count 3043
#
#
# Count 3044
#
#
# Count 3045
#
#
# Count 3046
#
#
# Count 3047
#
#
# Count 3048
#
#
# Count 3049
#
#
# Count 3050
#
#
# Count 3051
#
#
# Count 3052
#
#
# Count 3053
#
#
# Count 3054
#
#
# Count 3055
#
#
# Count 3056
#
#
# Count 3057
#
#
# Count 3058
#
#
# Count 3059
#
#
# Count 3060
#
#
# Count 3061
#
#
# Count 3062
#
#
# Count 3063
#
#
# Count 3064
#
#
# Count 3065
#
#
# Count 3066
#
#
# Count 3067
#
#
# Count 3068
#
#
# Count 3069
#
#
# Count 3070
#
#
# Count 3071
#
#
# Count 3072
#
#
# Count 3073
#
#
# Count 3074
#
#
# Count 3075
#
#
# Count 3076
#
#
# Count 3077
#
#
# Count 3078
#
#
# Count 3079
#
#
# Count 3080
#
#
# Count 3081
#
#
# Count 3082
#
#
# Count 3083
#
#
# Count 3084
#
#
# Count 3085
#
#
# Count 3086
#
#
# Count 3087
#
#
# Count 3088
#
#
# Count 3089
#
#
# Count 3090
#
#
# Count 3091
#
#
# Count 3092
#
#
# Count 3093
#
#
# Count 3094
#
#
# Count 3095
#
#
# Count 3096
#
#
# Count 3097
#
#
# Count 3098
#
#
# Count 3099
#
#
# Count 3100
#
#
# Count 3101
#
#
# Count 3102
#
#
# Count 3103
#
#
# Count 3104
#
#
# Count 3105
#
#
# Count 3106
#
#
# Count 3107
#
#
# Count 3108
#
#
# Count 3109
#
#
# Count 3110
#
#
# Count 3111
#
#
# Count 3112
#
#
# Count 3113
#
#
# Count 3114
#
#
# Count 3115
#
#
# Count 3116
#
#
# Count 3117
#
#
# Count 3118
#
#
# Count 3119
#
#
# Count 3120
#
#
# Count 3121
#
#
# Count 3122
#
#
# Count 3123
#
#
# Count 3124
#
#
# Count 3125
#
#
# Count 3126
#
#
# Count 3127
#
#
# Count 3128
#
#
# Count 3129
#
#
# Count 3130
#
#
# Count 3131
#
#
# Count 3132
#
#
# Count 3133
#
#
# Count 3134
#
#
# Count 3135
#
#
# Count 3136
#
#
# Count 3137
#
#
# Count 3138
#
#
# Count 3139
#
#
# Count 3140
#
#
# Count 3141
#
#
# Count 3142
#
#
# Count 3143
#
#
# Count 3144
#
#
# Count 3145
#
#
# Count 3146
#
#
# Count 3147
#
#
# Count 3148
#
#
# Count 3149
#
#
# Count 3150
#
#
# Count 3151
#
#
# Count 3152
#
#
# Count 3153
#
#
# Count 3154
#
#
# Count 3155
#
#
# Count 3156
#
#
# Count 3157
#
#
# Count 3158
#
#
# Count 3159
#
#
# Count 3160
#
#
# Count 3161
#
#
# Count 3162
#
#
# Count 3163
#
#
# Count 3164
#
#
# Count 3165
#
#
# Count 3166
#
#
# Count 3167
#
#
# Count 3168
#
#
# Count 3169
#
#
# Count 3170
#
#
# Count 3171
#
#
# Count 3172
#
#
# Count 3173
#
#
# Count 3174
#
#
# Count 3175
#
#
# Count 3176
#
#
# Count 3177
#
#
# Count 3178
#
#
# Count 3179
#
#
# Count 3180
#
#
# Count 3181
#
#
# Count 3182
#
#
# Count 3183
#
#
# Count 3184
#
#
# Count 3185
#
#
# Count 3186
#
#
# Count 3187
#
#
# Count 3188
#
#
# Count 3189
#
#
# Count 3190
#
#
# Count 3191
#
#
# Count 3192
#
#
# Count 3193
#
#
# Count 3194
#
#
# Count 3195
#
#
# Count 3196
#
#
# Count 3197
#
#
# Count 3198
#
#
# Count 3199
#
#
# Count 3200
#
#
# Count 3201
#
#
# Count 3202
#
#
# Count 3203
#
#
# Count 3204
#
#
# Count 3205
#
#
# Count 3206
#
#
# Count 3207
#
#
# Count 3208
#
#
# Count 3209
#
#
# Count 3210
#
#
# Count 3211
#
#
# Count 3212
#
#
# Count 3213
#
#
# Count 3214
#
#
# Count 3215
#
#
# Count 3216
#
#
# Count 3217
#
#
# Count 3218
#
#
# Count 3219
#
#
# Count 3220
#
#
# Count 3221
#
#
# Count 3222
#
#
# Count 3223
#
#
# Count 3224
#
#
# Count 3225
#
#
# Count 3226
#
#
# Count 3227
#
#
# Count 3228
#
#
# Count 3229
#
#
# Count 3230
#
#
# Count 3231
#
#
# Count 3232
#
#
# Count 3233
#
#
# Count 3234
#
#
# Count 3235
#
#
# Count 3236
#
#
# Count 3237
#
#
# Count 3238
#
#
# Count 3239
#
#
# Count 3240
#
#
# Count 3241
#
#
# Count 3242
#
#
# Count 3243
#
#
# Count 3244
#
#
# Count 3245
#
#
# Count 3246
#
#
# Count 3247
#
#
# Count 3248
#
#
# Count 3249
#
#
# Count 3250
#
#
# Count 3251
#
#
# Count 3252
#
#
# Count 3253
#
#
# Count 3254
#
#
# Count 3255
#
#
# Count 3256
#
#
# Count 3257
#
#
# Count 3258
#
#
# Count 3259
#
#
# Count 3260
#
#
# Count 3261
#
#
# Count 3262
#
#
# Count 3263
#
#
# Count 3264
#
#
# Count 3265
#
#
# Count 3266
#
#
# Count 3267
#
#
# Count 3268
#
#
# Count 3269
#
#
# Count 3270
#
#
# Count 3271
#
#
# Count 3272
#
#
# Count 3273
#
#
# Count 3274
#
#
# Count 3275
#
#
# Count 3276
#
#
# Count 3277
#
#
# Count 3278
#
#
# Count 3279
#
#
# Count 3280
#
#
# Count 3281
#
#
# Count 3282
#
#
# Count 3283
#
#
# Count 3284
#
#
# Count 3285
#
#
# Count 3286
#
#
# Count 3287
#
#
# Count 3288
#
#
# Count 3289
#
#
# Count 3290
#
#
# Count 3291
#
#
# Count 3292
#
#
# Count 3293
#
#
# Count 3294
#
#
# Count 3295
#
#
# Count 3296
#
#
# Count 3297
#
#
# Count 3298
#
#
# Count 3299
#
#
# Count 3300
#
#
# Count 3301
#
#
# Count 3302
#
#
# Count 3303
#
#
# Count 3304
#
#
# Count 3305
#
#
# Count 3306
#
#
# Count 3307
#
#
# Count 3308
#
#
# Count 3309
#
#
# Count 3310
#
#
# Count 3311
#
#
# Count 3312
#
#
# Count 3313
#
#
# Count 3314
#
#
# Count 3315
#
#
# Count 3316
#
#
# Count 3317
#
#
# Count 3318
#
#
# Count 3319
#
#
# Count 3320
#
#
# Count 3321
#
#
# Count 3322
#
#
# Count 3323
#
#
# Count 3324
#
#
# Count 3325
#
#
# Count 3326
#
#
# Count 3327
#
#
# Count 3328
#
#
# Count 3329
#
#
# Count 3330
#
#
# Count 3331
#
#
# Count 3332
#
#
# Count 3333
#
#
# Count 3334
#
#
# Count 3335
#
#
# Count 3336
#
#
# Count 3337
#
#
# Count 3338
#
#
# Count 3339
#
#
# Count 3340
#
#
# Count 3341
#
#
# Count 3342
#
#
# Count 3343
#
#
# Count 3344
#
#
# Count 3345
#
#
# Count 3346
#
#
# Count 3347
#
#
# Count 3348
#
#
# Count 3349
#
#
# Count 3350
#
#
# Count 3351
#
#
# Count 3352
#
#
# Count 3353
#
#
# Count 3354
#
#
# Count 3355
#
#
# Count 3356
#
#
# Count 3357
#
#
# Count 3358
#
#
# Count 3359
#
#
# Count 3360
#
#
# Count 3361
#
#
# Count 3362
#
#
# Count 3363
#
#
# Count 3364
#
#
# Count 3365
#
#
# Count 3366
#
#
# Count 3367
#
#
# Count 3368
#
#
# Count 3369
#
#
# Count 3370
#
#
# Count 3371
#
#
# Count 3372
#
#
# Count 3373
#
#
# Count 3374
#
#
# Count 3375
#
#
# Count 3376
#
#
# Count 3377
#
#
# Count 3378
#
#
# Count 3379
#
#
# Count 3380
#
#
# Count 3381
#
#
# Count 3382
#
#
# Count 3383
#
#
# Count 3384
#
#
# Count 3385
#
#
# Count 3386
#
#
# Count 3387
#
#
# Count 3388
#
#
# Count 3389
#
#
# Count 3390
#
#
# Count 3391
#
#
# Count 3392
#
#
# Count 3393
#
#
# Count 3394
#
#
# Count 3395
#
#
# Count 3396
#
#
# Count 3397
#
#
# Count 3398
#
#
# Count 3399
#
#
# Count 3400
#
#
# Count 3401
#
#
# Count 3402
#
#
# Count 3403
#
#
# Count 3404
#
#
# Count 3405
#
#
# Count 3406
#
#
# Count 3407
#
#
# Count 3408
#
#
# Count 3409
#
#
# Count 3410
#
#
# Count 3411
#
#
# Count 3412
#
#
# Count 3413
#
#
# Count 3414
#
#
# Count 3415
#
#
# Count 3416
#
#
# Count 3417
#
#
# Count 3418
#
#
# Count 3419
#
#
# Count 3420
#
#
# Count 3421
#
#
# Count 3422
#
#
# Count 3423
#
#
# Count 3424
#
#
# Count 3425
#
#
# Count 3426
#
#
# Count 3427
#
#
# Count 3428
#
#
# Count 3429
#
#
# Count 3430
#
#
# Count 3431
#
#
# Count 3432
#
#
# Count 3433
#
#
# Count 3434
#
#
# Count 3435
#
#
# Count 3436
#
#
# Count 3437
#
#
# Count 3438
#
#
# Count 3439
#
#
# Count 3440
#
#
# Count 3441
#
#
# Count 3442
#
#
# Count 3443
#
#
# Count 3444
#
#
# Count 3445
#
#
# Count 3446
#
#
# Count 3447
#
#
# Count 3448
#
#
# Count 3449
#
#
# Count 3450
#
#
# Count 3451
#
#
# Count 3452
#
#
# Count 3453
#
#
# Count 3454
#
#
# Count 3455
#
#
# Count 3456
#
#
# Count 3457
#
#
# Count 3458
#
#
# Count 3459
#
#
# Count 3460
#
#
# Count 3461
#
#
# Count 3462
#
#
# Count 3463
#
#
# Count 3464
#
#
# Count 3465
#
#
# Count 3466
#
#
# Count 3467
#
#
# Count 3468
#
#
# Count 3469
#
#
# Count 3470
#
#
# Count 3471
#
#
# Count 3472
#
#
# Count 3473
#
#
# Count 3474
#
#
# Count 3475
#
#
# Count 3476
#
#
# Count 3477
#
#
# Count 3478
#
#
# Count 3479
#
#
# Count 3480
#
#
# Count 3481
#
#
# Count 3482
#
#
# Count 3483
#
#
# Count 3484
#
#
# Count 3485
#
#
# Count 3486
#
#
# Count 3487
#
#
# Count 3488
#
#
# Count 3489
#
#
# Count 3490
#
#
# Count 3491
#
#
# Count 3492
#
#
# Count 3493
#
#
# Count 3494
#
#
# Count 3495
#
#
# Count 3496
#
#
# Count 3497
#
#
# Count 3498
#
#
# Count 3499
#
#
# Count 3500
#
#
# Count 3501
#
#
# Count 3502
#
#
# Count 3503
#
#
# Count 3504
#
#
# Count 3505
#
#
# Count 3506
#
#
# Count 3507
#
#
# Count 3508
#
#
# Count 3509
#
#
# Count 3510
#
#
# Count 3511
#
#
# Count 3512
#
#
# Count 3513
#
#
# Count 3514
#
#
# Count 3515
#
#
# Count 3516
#
#
# Count 3517
#
#
# Count 3518
#
#
# Count 3519
#
#
# Count 3520
#
#
# Count 3521
#
#
# Count 3522
#
#
# Count 3523
#
#
# Count 3524
#
#
# Count 3525
#
#
# Count 3526
#
#
# Count 3527
#
#
# Count 3528
#
#
# Count 3529
#
#
# Count 3530
#
#
# Count 3531
#
#
# Count 3532
#
#
# Count 3533
#
#
# Count 3534
#
#
# Count 3535
#
#
# Count 3536
#
#
# Count 3537
#
#
# Count 3538
#
#
# Count 3539
#
#
# Count 3540
#
#
# Count 3541
#
#
# Count 3542
#
#
# Count 3543
#
#
# Count 3544
#
#
# Count 3545
#
#
# Count 3546
#
#
# Count 3547
#
#
# Count 3548
#
#
# Count 3549
#
#
# Count 3550
#
#
# Count 3551
#
#
# Count 3552
#
#
# Count 3553
#
#
# Count 3554
#
#
# Count 3555
#
#
# Count 3556
#
#
# Count 3557
#
#
# Count 3558
#
#
# Count 3559
#
#
# Count 3560
#
#
# Count 3561
#
#
# Count 3562
#
#
# Count 3563
#
#
# Count 3564
#
#
# Count 3565
#
#
# Count 3566
#
#
# Count 3567
#
#
# Count 3568
#
#
# Count 3569
#
#
# Count 3570
#
#
# Count 3571
#
#
# Count 3572
#
#
# Count 3573
#
#
# Count 3574
#
#
# Count 3575
#
#
# Count 3576
#
#
# Count 3577
#
#
# Count 3578
#
#
# Count 3579
#
#
# Count 3580
#
#
# Count 3581
#
#
# Count 3582
#
#
# Count 3583
#
#
# Count 3584
#
#
# Count 3585
#
#
# Count 3586
#
#
# Count 3587
#
#
# Count 3588
#
#
# Count 3589
#
#
# Count 3590
#
#
# Count 3591
#
#
# Count 3592
#
#
# Count 3593
#
#
# Count 3594
#
#
# Count 3595
#
#
# Count 3596
#
#
# Count 3597
#
#
# Count 3598
#
#
# Count 3599
#
#
# Count 3600
#
#
# Count 3601
#
#
# Count 3602
#
#
# Count 3603
#
#
# Count 3604
