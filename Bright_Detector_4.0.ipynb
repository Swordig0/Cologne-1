# %%
import os
import cv2
import numpy as np

# %%
def measure_brightness(frame):
    """
    Measures the brightness of an image by calculating the average pixel intensity.

    Args:
        frame (np.array): Input image in BGR format.

    Returns:
        float: Average brightness of the image.
    """
    gray = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)  # Convert to grayscale
    brightness = np.mean(gray)  # Compute the mean intensity
    return brightness

# %%
def crop_image(frame, x, y, w, h):
    """
    Crops a region of interest (ROI) from an image.

    Args:
        frame (np.array): Input image.
        x (int): X-coordinate of the top-left corner of the ROI.
        y (int): Y-coordinate of the top-left corner of the ROI.
        w (int): Width of the ROI.
        h (int): Height of the ROI.

    Returns:
        np.array: Cropped image.
    """
    return frame[y:y+h, x:x+w]

# %%
def process_brightness_batch(input_path, output_path):
    """
    Processes a batch of images, measures brightness, and saves results.

    Args:
        input_path (str): Path to the folder containing input images.
        output_path (str): Path to save results.
    """
    if not os.path.exists(output_path):
        os.makedirs(output_path)  # Create the output directory if it doesn't exist

    best_frame = None
    best_frame_name = None
    highest_brightness = -1  # Initialize with a very low value

    brightness_scores = []

    for filename in os.listdir(input_path):
        input_file = os.path.join(input_path, filename)

        # Ensure the file is an image
        if not filename.lower().endswith(('.jpg')):
            continue

        # Read the image
        frame = cv2.imread(input_file)
        if frame is None:
            print(f"Failed to read {input_file}. Skipping...")
            continue
        
        cropped = crop_image(frame, x, y, w, h)
        cropped_frame = os.path.join(cropped_frame_path, f"{filename}")
        cv2.imwrite(cropped_frame, cropped)
        
        # Measure brightness
        brightness = measure_brightness(cropped)
        brightness_scores.append((filename, brightness))

        print(f"Processed {filename}: Brightness = {brightness:.2f}")

        # Save brightness scores to a text file
        scores_file = os.path.join(output_path, "brightness_scores.txt")
        with open(scores_file, "a") as f:
            f.write(f"Name {filename} : {brightness:.2f}\n")

        # Update the best frame if this one is better
        if brightness > highest_brightness:
            highest_brightness = brightness
            best_frame = frame  # Save the cropped frame as the best frame
            best_frame_name = filename
    
    # Save the best frame separately
    if best_frame is not None:
        best_frame_file = os.path.join(best_frame_path, f"best_frame_{best_frame_name}")
        cv2.imwrite(best_frame_file, best_frame)
        print(f"Best frame saved as: {best_frame_file} with Brightness = {highest_brightness}")


# Example usage
input_path = "Brightness/Samples/10"   # Replace with your input images path
output_path = "Brightness/Results/10"  # Replace with your results path
best_frame_path = "Brightness/Results/10/Best"    # Replace with the path to save the best frame
cropped_frame_path = "Brightness/Results/10/Crop" 
x, y, w, h = 220, 0, 200, 200  # Example crop rectangle (top-left at (100, 50), 200x200 size)
process_brightness_batch(input_path, output_path)
# Out:
# Processed Image5901.jpg: Brightness = 144.61
# Processed Image5904.jpg: Brightness = 157.77
# Processed Image5907.jpg: Brightness = 150.64
# Processed Image5911.jpg: Brightness = 91.14
# Processed Image5921.jpg: Brightness = 67.63
# Processed Image5926.jpg: Brightness = 131.15
# Processed Image5927.jpg: Brightness = 133.84
# Processed Image5933.jpg: Brightness = 92.16
# Processed Image5945.jpg: Brightness = 113.29
# Processed Image5950.jpg: Brightness = 160.69
# Processed Image5952.jpg: Brightness = 145.08
# Processed Image5967.jpg: Brightness = 126.23
# Processed Image5970.jpg: Brightness = 155.55
# Processed Image5973.jpg: Brightness = 148.31
# Processed Image5994.jpg: Brightness = 150.36
# Processed Image5996.jpg: Brightness = 151.99
# Processed Image6001.jpg: Brightness = 111.62
# Processed Image6783.jpg: Brightness = 126.53
# Processed Image6789.jpg: Brightness = 171.29
# Processed Image6790.jpg: Brightness = 148.10
# Processed Image6835.jpg: Brightness = 157.27
# Processed Image6837.jpg: Brightness = 157.89
# Processed Image6841.jpg: Brightness = 158.60
# Processed Image6844.jpg: Brightness = 129.92
# Processed Image6859.jpg: Brightness = 147.59
# Processed Image6863.jpg: Brightness = 163.56
# Processed Image6865.jpg: Brightness = 157.04
# Processed Image6887.jpg: Brightness = 163.68
# Processed Image6888.jpg: Brightness = 157.45
# Processed Image7259.jpg: Brightness = 149.97
# Processed Image7260.jpg: Brightness = 141.47
# Processed Image7265.jpg: Brightness = 99.56
# Processed Image7267.jpg: Brightness = 79.50
# Processed Image7301.jpg: Brightness = 93.15
# Processed Image7304.jpg: Brightness = 154.80
# Processed Image7307.jpg: Brightness = 151.91
# Processed Image7311.jpg: Brightness = 68.43
# Processed Image7325.jpg: Brightness = 93.57
# Processed Image7330.jpg: Brightness = 137.73
# Processed Image7331.jpg: Brightness = 139.92
# Processed Image7349.jpg: Brightness = 116.96
# Processed Image7350.jpg: Brightness = 152.35
# Processed Image7355.jpg: Brightness = 175.37
# Processed Image7357.jpg: Brightness = 151.05
# Processed Image7361.jpg: Brightness = 96.15
# Processed Image7952.jpg: Brightness = 185.15
# Processed Image7955.jpg: Brightness = 183.81
# Processed Image7959.jpg: Brightness = 150.53
# Processed Image7976.jpg: Brightness = 103.60
# Processed Image7981.jpg: Brightness = 100.11
# Processed Image7982.jpg: Brightness = 95.89
# Processed Image7999.jpg: Brightness = 121.08
# Processed Image8000.jpg: Brightness = 157.95
# Processed Image8005.jpg: Brightness = 161.59
# Processed Image8007.jpg: Brightness = 154.79
# Processed Image8024.jpg: Brightness = 103.51
# Processed Image8027.jpg: Brightness = 146.80
# Processed Image8030.jpg: Brightness = 156.03
# Processed Image8034.jpg: Brightness = 137.40
# Processed Image8036.jpg: Brightness = 99.57
# Processed Image8052.jpg: Brightness = 118.03
# Processed Image8053.jpg: Brightness = 114.56
# Processed Image8059.jpg: Brightness = 103.57
# Processed Image8060.jpg: Brightness = 98.55
# Processed Image8355.jpg: Brightness = 90.70
# Processed Image8357.jpg: Brightness = 145.25
# Processed Image8361.jpg: Brightness = 184.03
# Processed Image8364.jpg: Brightness = 161.22
# Processed Image8367.jpg: Brightness = 129.56
# Processed Image8383.jpg: Brightness = 42.64
# Processed Image8385.jpg: Brightness = 63.37
# Processed Image8390.jpg: Brightness = 83.15
# Processed Image8391.jpg: Brightness = 73.74
# Processed Image8410.jpg: Brightness = 94.97
# Processed Image8411.jpg: Brightness = 96.89
# Processed Image8416.jpg: Brightness = 39.65
# Processed Image8428.jpg: Brightness = 138.91
# Processed Image8432.jpg: Brightness = 120.34
# Processed Image8435.jpg: Brightness = 106.08
# Processed Image8438.jpg: Brightness = 94.52
# Processed Image8451.jpg: Brightness = 68.53
# Processed Image8453.jpg: Brightness = 84.16
# Processed Image8458.jpg: Brightness = 43.76
# Best frame saved as: Brightness/Results/10/Best\best_frame_Image7952.jpg with Brightness = 185.151525
