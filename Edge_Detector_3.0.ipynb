# %%
import cv2
import os
import numpy as np

# %%
def crop_image(frame, x, y, w, h):
    """
    Crops a region of interest (ROI) from an image.

    Args:
        frame (np.array): Input image.
        x (int): X-coordinate of the top-left corner of the ROI.
        y (int): Y-coordinate of the top-left corner of the ROI.
        w (int): Width of the ROI.
        h (int): Height of the ROI.

    Returns:
        np.array: Cropped image.
    """
    return frame[y:y+h, x:x+w]

# %%
def measure_edge_richness(frame):
    """
    Measures the edge richness of a frame using Canny edge detection.
    
    Args:
        frame (np.array): Input frame (BGR format).
    
    Returns:
        edges (np.array): The edge-detected image.
        edge_richness (int): The sum of edge intensities (or count of edge pixels).
    """
    gray = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)  # Convert to grayscale
    edges = cv2.Canny(gray, 200, 400)  # Apply Canny edge detection
    edge_richness = np.sum(edges)  # Sum of edge pixel intensities
    return edges, edge_richness

# %%
def process_batch(input_path, output_path):
    """
    Processes a batch of images, applies edge detection, computes edge richness, 
    and saves the results to the output path.

    Args:
        input_path (str): Path to the folder containing input images.
        output_path (str): Path to the folder to save results.
    """
    if not os.path.exists(output_path):
        os.makedirs(output_path)  # Create the output directory if it doesn't exist

    # Loop through all images in the input directory
    for filename in os.listdir(input_path):
        input_file = os.path.join(input_path, filename)
        
        # Ensure the file is an image
        if not (filename.lower().endswith(('.jpg'))):
            continue

        # Read the image
        frame = cv2.imread(input_file)
        if frame is None:
            print(f"Failed to read {input_file}. Skipping...")
            continue
        
        crop_image(frame, 0, 0, 640, 240)

        # Apply edge detection and measure edge richness
        edges, edge_richness = measure_edge_richness(frame)

        # Save the edge-detected image
        edge_file = os.path.join(output_path, f"edges_{filename}")
        cv2.imwrite(edge_file, edges)

        # Save the edge richness score to a text file
        score_file = os.path.join(output_path, "edge_richness_scores.txt")
        with open(score_file, "a") as f:
            f.write(f"{filename}: {edge_richness}\n")

        print(f"Processed {filename}: Edge Richness = {edge_richness}")

# %%
# Example usage
input_path = "Edge/Samples"   # Replace with the path to your input images
output_path = "Edge/Results"  # Replace with the path to save results
process_batch(input_path, output_path)
# Out:
# Processed Image0021.jpg: Edge Richness = 0
# Processed Image0022.jpg: Edge Richness = 0
# Processed Image0023.jpg: Edge Richness = 0
# Processed Image0024.jpg: Edge Richness = 0
# Processed Image0025.jpg: Edge Richness = 0
# Processed Image0026.jpg: Edge Richness = 0
# Processed Image0027.jpg: Edge Richness = 0
# Processed Image0028.jpg: Edge Richness = 0
# Processed Image0029.jpg: Edge Richness = 0
# Processed Image0030.jpg: Edge Richness = 0
# Processed Image0031.jpg: Edge Richness = 0
# Processed Image0032.jpg: Edge Richness = 0
# Processed Image0033.jpg: Edge Richness = 0
# Processed Image0034.jpg: Edge Richness = 0
# Processed Image0035.jpg: Edge Richness = 0
# Processed Image0036.jpg: Edge Richness = 0
# Processed Image0037.jpg: Edge Richness = 0
# Processed Image0038.jpg: Edge Richness = 0
# Processed Image0039.jpg: Edge Richness = 0
# Processed Image0040.jpg: Edge Richness = 0
# Processed Image0041.jpg: Edge Richness = 0
# Processed Image0042.jpg: Edge Richness = 0
# Processed Image0043.jpg: Edge Richness = 0
# Processed Image0044.jpg: Edge Richness = 0
# Processed Image0045.jpg: Edge Richness = 0
# Processed Image0046.jpg: Edge Richness = 0
# Processed Image0047.jpg: Edge Richness = 0
# Processed Image0048.jpg: Edge Richness = 0
# Processed Image4385.jpg: Edge Richness = 81855
# Processed Image4386.jpg: Edge Richness = 65790
# Processed Image4387.jpg: Edge Richness = 79815
# Processed Image4388.jpg: Edge Richness = 93330
# Processed Image4389.jpg: Edge Richness = 78030
# Processed Image4390.jpg: Edge Richness = 97410
# Processed Image4391.jpg: Edge Richness = 142035
# Processed Image4392.jpg: Edge Richness = 149685
# Processed Image4393.jpg: Edge Richness = 155040
# Processed Image4394.jpg: Edge Richness = 150960
# Processed Image4395.jpg: Edge Richness = 143055
# Processed Image4396.jpg: Edge Richness = 184620
# Processed Image4397.jpg: Edge Richness = 140505
# Processed Image4398.jpg: Edge Richness = 164475
# Processed Image4399.jpg: Edge Richness = 152235
# Processed Image4400.jpg: Edge Richness = 160395
# Processed Image4401.jpg: Edge Richness = 181305
# Processed Image4402.jpg: Edge Richness = 202980
# Processed Image4403.jpg: Edge Richness = 234345
# Processed Image4404.jpg: Edge Richness = 171360
# Processed Image4405.jpg: Edge Richness = 216495
# Processed Image4406.jpg: Edge Richness = 209865
# Processed Image4407.jpg: Edge Richness = 198645
# Processed Image4408.jpg: Edge Richness = 182325
# Processed Image4409.jpg: Edge Richness = 230265
# Processed Image4410.jpg: Edge Richness = 233580
# Processed Image4411.jpg: Edge Richness = 237915
# Processed Image4412.jpg: Edge Richness = 250155
# Processed Image4413.jpg: Edge Richness = 164730
# Processed Image4414.jpg: Edge Richness = 243270
# Processed Image4415.jpg: Edge Richness = 230775
# Processed Image4416.jpg: Edge Richness = 235875
# Processed Image4417.jpg: Edge Richness = 161415
# Processed Image4418.jpg: Edge Richness = 137190
# Processed Image4419.jpg: Edge Richness = 115770
# Processed Image4420.jpg: Edge Richness = 118830
# Processed Image4421.jpg: Edge Richness = 115515
# Processed Image4422.jpg: Edge Richness = 103275
# Processed Image4423.jpg: Edge Richness = 114750
# Processed Image4424.jpg: Edge Richness = 127755
# Processed Image4425.jpg: Edge Richness = 104805
# Processed Image4426.jpg: Edge Richness = 145605
# Processed Image4427.jpg: Edge Richness = 149175
# Processed Image4428.jpg: Edge Richness = 151215
# Processed Image4429.jpg: Edge Richness = 147900
# Processed Image4430.jpg: Edge Richness = 126480
# Processed Image4431.jpg: Edge Richness = 169575
# Processed Image4432.jpg: Edge Richness = 165495
# Processed Image4433.jpg: Edge Richness = 142035
# Processed Image4434.jpg: Edge Richness = 132600
# Processed Image4435.jpg: Edge Richness = 128520
# Processed Image4436.jpg: Edge Richness = 87210
# Processed Image4437.jpg: Edge Richness = 102765
# Processed Image4438.jpg: Edge Richness = 92055
# Processed Image4439.jpg: Edge Richness = 73440
# Processed Image4440.jpg: Edge Richness = 75990
# Processed Image4441.jpg: Edge Richness = 75735
# Processed Image4442.jpg: Edge Richness = 30600
# Processed Image4443.jpg: Edge Richness = 37995
# Processed Image4444.jpg: Edge Richness = 35190
# Processed Image4445.jpg: Edge Richness = 73440
# Processed Image4446.jpg: Edge Richness = 75990
# Processed Image4447.jpg: Edge Richness = 78540
# Processed Image4448.jpg: Edge Richness = 77010
# Processed Image4449.jpg: Edge Richness = 74460
# Processed Image4450.jpg: Edge Richness = 70125
# Processed Image4451.jpg: Edge Richness = 72930
# Processed Image4452.jpg: Edge Richness = 52275
# Processed Image4453.jpg: Edge Richness = 33150
# Processed Image4454.jpg: Edge Richness = 20400
# Processed Image4455.jpg: Edge Richness = 17850
# Processed Image4456.jpg: Edge Richness = 0
