# %%
# import necessary libraries
import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt
import time

# %%
BATCH_SIZE = 32
IMAGE_SIZE = (128,128)

# %%
train_data_dir = r'D:\Cologne\Sample DataSet 6\train'
test_data_dir = r'D:\Cologne\Sample DataSet 6\test'

train_data = tf.keras.utils.image_dataset_from_directory(train_data_dir,
                                                         batch_size=BATCH_SIZE,
                                                         image_size=IMAGE_SIZE,
                                                         subset='training',
                                                         validation_split=0.1,
                                                         seed=42)

validation_data = tf.keras.utils.image_dataset_from_directory(train_data_dir,
                                                         batch_size=BATCH_SIZE,
                                                         image_size=IMAGE_SIZE,
                                                         subset='validation',
                                                         validation_split=0.1,
                                                         seed=42)

test_data = tf.keras.utils.image_dataset_from_directory(test_data_dir,
                                                         batch_size=BATCH_SIZE,
                                                         image_size=IMAGE_SIZE)
# Out:
# Found 316 files belonging to 2 classes.
# Using 285 files for training.
# Found 316 files belonging to 2 classes.
# Using 31 files for validation.
# Found 200 files belonging to 2 classes.

# %%
class_names = train_data.class_names
class_names
# Out:
# ['defective', 'non-defective']

# %%
for image_batch,label_batch in train_data.take(1):
    print(image_batch.shape)
    print(label_batch.shape)
# Out:
# (32, 128, 128, 3)
# (32,)

# %%
# plot data sample
plt.figure(figsize=(10,4))
for image,label in train_data.take(1):
    for i in range(10):
        ax = plt.subplot(2,5,i+1)
        plt.imshow(image[i].numpy().astype('uint8'))
        plt.title(class_names[label[i]])
        plt.axis('off')

# %%
train_data = train_data.map(lambda x,y:(x/255,y))
validation_data = validation_data.map(lambda x,y:(x/255,y))
test_data = test_data.map(lambda x,y:(x/255,y))

# %%
pretrained_model = tf.keras.applications.xception.Xception(include_top=False,
                                                           input_shape=(128,128,3),
                                                           weights="imagenet",
                                                           pooling='max')
for layer in pretrained_model.layers:
        layer.trainable=False

# %%
model = tf.keras.models.Sequential()
model.add(tf.keras.layers.InputLayer(input_shape=(128, 128, 3)))

model.add(pretrained_model)

model.add(tf.keras.layers.Flatten())
model.add(tf.keras.layers.Dropout(0.2))
model.add(tf.keras.layers.Dense(units=16, activation='relu'))
model.add(tf.keras.layers.Dense(units=16, activation='relu'))
model.add(tf.keras.layers.Dense(units=8, activation='relu'))
model.add(tf.keras.layers.Dense(units=1, activation='sigmoid'))
# Out:
# c:\Users\malin\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\layers\core\input_layer.py:27: UserWarning: Argument `input_shape` is deprecated. Use `shape` instead.
#   warnings.warn(

# %%
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ xception (Functional)           │ (None, 2048)           │    20,861,480 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten (Flatten)               │ (None, 2048)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 2048)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 16)             │        32,784 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 16)             │           272 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 8)              │           136 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_3 (Dense)                 │ (None, 1)              │             9 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 20,894,681 (79.71 MB)
#  Trainable params: 33,201 (129.69 KB)
#  Non-trainable params: 20,861,480 (79.58 MB)

# %%
model.compile(optimizer=tf.keras.optimizers.Adam(),
              loss=tf.keras.losses.BinaryCrossentropy(),
              metrics=['accuracy'])

# %%
start_time = time.time()

history = model.fit(train_data,
                    epochs=15,
                    validation_data=validation_data)

end_time = time.time()
# Out:
# Epoch 1/15
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 16s 902ms/step - accuracy: 0.6194 - loss: 0.6692 - val_accuracy: 0.7097 - val_loss: 0.4948
# Epoch 2/15
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 6s 657ms/step - accuracy: 0.6228 - loss: 0.5709 - val_accuracy: 0.7097 - val_loss: 0.4796
# Epoch 3/15
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 6s 662ms/step - accuracy: 0.6293 - loss: 0.5309 - val_accuracy: 0.7097 - val_loss: 0.4994
# Epoch 4/15
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 6s 640ms/step - accuracy: 0.6041 - loss: 0.5137 - val_accuracy: 0.7419 - val_loss: 0.4256
# Epoch 5/15
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 6s 617ms/step - accuracy: 0.7025 - loss: 0.4397 - val_accuracy: 0.8065 - val_loss: 0.4128
# Epoch 6/15
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 6s 607ms/step - accuracy: 0.7922 - loss: 0.4223 - val_accuracy: 0.8387 - val_loss: 0.4076
# Epoch 7/15
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 6s 598ms/step - accuracy: 0.8343 - loss: 0.3972 - val_accuracy: 0.8710 - val_loss: 0.4095
# Epoch 8/15
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 6s 620ms/step - accuracy: 0.8508 - loss: 0.4430 - val_accuracy: 0.8387 - val_loss: 0.3983
# Epoch 9/15
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 6s 619ms/step - accuracy: 0.8486 - loss: 0.3422 - val_accuracy: 0.9355 - val_loss: 0.4191
# Epoch 10/15
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 6s 669ms/step - accuracy: 0.8788 - loss: 0.4036 - val_accuracy: 0.9032 - val_loss: 0.3715
# Epoch 11/15
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 6s 643ms/step - accuracy: 0.9199 - loss: 0.3621 - val_accuracy: 0.8710 - val_loss: 0.3522
# Epoch 12/15
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 6s 656ms/step - accuracy: 0.9021 - loss: 0.3380 - val_accuracy: 0.9032 - val_loss: 0.3493
# Epoch 13/15
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 6s 620ms/step - accuracy: 0.9169 - loss: 0.3421 - val_accuracy: 0.8387 - val_loss: 0.3676
# Epoch 14/15
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 6s 631ms/step - accuracy: 0.8817 - loss: 0.3412 - val_accuracy: 0.9032 - val_loss: 0.3324
# Epoch 15/15
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 6s 652ms/step - accuracy: 0.9016 - loss: 0.3185 - val_accuracy: 0.9355 - val_loss: 0.3812

# %%
print(f'Total time for training {(end_time-start_time):.3f} seconds')
# Out:
# Total time for training 98.968 seconds

# %%
fig = plt.figure()
plt.plot(history.history['loss'], color='teal', label='loss')
plt.plot(history.history['val_loss'], color='orange', label='val_loss')
fig.suptitle('Loss', fontsize=20)
plt.legend(loc="upper left")
plt.show()

# %%
fig = plt.figure()
plt.plot(history.history['accuracy'], color='teal', label='accuracy')
plt.plot(history.history['val_accuracy'], color='orange', label='val_accuracy')
fig.suptitle('Accuracy', fontsize=20)
plt.legend(loc="upper left")
plt.show()

# %%
precision = tf.keras.metrics.Precision()
recall = tf.keras.metrics.Recall()
accuracy = tf.keras.metrics.BinaryAccuracy()

# %%
for batch in test_data.as_numpy_iterator():
    X, y = batch
    yhat = model.predict(X)
    precision.update_state(y, yhat)
    recall.update_state(y, yhat)
    accuracy.update_state(y, yhat)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 602ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 651ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 651ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 630ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 640ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step

# %%
precision.result()
# Out:
# <tf.Tensor: shape=(), dtype=float32, numpy=0.8333333134651184>

# %%
recall.result()
# Out:
# <tf.Tensor: shape=(), dtype=float32, numpy=0.6499999761581421>

# %%
accuracy.result()
# Out:
# <tf.Tensor: shape=(), dtype=float32, numpy=0.7599999904632568>

# %%
import cv2

# %%
img = cv2.imread(r'D:\Cologne\Sample DataSet 6\test\non-defective\Image0022.jpg.')
plt.imshow(img)
plt.show()

# %%
resized_image = tf.image.resize(img, IMAGE_SIZE)
scaled_image = resized_image/255

# %%
scaled_image.shape
# Out:
# TensorShape([128, 128, 3])

# %%
np.expand_dims(scaled_image, 0).shape
# Out:
# (1, 128, 128, 3)

# %%
yhat = model.predict(np.expand_dims(scaled_image, 0))
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 141ms/step

# %%
yhat
# Out:
# array([[0.5285232]], dtype=float32)

# %%
class_names
# Out:
# ['defective', 'non-defective']

# %%
if yhat > 0.5:
    print(f'{class_names[1]}')
else:
    print(f'{class_names[0]}')
# Out:
# non-defective

# %%
img = cv2.imread(r'D:\Cologne\Sample DataSet 6\test\defective\Image0022.jpg')
plt.imshow(img)
plt.show()

# %%
resized_image = tf.image.resize(img, IMAGE_SIZE)
scaled_image = resized_image/255

scaled_image.shape
# Out:
# TensorShape([128, 128, 3])

# %%
np.expand_dims(scaled_image, 0).shape
# Out:
# (1, 128, 128, 3)

# %%
yhat = model.predict(np.expand_dims(scaled_image, 0))
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 103ms/step

# %%
yhat
# Out:
# array([[0.3259136]], dtype=float32)

# %%
class_names
# Out:
# ['defective', 'non-defective']

# %%
if yhat > 0.5:
    print(f'{class_names[1]}')
else:
    print(f'{class_names[0]}')
# Out:
# defective

# %%
model.save('my_model_5.0.h5') # saves the model in h5 format
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.

# %%
import cv2
from IPython.display import display, Image
import os

# %%
for i in range(5):  # Test camera indices 0 through 4
    cap = cv2.VideoCapture(i)
    if cap.isOpened():
        print(f"Camera {i} is available")
        cap.release()
    else:
        print(f"Camera {i} is not available")
# Out:
# Camera 0 is available
# Camera 1 is available
# Camera 2 is available
# Camera 3 is not available
# Camera 4 is not available

# %% [markdown]
# import cv2
#
# cap = cv2.VideoCapture(0, cv2.CAP_DSHOW)  # Use DirectShow backend
# if not cap.isOpened():
#     print("Camera not accessible")
# else:
#     print("Camera accessible")

# %% [markdown]
# import cv2
#
# print("Testing cameras with DirectShow backend...")
# for i in range(5):  # Test indices 0 to 4
#     cap = cv2.VideoCapture(i, cv2.CAP_DSHOW)
#     if cap.isOpened():
#         print(f"Camera {i} is available")
#         cap.release()
#     else:
#         print(f"Camera {i} is not available")

# %% [markdown]
# import cv2
#
# # Replace the index '1' with the correct index for Iriun Webcam (use the enumeration test above)
# cap = cv2.VideoCapture(1, cv2.CAP_DSHOW)
#
# if not cap.isOpened():
#     print("Unable to access the camera")
# else:
#     print("Camera is accessible")
#
#     while True:
#         ret, frame = cap.read()
#         if not ret:
#             print("Failed to grab frame")
#             break
#
#         # Display the video feed
#         cv2.imshow("Iriun Webcam", frame)
#
#         # Press 'ESC' to exit
#         if cv2.waitKey(1) & 0xFF == 27:
#             break
#
#     cap.release()
#     cv2.destroyAllWindows()

# %%
def capture_photo(filename='photo.jpg'):
    """
    Captures an image from the webcam and saves it to a file.
    
    Args:
        filename (str): The file path where the image will be saved.
        
    Returns:
        str: The filename of the captured photo.
    """
    # Open webcam
    cap = cv2.VideoCapture(2)

    if not cap.isOpened():
        raise IOError("Cannot access the webcam")

    print("Press 'Space' to capture the photo or 'ESC' to exit.")

    while True:
        # Read frame from the webcam
        ret, frame = cap.read()
        if not ret:
            raise IOError("Failed to read from the webcam")

        # Show the live video feed
        cv2.imshow("Webcam - Press Space to Capture", frame)

        # Wait for key press
        key = cv2.waitKey(1)

        if key == 27:  # ESC key to exit
            print("Exiting without saving...")
            break
        elif key == 32:  # Space key to capture photo
            cv2.imwrite(filename, frame)  # Save the captured image
            print(f"Photo saved to {filename}")
            break

    # Release resources
    cap.release()
    cv2.destroyAllWindows()

    # Return the filename
    return filename

# Usage
try:
    filename = capture_photo("captured_image.jpg")
    display(Image(filename))  # Display the captured image in Jupyter
except Exception as e:
    print(f"Error: {e}")
# Out:
# Press 'Space' to capture the photo or 'ESC' to exit.
# Photo saved to captured_image.jpg

# %%
img = cv2.imread(filename)

resized_image = tf.image.resize(img, IMAGE_SIZE)
scaled_image = resized_image/255

scaled_image.shape
  
np.expand_dims(scaled_image, 0).shape

yhat = model.predict(np.expand_dims(scaled_image, 0))
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 120ms/step

# %%
if yhat > 0.5:
    print(f'{class_names[1]}')
else:
    print(f'{class_names[0]}')
# Out:
# non-defective
